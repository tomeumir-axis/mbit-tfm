# %% [markdown]
# # MBIT School
#
# ## Executive Master en Data Science (2020-2021)
#
# by
#
# *Nuria Espadas*
# *Mireia Vecino*
# *Tomeu Mir*
#
# ## notebook: pre_process
#
# This notebook mainly loads datasets:
#  - **df_meteo**: contains the weather information for each day in 2019 in Tenerife. The data was obtained via API from AEMET.es
#  - **df_xa**: contains all the excursions exported from the Oracle database.
#
#
# After loading the two datasets, the notebook creates a new dataset adding the weather information to each excursion for when the excursion was made.
#
# This process was a little bit tricky, as there are 4 different weather measures for each metric per day, because the info was collected from 4 different stations.
#
# The weather info finally added to each excursion belongs to the closest station, as we had the lat and long for each excursion.
#
# The output is persisted in acsv file **df_tfs_xa_plus_meteo.csv**, which will be the one that will be used as a input for the further different **EDA processes**.

# %%
import pandas as pd
import numpy as np

# %%
DATA_PATH = '../data/'

# %% [markdown]
# # Load idemas dataset

# %%
df_idemas = pd.read_csv(DATA_PATH+'idemas.csv')
df_idemas.rename(columns={"idema": "indicativo"}, inplace=True)
df_idemas
# Out:
#   indicativo                      ubi        lat        lon
# 0      C429I             TENERIFE/SUR  28.046991 -16.561157
# 1      C439J          TENERIFE-GÜIMAR  28.318405 -16.382229
# 2      C447A      TENERIFE/LOS RODEOS  28.477497 -16.329445
# 3      C449C  SANTA CRUZ DE TENERIFE   28.463337 -16.255281

# %% [markdown]
# # Load meteo metrics dataset
#
# It contains all meteo metrics from 2019 for the 4 IDEMAS identified above

# %%
df_meteo = pd.read_csv(DATA_PATH+'df_meteo_tfs_2019.csv', decimal=',')
df_meteo['fecha'] = pd.to_datetime(df_meteo['fecha'])
df_meteo.head(4)
# Out:
#        fecha indicativo                     nombre              provincia  \
# 0 2019-01-01      C447A  TENERIFE NORTE AEROPUERTO  STA. CRUZ DE TENERIFE
# 1 2019-01-01      C449C       STA.CRUZ DE TENERIFE  STA. CRUZ DE TENERIFE
# 2 2019-01-01      C429I    TENERIFE SUR AEROPUERTO  STA. CRUZ DE TENERIFE
# 3 2019-01-01      C439J                     GÜÍMAR  STA. CRUZ DE TENERIFE
#
#    altitud  tmed prec  tmin horatmin  tmax horatmax   dir  velmedia  racha  \
# 0      632  15.0  0,0  10.4    07:56  19.5    15:30  16.0       3.9   11.4
# 1       35  19.6  0,0  15.0    07:00  24.2    15:20  20.0       3.1    8.6
# 2       64  19.2  0,0  15.1    06:54  23.3    13:05   3.0       4.4    8.9
# 3      115  16.6  0,0  10.5    05:50  22.6    17:00   NaN       NaN    NaN
#
#   horaracha  sol  presMax horaPresMax  presMin horaPresMin
# 0     10:11  5.5    956.5      Varias    951.2          01
# 1     13:00  9.3   1023.3      Varias   1018.1          01
# 2     20:50  9.6   1018.3      Varias   1013.0          05
# 3       NaN  NaN   1013.7          22   1008.4          05

# %% [markdown]
# # Add coordenates to meteo dataset
#
# Getting the lat,lon from the idemas dataset

# %%
df_clima = pd.merge(df_meteo, df_idemas, how='left', on='indicativo')
df_clima.drop(['nombre','provincia','ubi','altitud','horatmin','horatmax','horaracha','horaPresMax','horaPresMin'],axis=1, inplace=True)
df_clima.head()
# Out:
#        fecha indicativo  tmed prec  tmin  tmax   dir  velmedia  racha  sol  \
# 0 2019-01-01      C447A  15.0  0,0  10.4  19.5  16.0       3.9   11.4  5.5
# 1 2019-01-01      C449C  19.6  0,0  15.0  24.2  20.0       3.1    8.6  9.3
# 2 2019-01-01      C429I  19.2  0,0  15.1  23.3   3.0       4.4    8.9  9.6
# 3 2019-01-01      C439J  16.6  0,0  10.5  22.6   NaN       NaN    NaN  NaN
# 4 2019-01-02      C447A  14.6  0,0  10.9  18.2  14.0       3.1    7.8  6.3
#
#    presMax  presMin        lat        lon
# 0    956.5    951.2  28.477497 -16.329445
# 1   1023.3   1018.1  28.463337 -16.255281
# 2   1018.3   1013.0  28.046991 -16.561157
# 3   1013.7   1008.4  28.318405 -16.382229
# 4    957.5    954.5  28.477497 -16.329445

# %%
df_clima.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1460 entries, 0 to 1459
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   fecha       1460 non-null   datetime64[ns]
#  1   indicativo  1460 non-null   object
#  2   tmed        1456 non-null   float64
#  3   prec        1460 non-null   object
#  4   tmin        1456 non-null   float64
#  5   tmax        1458 non-null   float64
#  6   dir         1425 non-null   float64
#  7   velmedia    1440 non-null   float64
#  8   racha       1425 non-null   float64
#  9   sol         1088 non-null   float64
#  10  presMax     1453 non-null   float64
#  11  presMin     1453 non-null   float64
#  12  lat         1460 non-null   float64
#  13  lon         1460 non-null   float64
# dtypes: datetime64[ns](1), float64(11), object(2)
# memory usage: 171.1+ KB

# %% [markdown]
# ### The "prec" column has some shity values ('Ip'), we remove them replacing them by NaNs and then we convert the column to float type

# %%
df_clima['prec'] = df_clima['prec'].replace('Ip', '0')  # remove Ip and set to 0
df_clima['prec'] = df_clima['prec'].str.replace(',', '.').astype(float)

# %%
df_clima.describe().transpose()
# Out:
#            count        mean        std         min         25%          50%  \
# tmed      1456.0   20.188530   3.458110   11.700000   18.000000    20.000000
# prec      1460.0    0.421096   2.493840    0.000000    0.000000     0.000000
# tmin      1456.0   16.498901   3.386078    7.400000   14.200000    16.400000
# tmax      1458.0   23.868244   3.842759   13.000000   21.400000    23.700000
# dir       1425.0   32.945263  35.297151    1.000000    7.000000    18.000000
# velmedia  1440.0    4.965000   2.319970    1.100000    3.100000     4.200000
# racha     1425.0   11.434947   3.513695    3.900000    8.900000    11.100000
# sol       1088.0    8.080147   3.517593    0.000000    5.600000     9.100000
# presMax   1453.0  996.353407  26.915474  940.400000  997.400000  1009.100000
# presMin   1453.0  993.248451  26.799201  935.600000  992.500000  1006.000000
# lat       1460.0   28.326558   0.173059   28.046991   28.250552    28.390871
# lon       1460.0  -16.382028   0.112863  -16.561157  -16.426961   -16.355837
#
#                   75%          max
# tmed        22.800000    30.400000
# prec         0.000000    42.800000
# tmin        19.100000    25.700000
# tmax        26.700000    36.400000
# dir         33.000000    99.000000
# velmedia     6.700000    15.800000
# racha       13.900000    24.700000
# sol         10.900000    13.300000
# presMax   1014.200000  1025.900000
# presMin   1010.900000  1022.900000
# lat         28.466877    28.477497
# lon        -16.310904   -16.255281

# %% [markdown]
# # Add meteo metrics to the excursions dataset
#
# Based on the booking date, get the meteo metrics of that day from the closest indicativo.
#
#
#   1. adding a column to df_xa -> df_xa['indicativo'] = get_closest_idema(xa_lat,xa_lon)
#
#
#   df_xa['indicativo'] = get_closest_idema(df_xa['i_lat'],df_xa['i_lon'])
#
#
#
#   2. joining df_xa with df_clima by:
#   - df_xa.booking_date = df_clima.fecha
#       - AND
#   - df_xa.indicativo = df_clima.indicativo
#
#
# **geopy**:<br>
# https://github.com/geopy/geopy
# Using library **geopy** for calculating the distance between to location points.<br>
# From terminal execute: conda install -c conda-forge geopy**

# %% [markdown]
# **Quick test of the function geodesic of the geopy lib**
# ```
# # testing the lib
# C429I_TENERIFE_SUR = (28.046991, -16.561157)
# C449C_SANTA_CRUZ_DE_TENERIFE = (28.463337,-16.255281)
#
# dist_km = geodesic(C429I_TENERIFE_SUR, C449C_SANTA_CRUZ_DE_TENERIFE).km
# print (dist_km)
# ```
# **output:**
# ```
# 55.044545572206346

# %% [markdown]
# **The following code was for making a quick test of the procedure to follow for getting the closest IDEMA passing a location as a parameter:**
#
# ```
# from geopy.distance import geodesic
#
# def get_closest_idema( loc_point):
#     # returns the closest idema to the point location pased as parameters
#     # parameter: loc_point = (lat,lon) # tuple
#     idema = None
#     min_dist = 100000 # initially 100k kms so, the first iteration always will set the min. value.
#     for index, row in df_idemas.iterrows():
#         idema_loc = (row['lat'], row['lon'])
#         dist = geodesic(loc_point, idema_loc).km
#         if dist < min_dist:
#             min_dist = dist
#             idema = row['indicativo']
#         print(row['indicativo'],row['lat'], row['lon'], dist, min_dist)
#     return idema
#
# # Testing the function
# loc_point = (28.480410, -16.400138) # LESTCI4FX8	Bodegas Alvaro
# closest_indicativo = get_closest_idema( loc_point)
# closest_indicativo
# ```
#
# **And the output is:**
# ```
# C429I 28.046991 -16.561157 50.56479217874456 50.56479217874456
# C439J 28.318405 -16.382229 18.039925667610657 18.039925667610657
# C447A 28.477497 -16.329445 6.930032096794651 6.930032096794651
# C449C 28.463337 -16.255281 14.311488034348436 6.930032096794651
#
# 'C447A'
# ```

# %%
df_xa = pd.read_csv(DATA_PATH+'df_tfs_xa_2019.csv')

df_xa.head()
# Out:
#    H_BO_HEADERID H_BOOKINGDATE H_STARTDATE H_ENDDATE  H_DURATION  \
# 0       21788788      10/05/18    06/01/19  27/01/19          21
# 1       21788788      10/05/18    06/01/19  27/01/19          21
# 2       21788788      10/05/18    06/01/19  27/01/19          21
# 3       21788788      10/05/18    06/01/19  27/01/19          21
# 4       21788788      10/05/18    06/01/19  27/01/19          21
#
#    H_DAYSBEFOREBOOK  I_BO_ITEMID I_BOOKINGDATE I_STARTDATE I_ENDDATE  ...  \
# 0               241     57811718      10/05/18    14/01/19  14/01/19  ...
# 1               241     57811786      10/05/18    22/01/19  22/01/19  ...
# 2               241     59637648      10/05/18    22/01/19  22/01/19  ...
# 3               241     59244068      10/05/18    16/01/19  16/01/19  ...
# 4               241     57811620      10/05/18    16/01/19  16/01/19  ...
#
#    CHD  INF  AVG_ADT_AGE  LEAD_PAX_AGE TR_NUM_OF_SERVICES TR_TOTAL_SALES  \
# 0    0    0          NaN           NaN                2.0           13.0
# 1    0    0          NaN           NaN                2.0           13.0
# 2    0    0          NaN           NaN                2.0           13.0
# 3    0    0          NaN           NaN                2.0           13.0
# 4    0    0          NaN           NaN                2.0           13.0
#
#   XA_NUM_OF_SERVICES  XA_TOTAL_SALES AC_NUM_OF_SERVICES AC_TOTAL_SALES
# 0                  5             221                1.0            0.0
# 1                  5             221                1.0            0.0
# 2                  5             221                1.0            0.0
# 3                  5             221                1.0            0.0
# 4                  5             221                1.0            0.0
#
# [5 rows x 36 columns]

# %%
df_xa['H_BOOKINGDATE'] = pd.to_datetime(df_xa['H_BOOKINGDATE'])
df_xa['H_STARTDATE'] = pd.to_datetime(df_xa['H_STARTDATE'])
df_xa['H_ENDDATE'] = pd.to_datetime(df_xa['H_ENDDATE'])
df_xa['I_BOOKINGDATE'] = pd.to_datetime(df_xa['I_BOOKINGDATE'])
df_xa['I_STARTDATE'] = pd.to_datetime(df_xa['I_STARTDATE'])
df_xa['I_ENDDATE'] = pd.to_datetime(df_xa['I_ENDDATE'])

# %%
from geopy.distance import geodesic
    
def get_closest_idema(x):
    # returns the closest idema to the (lat,lon) of the row pased as parameters
    # parameter: a df row
    #
    if pd.isna(x['I_LATITUD']) or pd.isna(x['I_LATITUD']):
        return None
    
    loc_point = (x['I_LATITUD'], x['I_LONGITUD'])
    
    idema = None
    min_dist = 100000 # initially 100k kms so, the first iteration always will set the min. value.
    for index, row in df_idemas.iterrows():
        idema_loc = (row['lat'], row['lon'])
        dist = geodesic(loc_point, idema_loc).km
        if dist < min_dist:
            min_dist = dist
            idema = row['indicativo']
            
    return idema

# %%
df_xa['indicativo'] = df_xa.apply(get_closest_idema, axis=1)
df_xa[['STOCK_CODE','I_LATITUD','I_LONGITUD','indicativo']]
# Out:
#        STOCK_CODE  I_LATITUD  I_LONGITUD indicativo
# 0      XESTCIBSBI  28.056230  -16.724170      C429I
# 1      PESTCI4KNA  28.063877  -16.727066      C429I
# 2      LESTCI5XRO  28.033218  -17.190764      C429I
# 3      LESTCI4FX8  28.480410  -16.400138      C447A
# 4      XESTCIBUM4  28.061094  -16.727680      C429I
# ...           ...        ...         ...        ...
# 25480  PESTCI4IGS  28.264957  -16.637370      C429I
# 25481  PESTCI4FMM  28.417067  -16.542494      C439J
# 25482  PESTCI4FMM  28.417067  -16.542494      C439J
# 25483  XESTCID0CS  28.084962  -17.333884      C429I
# 25484  XESTCID0CS  28.084962  -17.333884      C429I
#
# [25485 rows x 4 columns]

# %%
df_xa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25485 entries, 0 to 25484
# Data columns (total 37 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   H_BO_HEADERID          25485 non-null  int64
#  1   H_BOOKINGDATE          25485 non-null  datetime64[ns]
#  2   H_STARTDATE            25485 non-null  datetime64[ns]
#  3   H_ENDDATE              25485 non-null  datetime64[ns]
#  4   H_DURATION             25485 non-null  int64
#  5   H_DAYSBEFOREBOOK       25485 non-null  int64
#  6   I_BO_ITEMID            25485 non-null  int64
#  7   I_BOOKINGDATE          25485 non-null  datetime64[ns]
#  8   I_STARTDATE            25485 non-null  datetime64[ns]
#  9   I_ENDDATE              25485 non-null  datetime64[ns]
#  10  I_DURATION             25485 non-null  int64
#  11  I_DAYSBEFOREBOOK       25485 non-null  int64
#  12  I_OD_RESORTOFFICEID    25485 non-null  int64
#  13  I_OD_STOCKID           25485 non-null  int64
#  14  GD_STOCKTYPEGROUPCODE  25485 non-null  object
#  15  STOCK_CODE             25485 non-null  object
#  16  STOCK_NAME             25485 non-null  object
#  17  I_TOTAL_SALES_SC       25485 non-null  int64
#  18  SERVICEUNITDESC        25485 non-null  object
#  19  SOURCE_MARKET          25485 non-null  object
#  20  SOURCE_COUNTRY_CODE    25481 non-null  object
#  21  SOURCE_COUNTRY_NAME    25481 non-null  object
#  22  AC_AVG_RATING          1450 non-null   float64
#  23  I_LATITUD              25429 non-null  float64
#  24  I_LONGITUD             25429 non-null  float64
#  25  ADT                    25485 non-null  int64
#  26  CHD                    25485 non-null  int64
#  27  INF                    25485 non-null  int64
#  28  AVG_ADT_AGE            14424 non-null  float64
#  29  LEAD_PAX_AGE           14526 non-null  float64
#  30  TR_NUM_OF_SERVICES     1477 non-null   float64
#  31  TR_TOTAL_SALES         1477 non-null   float64
#  32  XA_NUM_OF_SERVICES     25485 non-null  int64
#  33  XA_TOTAL_SALES         25485 non-null  int64
#  34  AC_NUM_OF_SERVICES     1450 non-null   float64
#  35  AC_TOTAL_SALES         1450 non-null   float64
#  36  indicativo             25429 non-null  object
# dtypes: datetime64[ns](6), float64(9), int64(14), object(8)
# memory usage: 7.2+ MB

# %%
# Drop bookings without lat,lon info : 25481 - 25429 = 52 bookings to be deleted
indexNames = df_xa[ (np.isnan(df_xa['I_LATITUD'])) | (np.isnan(df_xa['I_LONGITUD'])) ].index
df_xa.drop(indexNames , inplace=True)

# %%
df_xa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25429 entries, 0 to 25484
# Data columns (total 37 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   H_BO_HEADERID          25429 non-null  int64
#  1   H_BOOKINGDATE          25429 non-null  datetime64[ns]
#  2   H_STARTDATE            25429 non-null  datetime64[ns]
#  3   H_ENDDATE              25429 non-null  datetime64[ns]
#  4   H_DURATION             25429 non-null  int64
#  5   H_DAYSBEFOREBOOK       25429 non-null  int64
#  6   I_BO_ITEMID            25429 non-null  int64
#  7   I_BOOKINGDATE          25429 non-null  datetime64[ns]
#  8   I_STARTDATE            25429 non-null  datetime64[ns]
#  9   I_ENDDATE              25429 non-null  datetime64[ns]
#  10  I_DURATION             25429 non-null  int64
#  11  I_DAYSBEFOREBOOK       25429 non-null  int64
#  12  I_OD_RESORTOFFICEID    25429 non-null  int64
#  13  I_OD_STOCKID           25429 non-null  int64
#  14  GD_STOCKTYPEGROUPCODE  25429 non-null  object
#  15  STOCK_CODE             25429 non-null  object
#  16  STOCK_NAME             25429 non-null  object
#  17  I_TOTAL_SALES_SC       25429 non-null  int64
#  18  SERVICEUNITDESC        25429 non-null  object
#  19  SOURCE_MARKET          25429 non-null  object
#  20  SOURCE_COUNTRY_CODE    25428 non-null  object
#  21  SOURCE_COUNTRY_NAME    25428 non-null  object
#  22  AC_AVG_RATING          1440 non-null   float64
#  23  I_LATITUD              25429 non-null  float64
#  24  I_LONGITUD             25429 non-null  float64
#  25  ADT                    25429 non-null  int64
#  26  CHD                    25429 non-null  int64
#  27  INF                    25429 non-null  int64
#  28  AVG_ADT_AGE            14415 non-null  float64
#  29  LEAD_PAX_AGE           14517 non-null  float64
#  30  TR_NUM_OF_SERVICES     1469 non-null   float64
#  31  TR_TOTAL_SALES         1469 non-null   float64
#  32  XA_NUM_OF_SERVICES     25429 non-null  int64
#  33  XA_TOTAL_SALES         25429 non-null  int64
#  34  AC_NUM_OF_SERVICES     1440 non-null   float64
#  35  AC_TOTAL_SALES         1440 non-null   float64
#  36  indicativo             25429 non-null  object
# dtypes: datetime64[ns](6), float64(9), int64(14), object(8)
# memory usage: 7.4+ MB

# %% [markdown]
# ## Important remark
#
# We should not join the **xa** + **meteo** data based on booking date, because there are booking made quite a lot in advanced, so much, that sometimes the booking was made in 2018 and there are no meteo data. It would not have either sense to use meteo data from 2018, because these bookings are surely made from the market countries, before people travels to the destinations.
#
# **Which meteo data to use?**
#
# - If the booking was done less than 7 days prior the start of the excursion -> meteo data of the **booking_date**
# - If the booking was done with more than 7 days in advanced:
#     - Meteo data of **starting_date - 1** (the previous day)
#     - if the start date if 1-Jan, then we will take the meteo data of the same **starting_date** instead.

# %%
def set_meteo_date(x):
    fecha = x['I_BOOKINGDATE']
    if x['I_DAYSBEFOREBOOK'] > 7 or fecha.year == 2018:
        fecha = x['I_STARTDATE'] - pd.Timedelta(days=1)
        if fecha.year == 2018:
            fecha = x['I_STARTDATE']
    return fecha

# %%
df_xa['fecha'] = df_xa.apply(set_meteo_date, axis=1)
df_xa[['I_BOOKINGDATE','I_DAYSBEFOREBOOK','I_STARTDATE','fecha']]
# Out:
#       I_BOOKINGDATE  I_DAYSBEFOREBOOK I_STARTDATE      fecha
# 0        2018-10-05               249  2019-01-14 2019-01-13
# 1        2018-10-05               257  2019-01-22 2019-01-21
# 2        2018-10-05               257  2019-01-22 2019-01-21
# 3        2018-10-05               251  2019-01-16 2019-01-15
# 4        2018-10-05               251  2019-01-16 2019-01-15
# ...             ...               ...         ...        ...
# 25480    2019-12-29                 0  2019-12-29 2019-12-29
# 25481    2019-12-30                 0  2019-12-30 2019-12-30
# 25482    2019-12-26                 0  2019-12-26 2019-12-26
# 25483    2019-12-30                 0  2019-12-30 2019-12-30
# 25484    2019-12-28                 2  2019-12-30 2019-12-28
#
# [25429 rows x 4 columns]

# %%
df_xa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25429 entries, 0 to 25484
# Data columns (total 38 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   H_BO_HEADERID          25429 non-null  int64
#  1   H_BOOKINGDATE          25429 non-null  datetime64[ns]
#  2   H_STARTDATE            25429 non-null  datetime64[ns]
#  3   H_ENDDATE              25429 non-null  datetime64[ns]
#  4   H_DURATION             25429 non-null  int64
#  5   H_DAYSBEFOREBOOK       25429 non-null  int64
#  6   I_BO_ITEMID            25429 non-null  int64
#  7   I_BOOKINGDATE          25429 non-null  datetime64[ns]
#  8   I_STARTDATE            25429 non-null  datetime64[ns]
#  9   I_ENDDATE              25429 non-null  datetime64[ns]
#  10  I_DURATION             25429 non-null  int64
#  11  I_DAYSBEFOREBOOK       25429 non-null  int64
#  12  I_OD_RESORTOFFICEID    25429 non-null  int64
#  13  I_OD_STOCKID           25429 non-null  int64
#  14  GD_STOCKTYPEGROUPCODE  25429 non-null  object
#  15  STOCK_CODE             25429 non-null  object
#  16  STOCK_NAME             25429 non-null  object
#  17  I_TOTAL_SALES_SC       25429 non-null  int64
#  18  SERVICEUNITDESC        25429 non-null  object
#  19  SOURCE_MARKET          25429 non-null  object
#  20  SOURCE_COUNTRY_CODE    25428 non-null  object
#  21  SOURCE_COUNTRY_NAME    25428 non-null  object
#  22  AC_AVG_RATING          1440 non-null   float64
#  23  I_LATITUD              25429 non-null  float64
#  24  I_LONGITUD             25429 non-null  float64
#  25  ADT                    25429 non-null  int64
#  26  CHD                    25429 non-null  int64
#  27  INF                    25429 non-null  int64
#  28  AVG_ADT_AGE            14415 non-null  float64
#  29  LEAD_PAX_AGE           14517 non-null  float64
#  30  TR_NUM_OF_SERVICES     1469 non-null   float64
#  31  TR_TOTAL_SALES         1469 non-null   float64
#  32  XA_NUM_OF_SERVICES     25429 non-null  int64
#  33  XA_TOTAL_SALES         25429 non-null  int64
#  34  AC_NUM_OF_SERVICES     1440 non-null   float64
#  35  AC_TOTAL_SALES         1440 non-null   float64
#  36  indicativo             25429 non-null  object
#  37  fecha                  25429 non-null  datetime64[ns]
# dtypes: datetime64[ns](7), float64(9), int64(14), object(8)
# memory usage: 7.6+ MB

# %% [markdown]
# **Creating the final dataset** adding the meteo data to excursions data set joining by fecha and indicativo**

# %%
df_xa_plus_meteo = pd.merge(df_xa, df_clima, how='left', on=['fecha','indicativo'])
df_xa_plus_meteo
# Out:
#        H_BO_HEADERID H_BOOKINGDATE H_STARTDATE  H_ENDDATE  H_DURATION  \
# 0           21788788    2018-10-05  2019-06-01 2019-01-27          21
# 1           21788788    2018-10-05  2019-06-01 2019-01-27          21
# 2           21788788    2018-10-05  2019-06-01 2019-01-27          21
# 3           21788788    2018-10-05  2019-06-01 2019-01-27          21
# 4           21788788    2018-10-05  2019-06-01 2019-01-27          21
# ...              ...           ...         ...        ...         ...
# 25424       33576052    2020-02-01  2019-12-29 2019-12-29           0
# 25425       33576626    2020-02-01  2019-12-30 2019-12-30           0
# 25426       33595112    2020-03-01  2019-12-26 2019-12-26           0
# 25427       33744892    2019-12-30  2019-12-30 2019-12-30           0
# 25428       33744974    2019-12-28  2019-12-30 2019-12-30           0
#
#        H_DAYSBEFOREBOOK  I_BO_ITEMID I_BOOKINGDATE I_STARTDATE  I_ENDDATE  \
# 0                   241     57811718    2018-10-05  2019-01-14 2019-01-14
# 1                   241     57811786    2018-10-05  2019-01-22 2019-01-22
# 2                   241     59637648    2018-10-05  2019-01-22 2019-01-22
# 3                   241     59244068    2018-10-05  2019-01-16 2019-01-16
# 4                   241     57811620    2018-10-05  2019-01-16 2019-01-16
# ...                 ...          ...           ...         ...        ...
# 25424                -5     76493326    2019-12-29  2019-12-29 2019-12-29
# 25425                -4     76494434    2019-12-30  2019-12-30 2019-12-30
# 25426                -8     76536686    2019-12-26  2019-12-26 2019-12-26
# 25427                 0     76905618    2019-12-30  2019-12-30 2019-12-30
# 25428                 2     76905782    2019-12-28  2019-12-30 2019-12-30
#
#        ...  tmin  tmax   dir  velmedia racha  sol presMax  presMin        lat  \
# 0      ...  14.8  24.5  99.0       5.0   9.2  9.7  1013.5   1010.3  28.046991
# 1      ...  14.7  21.8  99.0       7.2  15.0  4.0  1016.8   1014.3  28.046991
# 2      ...  14.7  21.8  99.0       7.2  15.0  4.0  1016.8   1014.3  28.046991
# 3      ...   9.4  16.1  11.0       3.9   8.9  5.7   952.5    948.7  28.477497
# 4      ...  15.1  22.8  99.0       7.8  12.8  9.8  1014.3   1010.3  28.046991
# ...    ...   ...   ...   ...       ...   ...  ...     ...      ...        ...
# 25424  ...  16.1  27.0   1.0       3.9   9.7  9.7  1013.5   1010.2  28.046991
# 25425  ...  15.7  23.0   4.0       3.3   7.2  NaN  1011.9   1008.5  28.318405
# 25426  ...  15.1  25.0   5.0       2.8   6.9  NaN  1008.3   1004.3  28.318405
# 25427  ...  15.8  27.2   6.0       5.8  11.7  9.6  1016.0   1012.6  28.046991
# 25428  ...  16.6  27.1  99.0       4.4   9.7  9.1  1011.6   1009.2  28.046991
#
#              lon
# 0     -16.561157
# 1     -16.561157
# 2     -16.561157
# 3     -16.329445
# 4     -16.561157
# ...          ...
# 25424 -16.561157
# 25425 -16.382229
# 25426 -16.382229
# 25427 -16.561157
# 25428 -16.561157
#
# [25429 rows x 50 columns]

# %%
df_xa_plus_meteo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25429 entries, 0 to 25428
# Data columns (total 50 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   H_BO_HEADERID          25429 non-null  int64
#  1   H_BOOKINGDATE          25429 non-null  datetime64[ns]
#  2   H_STARTDATE            25429 non-null  datetime64[ns]
#  3   H_ENDDATE              25429 non-null  datetime64[ns]
#  4   H_DURATION             25429 non-null  int64
#  5   H_DAYSBEFOREBOOK       25429 non-null  int64
#  6   I_BO_ITEMID            25429 non-null  int64
#  7   I_BOOKINGDATE          25429 non-null  datetime64[ns]
#  8   I_STARTDATE            25429 non-null  datetime64[ns]
#  9   I_ENDDATE              25429 non-null  datetime64[ns]
#  10  I_DURATION             25429 non-null  int64
#  11  I_DAYSBEFOREBOOK       25429 non-null  int64
#  12  I_OD_RESORTOFFICEID    25429 non-null  int64
#  13  I_OD_STOCKID           25429 non-null  int64
#  14  GD_STOCKTYPEGROUPCODE  25429 non-null  object
#  15  STOCK_CODE             25429 non-null  object
#  16  STOCK_NAME             25429 non-null  object
#  17  I_TOTAL_SALES_SC       25429 non-null  int64
#  18  SERVICEUNITDESC        25429 non-null  object
#  19  SOURCE_MARKET          25429 non-null  object
#  20  SOURCE_COUNTRY_CODE    25428 non-null  object
#  21  SOURCE_COUNTRY_NAME    25428 non-null  object
#  22  AC_AVG_RATING          1440 non-null   float64
#  23  I_LATITUD              25429 non-null  float64
#  24  I_LONGITUD             25429 non-null  float64
#  25  ADT                    25429 non-null  int64
#  26  CHD                    25429 non-null  int64
#  27  INF                    25429 non-null  int64
#  28  AVG_ADT_AGE            14415 non-null  float64
#  29  LEAD_PAX_AGE           14517 non-null  float64
#  30  TR_NUM_OF_SERVICES     1469 non-null   float64
#  31  TR_TOTAL_SALES         1469 non-null   float64
#  32  XA_NUM_OF_SERVICES     25429 non-null  int64
#  33  XA_TOTAL_SALES         25429 non-null  int64
#  34  AC_NUM_OF_SERVICES     1440 non-null   float64
#  35  AC_TOTAL_SALES         1440 non-null   float64
#  36  indicativo             25429 non-null  object
#  37  fecha                  25429 non-null  datetime64[ns]
#  38  tmed                   25373 non-null  float64
#  39  prec                   25429 non-null  float64
#  40  tmin                   25373 non-null  float64
#  41  tmax                   25374 non-null  float64
#  42  dir                    24976 non-null  float64
#  43  velmedia               25216 non-null  float64
#  44  racha                  24976 non-null  float64
#  45  sol                    17663 non-null  float64
#  46  presMax                25098 non-null  float64
#  47  presMin                25098 non-null  float64
#  48  lat                    25429 non-null  float64
#  49  lon                    25429 non-null  float64
# dtypes: datetime64[ns](7), float64(21), int64(14), object(8)
# memory usage: 9.9+ MB

# %%
df_xa_plus_meteo.head(10)
# Out:
#    H_BO_HEADERID H_BOOKINGDATE H_STARTDATE  H_ENDDATE  H_DURATION  \
# 0       21788788    2018-10-05  2019-06-01 2019-01-27          21
# 1       21788788    2018-10-05  2019-06-01 2019-01-27          21
# 2       21788788    2018-10-05  2019-06-01 2019-01-27          21
# 3       21788788    2018-10-05  2019-06-01 2019-01-27          21
# 4       21788788    2018-10-05  2019-06-01 2019-01-27          21
# 5       21863092    2018-11-03  2018-12-22 2019-05-01          14
# 6       21863092    2018-11-03  2018-12-22 2019-05-01          14
# 7       21924996    2018-05-26  2019-01-03 2019-08-03           7
# 8       21926642    2018-01-04  2019-03-30 2019-04-13          14
# 9       21926642    2018-01-04  2019-03-30 2019-04-13          14
#
#    H_DAYSBEFOREBOOK  I_BO_ITEMID I_BOOKINGDATE I_STARTDATE  I_ENDDATE  ...  \
# 0               241     57811718    2018-10-05  2019-01-14 2019-01-14  ...
# 1               241     57811786    2018-10-05  2019-01-22 2019-01-22  ...
# 2               241     59637648    2018-10-05  2019-01-22 2019-01-22  ...
# 3               241     59244068    2018-10-05  2019-01-16 2019-01-16  ...
# 4               241     57811620    2018-10-05  2019-01-16 2019-01-16  ...
# 5               286     58241674    2018-12-30  2019-02-01 2019-02-01  ...
# 6               286     58194746    2018-12-30  2019-02-01 2019-02-01  ...
# 7               279     61921016    2019-04-03  2019-05-03 2019-05-03  ...
# 8               363     63613814    2019-01-04  2019-09-04 2019-09-04  ...
# 9               363     63310364    2019-01-04  2019-09-04 2019-09-04  ...
#
#    tmin  tmax   dir  velmedia racha   sol presMax  presMin        lat  \
# 0  14.8  24.5  99.0       5.0   9.2   9.7  1013.5   1010.3  28.046991
# 1  14.7  21.8  99.0       7.2  15.0   4.0  1016.8   1014.3  28.046991
# 2  14.7  21.8  99.0       7.2  15.0   4.0  1016.8   1014.3  28.046991
# 3   9.4  16.1  11.0       3.9   8.9   5.7   952.5    948.7  28.477497
# 4  15.1  22.8  99.0       7.8  12.8   9.8  1014.3   1010.3  28.046991
# 5  16.5  19.3  99.0       3.3  10.3   0.0  1013.2   1010.3  28.046991
# 6  16.5  19.3  99.0       3.3  10.3   0.0  1013.2   1010.3  28.046991
# 7  13.0  24.0  26.0       2.8  11.7   7.9  1004.6   1002.0  28.046991
# 8  19.9  27.3  99.0       6.1  10.8  10.4  1011.6   1008.3  28.046991
# 9  14.8  21.2  99.0       4.2  11.7   9.2  1017.3   1013.4  28.046991
#
#          lon
# 0 -16.561157
# 1 -16.561157
# 2 -16.561157
# 3 -16.329445
# 4 -16.561157
# 5 -16.561157
# 6 -16.561157
# 7 -16.561157
# 8 -16.561157
# 9 -16.561157
#
# [10 rows x 50 columns]

# %%
df_xa_plus_meteo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25429 entries, 0 to 25428
# Data columns (total 50 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   H_BO_HEADERID          25429 non-null  int64
#  1   H_BOOKINGDATE          25429 non-null  datetime64[ns]
#  2   H_STARTDATE            25429 non-null  datetime64[ns]
#  3   H_ENDDATE              25429 non-null  datetime64[ns]
#  4   H_DURATION             25429 non-null  int64
#  5   H_DAYSBEFOREBOOK       25429 non-null  int64
#  6   I_BO_ITEMID            25429 non-null  int64
#  7   I_BOOKINGDATE          25429 non-null  datetime64[ns]
#  8   I_STARTDATE            25429 non-null  datetime64[ns]
#  9   I_ENDDATE              25429 non-null  datetime64[ns]
#  10  I_DURATION             25429 non-null  int64
#  11  I_DAYSBEFOREBOOK       25429 non-null  int64
#  12  I_OD_RESORTOFFICEID    25429 non-null  int64
#  13  I_OD_STOCKID           25429 non-null  int64
#  14  GD_STOCKTYPEGROUPCODE  25429 non-null  object
#  15  STOCK_CODE             25429 non-null  object
#  16  STOCK_NAME             25429 non-null  object
#  17  I_TOTAL_SALES_SC       25429 non-null  int64
#  18  SERVICEUNITDESC        25429 non-null  object
#  19  SOURCE_MARKET          25429 non-null  object
#  20  SOURCE_COUNTRY_CODE    25428 non-null  object
#  21  SOURCE_COUNTRY_NAME    25428 non-null  object
#  22  AC_AVG_RATING          1440 non-null   float64
#  23  I_LATITUD              25429 non-null  float64
#  24  I_LONGITUD             25429 non-null  float64
#  25  ADT                    25429 non-null  int64
#  26  CHD                    25429 non-null  int64
#  27  INF                    25429 non-null  int64
#  28  AVG_ADT_AGE            14415 non-null  float64
#  29  LEAD_PAX_AGE           14517 non-null  float64
#  30  TR_NUM_OF_SERVICES     1469 non-null   float64
#  31  TR_TOTAL_SALES         1469 non-null   float64
#  32  XA_NUM_OF_SERVICES     25429 non-null  int64
#  33  XA_TOTAL_SALES         25429 non-null  int64
#  34  AC_NUM_OF_SERVICES     1440 non-null   float64
#  35  AC_TOTAL_SALES         1440 non-null   float64
#  36  indicativo             25429 non-null  object
#  37  fecha                  25429 non-null  datetime64[ns]
#  38  tmed                   25373 non-null  float64
#  39  prec                   25429 non-null  float64
#  40  tmin                   25373 non-null  float64
#  41  tmax                   25374 non-null  float64
#  42  dir                    24976 non-null  float64
#  43  velmedia               25216 non-null  float64
#  44  racha                  24976 non-null  float64
#  45  sol                    17663 non-null  float64
#  46  presMax                25098 non-null  float64
#  47  presMin                25098 non-null  float64
#  48  lat                    25429 non-null  float64
#  49  lon                    25429 non-null  float64
# dtypes: datetime64[ns](7), float64(21), int64(14), object(8)
# memory usage: 9.9+ MB

# %%
df_xa_plus_meteo.to_csv(DATA_PATH+'df_tfs_xa_plus_meteo.csv')
