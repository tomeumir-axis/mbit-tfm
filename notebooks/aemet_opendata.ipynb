# %% [markdown]
# # MBIT School
#
# ## Executive Master en Data Science (2020-2021)
#
# by
#
# *Nuria Espadas*
# *Mireia Vecino*
# *Tomeu Mir*
#
#
#
# # AEMET open data API
#
#
#
# **With this notebook we collect the meteo data for each day of 2019 in Tenerife.**
#
#
# How to get the key:
# https://opendata.aemet.es/centrodedescargas/inicio
#
#
# How to use the api - pdf document:
# https://opendata.aemet.es/centrodedescargas/docs/FAQs150217.pdf
#
#
# How to get the IDEMA codes or references:
# https://es.stackoverflow.com/questions/63842/aemet-opendata-api-no-devuelve-body

# %%
import requests
import json
import numpy as np
import pandas as pd

# %%
DATA_PATH = '../data/'

# %%
url = "https://opendata.aemet.es/opendata"
api_key = 'better get your own key amiguito'

# %%
# As the API always responses with a string containing a json with a URL for metadata and a URL for data, 
# we implement this functions for calling the URL having the data that we want and returns the result as 
# a json object.
def get_data( response):
    js =  json.loads(response.text)
    datos = requests.request("GET", js['datos'])
    return json.loads(datos.text)

# %%
# get all estaciones
api = '/api/valores/climatologicos/inventarioestaciones/todasestaciones/'
querystring = {"api_key":api_key}
headers = {
    'cache-control': "no-cache"
    }

response = requests.request("GET", url+api, headers=headers, params=querystring)

if response.status_code == 200:
    all_estations = get_data( response)
else:
    print(response)
    
all_estations
# Out:
# [{'latitud': '413515N',
#   'provincia': 'BARCELONA',
#   'altitud': '74',
#   'indicativo': '0252D',
#   'nombre': 'ARENYS DE MAR',
#   'indsinop': '08186',
#   'longitud': '023224E'},
#  {'latitud': '411734N',
#   'provincia': 'BARCELONA',
#   'altitud': '4',
#   'indicativo': '0076',
#   'nombre': 'BARCELONA AEROPUERTO',
#   'indsinop': '08181',
#   'longitud': '020412E'},
#  {'latitud': '412506N',
#   'provincia': 'BARCELONA',
#   'altitud': '408',
#   'indicativo': '0200E',
#   'nombre': 'BARCELONA, FABRA',
#   'indsinop': '',
#   'longitud': '020727E'},
#  {'latitud': '412326N',
#   'provincia': 'BARCELONA',
#   'altitud': '6',
#   'indicativo': '0201D',
#   'nombre': 'BARCELONA',
#   'indsinop': '08180',
#   'longitud': '021200E'},
#  {'latitud': '414312N',
#   'provincia': 'BARCELONA',
#   'altitud': '291',
#   'indicativo': '0149X',
#   'nombre': 'MANRESA',
#   'indsinop': '08174',
#   'longitud': '015025E'},
#  {'latitud': '413125N',
#   'provincia': 'BARCELONA',
#   'altitud': '146',
#   'indicativo': '0229I',
#   'nombre': 'SABADELL AEROPUERTO',
#   'indsinop': '08192',
#   'longitud': '020611E'},
#  {'latitud': '413903N',
#   'provincia': 'BARCELONA',
#   'altitud': '40',
#   'indicativo': '0255B',
#   'nombre': 'SANTA SUSANNA',
#   'indsinop': '08188',
#   'longitud': '024149E'},
#  {'latitud': '415442N',
#   'provincia': 'GIRONA',
#   'altitud': '143',
#   'indicativo': '0367',
#   'nombre': 'GIRONA AEROPUERTO',
#   'indsinop': '08184',
#   'longitud': '024548E'},
#  {'latitud': '415848N',
#   'provincia': 'GIRONA',
#   'altitud': '95',
#   'indicativo': '0370B',
#   'nombre': 'GIRONA, ANTIC INSTITUT',
#   'indsinop': '',
#   'longitud': '024931E'},
#  {'latitud': '420616N',
#   'provincia': 'GIRONA',
#   'altitud': '157',
#   'indicativo': '0372C',
#   'nombre': 'PORQUERES',
#   'indsinop': '08120',
#   'longitud': '024549E'},
#  {'latitud': '421129N',
#   'provincia': 'GIRONA',
#   'altitud': '675',
#   'indicativo': '0324A',
#   'nombre': 'RIPOLL',
#   'indsinop': '08118',
#   'longitud': '021146E'},
#  {'latitud': '410842N',
#   'provincia': 'TARRAGONA',
#   'altitud': '71',
#   'indicativo': '0016A',
#   'nombre': 'REUS AEROPUERTO',
#   'indsinop': '08175',
#   'longitud': '010949E'},
#  {'latitud': '405729N',
#   'provincia': 'TARRAGONA',
#   'altitud': '32',
#   'indicativo': '0002I',
#   'nombre': 'VANDELLÒS  ',
#   'indsinop': '08169',
#   'longitud': '005217E'},
#  {'latitud': '431825N',
#   'provincia': 'A CORUÑA',
#   'altitud': '98',
#   'indicativo': '1387E',
#   'nombre': 'A CORUÑA AEROPUERTO',
#   'indsinop': '08002',
#   'longitud': '082219W'},
#  {'latitud': '432157N',
#   'provincia': 'A CORUÑA',
#   'altitud': '58',
#   'indicativo': '1387',
#   'nombre': 'A CORUÑA',
#   'indsinop': '08001',
#   'longitud': '082517W'},
#  {'latitud': '430938N',
#   'provincia': 'A CORUÑA',
#   'altitud': '50',
#   'indicativo': '1393',
#   'nombre': 'CABO VILÁN',
#   'indsinop': '08006',
#   'longitud': '091239W'},
#  {'latitud': '434710N',
#   'provincia': 'A CORUÑA',
#   'altitud': '80',
#   'indicativo': '1351',
#   'nombre': 'ESTACA DE BARES',
#   'indsinop': '08004',
#   'longitud': '074105W'},
#  {'latitud': '425529N',
#   'provincia': 'A CORUÑA',
#   'altitud': '230',
#   'indicativo': '1400',
#   'nombre': 'FISTERRA',
#   'indsinop': '08040',
#   'longitud': '091729W'},
#  {'latitud': '424314N',
#   'provincia': 'A CORUÑA',
#   'altitud': '685',
#   'indicativo': '1437O',
#   'nombre': 'MONTE IROITE',
#   'indsinop': '08043',
#   'longitud': '085524W'},
#  {'latitud': '424418N',
#   'provincia': 'A CORUÑA',
#   'altitud': '100',
#   'indicativo': '1473A',
#   'nombre': 'PADRÓN',
#   'indsinop': '08039',
#   'longitud': '083738W'},
#  {'latitud': '425317N',
#   'provincia': 'A CORUÑA',
#   'altitud': '370',
#   'indicativo': '1428',
#   'nombre': 'SANTIAGO DE COMPOSTELA AEROPUERTO',
#   'indsinop': '08042',
#   'longitud': '082438W'},
#  {'latitud': '425234N',
#   'provincia': 'A CORUÑA',
#   'altitud': '240',
#   'indicativo': '1475X',
#   'nombre': 'SANTIAGO DE COMPOSTELA',
#   'indsinop': '08041',
#   'longitud': '083321W'},
#  {'latitud': '433401N',
#   'provincia': 'ASTURIAS',
#   'altitud': '127',
#   'indicativo': '1212E',
#   'nombre': 'ASTURIAS AEROPUERTO',
#   'indsinop': '08011',
#   'longitud': '060239W'},
#  {'latitud': '433409N',
#   'provincia': 'ASTURIAS',
#   'altitud': '60',
#   'indicativo': '1283U',
#   'nombre': 'CABO BUSTO',
#   'indsinop': '08010',
#   'longitud': '062812W'},
#  {'latitud': '433921N',
#   'provincia': 'ASTURIAS',
#   'altitud': '100',
#   'indicativo': '1210X',
#   'nombre': 'CABO PEÑAS',
#   'indsinop': '08012',
#   'longitud': '055055W'},
#  {'latitud': '433129N',
#   'provincia': 'ASTURIAS',
#   'altitud': '40',
#   'indicativo': '1331A',
#   'nombre': 'CASTROPOL',
#   'indsinop': '08009',
#   'longitud': '070153W'},
#  {'latitud': '433123N',
#   'provincia': 'ASTURIAS',
#   'altitud': '26',
#   'indicativo': '1207U',
#   'nombre': 'GIJÓN, CAMPUS',
#   'indsinop': '08014',
#   'longitud': '053716W'},
#  {'latitud': '433230N',
#   'provincia': 'ASTURIAS',
#   'altitud': '22',
#   'indicativo': '1208A',
#   'nombre': 'GIJÓN. LA MERCED',
#   'indsinop': '',
#   'longitud': '053943W'},
#  {'latitud': '433336N',
#   'provincia': 'ASTURIAS',
#   'altitud': '5',
#   'indicativo': '1208H',
#   'nombre': 'GIJÓN, PUERTO',
#   'indsinop': '08014',
#   'longitud': '054203W'},
#  {'latitud': '433220N',
#   'provincia': 'ASTURIAS',
#   'altitud': '3',
#   'indicativo': '1208',
#   'nombre': 'GIJÓN',
#   'indsinop': '',
#   'longitud': '053815W'},
#  {'latitud': '432513N',
#   'provincia': 'ASTURIAS',
#   'altitud': '10',
#   'indicativo': '1183X',
#   'nombre': 'LLANES',
#   'indsinop': '08016',
#   'longitud': '044453W'},
#  {'latitud': '432112N',
#   'provincia': 'ASTURIAS',
#   'altitud': '336',
#   'indicativo': '1249X',
#   'nombre': 'OVIEDO',
#   'indsinop': '08015',
#   'longitud': '055227W'},
#  {'latitud': '432112N',
#   'provincia': 'ASTURIAS',
#   'altitud': '336',
#   'indicativo': '1249I',
#   'nombre': 'OVIEDO',
#   'indsinop': '08015',
#   'longitud': '055227W'},
#  {'latitud': '425843N',
#   'provincia': 'ASTURIAS',
#   'altitud': '1480',
#   'indicativo': '1221D',
#   'nombre': 'PAJARES-VALGRANDE',
#   'indsinop': '08031',
#   'longitud': '054635W'},
#  {'latitud': '425939N',
#   'provincia': 'ASTURIAS',
#   'altitud': '1530',
#   'indicativo': '1542',
#   'nombre': 'PUERTO DE LEITARIEGOS',
#   'indsinop': '08052',
#   'longitud': '062451W'},
#  {'latitud': '431753N',
#   'provincia': 'BIZKAIA',
#   'altitud': '42',
#   'indicativo': '1082',
#   'nombre': 'BILBAO AEROPUERTO',
#   'indsinop': '08025',
#   'longitud': '025423W'},
#  {'latitud': '431212N',
#   'provincia': 'BIZKAIA',
#   'altitud': '208',
#   'indicativo': '1078I',
#   'nombre': 'GÜEÑES',
#   'indsinop': '08035',
#   'longitud': '030617W'},
#  {'latitud': '432237N',
#   'provincia': 'BIZKAIA',
#   'altitud': '12',
#   'indicativo': '1055B',
#   'nombre': 'LEKEITIO',
#   'indsinop': '08024',
#   'longitud': '023037W'},
#  {'latitud': '432714N',
#   'provincia': 'BIZKAIA',
#   'altitud': '93',
#   'indicativo': '1057B',
#   'nombre': 'MACHICHACO',
#   'indsinop': '',
#   'longitud': '024510W'},
#  {'latitud': '432230N',
#   'provincia': 'BIZKAIA',
#   'altitud': '90',
#   'indicativo': '1059X',
#   'nombre': 'PUNTA GALEA',
#   'indsinop': '08059',
#   'longitud': '030118W'},
#  {'latitud': '432341N',
#   'provincia': 'CANTABRIA',
#   'altitud': '45',
#   'indicativo': '1083L',
#   'nombre': 'CASTRO URDIALES',
#   'indsinop': '08020',
#   'longitud': '031402W'},
#  {'latitud': '432336N',
#   'provincia': 'CANTABRIA',
#   'altitud': '38',
#   'indicativo': '1159',
#   'nombre': 'SAN VICENTE DE LA BARQUERA',
#   'indsinop': '08017',
#   'longitud': '042332W'},
#  {'latitud': '432526N',
#   'provincia': 'CANTABRIA',
#   'altitud': '3',
#   'indicativo': '1109',
#   'nombre': 'SANTANDER AEROPUERTO',
#   'indsinop': '08021',
#   'longitud': '034932W'},
#  {'latitud': '432754N',
#   'provincia': 'CANTABRIA',
#   'altitud': '64',
#   'indicativo': '1110',
#   'nombre': 'SANTANDER, CIUDAD',
#   'indsinop': '',
#   'longitud': '034908W'},
#  {'latitud': '432928N',
#   'provincia': 'CANTABRIA',
#   'altitud': '52',
#   'indicativo': '1111',
#   'nombre': 'SANTANDER',
#   'indsinop': '08023',
#   'longitud': '034802W'},
#  {'latitud': '432928N',
#   'provincia': 'CANTABRIA',
#   'altitud': '52',
#   'indicativo': '1111X',
#   'nombre': 'SANTANDER',
#   'indsinop': '08023',
#   'longitud': '034802W'},
#  {'latitud': '431823N',
#   'provincia': 'GIPUZKOA',
#   'altitud': '251',
#   'indicativo': '1024E',
#   'nombre': 'DONOSTIA/SAN SEBASTIÁN, IGUELDO',
#   'indsinop': '08027',
#   'longitud': '020228W'},
#  {'latitud': '431234N',
#   'provincia': 'GIPUZKOA',
#   'altitud': '119',
#   'indicativo': '1050J',
#   'nombre': 'ELGOIBAR',
#   'indsinop': '08036',
#   'longitud': '022448W'},
#  {'latitud': '432125N',
#   'provincia': 'GIPUZKOA',
#   'altitud': '4',
#   'indicativo': '1014',
#   'nombre': 'HONDARRIBIA, MALKARROA',
#   'indsinop': '08029',
#   'longitud': '014732W'},
#  {'latitud': '432125N',
#   'provincia': 'GIPUZKOA',
#   'altitud': '4',
#   'indicativo': '1014A',
#   'nombre': 'SAN SEBASTIÁN AEROPUERTO',
#   'indsinop': '08029',
#   'longitud': '014732W'},
#  {'latitud': '431808N',
#   'provincia': 'GIPUZKOA',
#   'altitud': '28',
#   'indicativo': '1041A',
#   'nombre': 'ZUMAIA',
#   'indsinop': '08026',
#   'longitud': '021504W'},
#  {'latitud': '430448N',
#   'provincia': 'GIPUZKOA',
#   'altitud': '420',
#   'indicativo': '1037Y',
#   'nombre': 'ZUMARRAGA',
#   'indsinop': '08037',
#   'longitud': '021903W'},
#  {'latitud': '423350N',
#   'provincia': 'LEON',
#   'altitud': '534',
#   'indicativo': '1549',
#   'nombre': 'PONFERRADA',
#   'indsinop': '08053',
#   'longitud': '063600W'},
#  {'latitud': '430641N',
#   'provincia': 'LUGO',
#   'altitud': '445',
#   'indicativo': '1505',
#   'nombre': 'LUGO AEROPUERTO',
#   'indsinop': '08008',
#   'longitud': '072727W'},
#  {'latitud': '430809N',
#   'provincia': 'NAVARRA',
#   'altitud': '183',
#   'indicativo': '1002Y',
#   'nombre': 'BAZTAN, IRURITA ',
#   'indsinop': '08030',
#   'longitud': '013235W'},
#  {'latitud': '422022N',
#   'provincia': 'OURENSE',
#   'altitud': '840',
#   'indicativo': '1631E',
#   'nombre': 'A POBRA DE TRIVES',
#   'indsinop': '08051',
#   'longitud': '071657W'},
#  {'latitud': '422517N',
#   'provincia': 'OURENSE',
#   'altitud': '400',
#   'indicativo': '1700X',
#   'nombre': 'O CARBALLIÑO',
#   'indsinop': '08047',
#   'longitud': '080533W'},
#  {'latitud': '421956N',
#   'provincia': 'OURENSE',
#   'altitud': '148',
#   'indicativo': '1690B',
#   'nombre': 'OURENSE,INSTITUTO',
#   'indsinop': '',
#   'longitud': '075152W'},
#  {'latitud': '421931N',
#   'provincia': 'OURENSE',
#   'altitud': '143',
#   'indicativo': '1690A',
#   'nombre': 'OURENSE',
#   'indsinop': '08048',
#   'longitud': '075135W'},
#  {'latitud': '420445N',
#   'provincia': 'OURENSE',
#   'altitud': '616',
#   'indicativo': '1735X',
#   'nombre': 'XINZO DE LIMIA',
#   'indsinop': '08050',
#   'longitud': '074401W'},
#  {'latitud': '422550N',
#   'provincia': 'PONTEVEDRA',
#   'altitud': '19',
#   'indicativo': '1484',
#   'nombre': 'PONTEVEDRA, INSTITUTO',
#   'indsinop': '',
#   'longitud': '083850W'},
#  {'latitud': '422618N',
#   'provincia': 'PONTEVEDRA',
#   'altitud': '108',
#   'indicativo': '1484C',
#   'nombre': 'PONTEVEDRA',
#   'indsinop': '08044',
#   'longitud': '083657W'},
#  {'latitud': '421419N',
#   'provincia': 'PONTEVEDRA',
#   'altitud': '261',
#   'indicativo': '1495',
#   'nombre': 'VIGO AEROPUERTO',
#   'indsinop': '08045',
#   'longitud': '083726W'},
#  {'latitud': '403924N',
#   'provincia': 'AVILA',
#   'altitud': '1143',
#   'indicativo': '2444C',
#   'nombre': 'ÁVILA, AYUNTAMIENTO',
#   'indsinop': '',
#   'longitud': '044201W'},
#  {'latitud': '403933N',
#   'provincia': 'AVILA',
#   'altitud': '1130',
#   'indicativo': '2444',
#   'nombre': 'ÁVILA',
#   'indsinop': '08210',
#   'longitud': '044048W'},
#  {'latitud': '402102N',
#   'provincia': 'AVILA',
#   'altitud': '1525',
#   'indicativo': '2811A',
#   'nombre': 'NAVARREDONDA DE GREDOS',
#   'indsinop': '08206',
#   'longitud': '050835W'},
#  {'latitud': '413957N',
#   'provincia': 'BURGOS',
#   'altitud': '790',
#   'indicativo': '2117D',
#   'nombre': 'ARANDA DE DUERO',
#   'indsinop': '08144',
#   'longitud': '034434W'},
#  {'latitud': '422125N',
#   'provincia': 'BURGOS',
#   'altitud': '891',
#   'indicativo': '2331',
#   'nombre': 'BURGOS AEROPUERTO',
#   'indsinop': '08075',
#   'longitud': '033713W'},
#  {'latitud': '415735N',
#   'provincia': 'BURGOS',
#   'altitud': '1080',
#   'indicativo': '2298',
#   'nombre': 'PALACIOS DE LA SIERRA',
#   'indsinop': '08149',
#   'longitud': '030754W'},
#  {'latitud': '422239N',
#   'provincia': 'LEON',
#   'altitud': '1020',
#   'indicativo': '2737E',
#   'nombre': 'LAGUNAS DE SOMOZA',
#   'indsinop': '08123',
#   'longitud': '061148W'},
#  {'latitud': '423558N',
#   'provincia': 'LEON',
#   'altitud': '912',
#   'indicativo': '2661B',
#   'nombre': 'LEÓN AEROPUERTO',
#   'indsinop': '08055',
#   'longitud': '053837W'},
#  {'latitud': '423518N',
#   'provincia': 'LEON',
#   'altitud': '912',
#   'indicativo': '2661',
#   'nombre': 'LEÓN, VIRGEN DEL CAMINO',
#   'indsinop': '08055',
#   'longitud': '053904W'},
#  {'latitud': '430344N',
#   'provincia': 'LEON',
#   'altitud': '1510',
#   'indicativo': '2630X',
#   'nombre': 'PUERTO DE SAN ISIDRO',
#   'indsinop': '08057',
#   'longitud': '052237W'},
#  {'latitud': '404735N',
#   'provincia': 'MADRID',
#   'altitud': '1894',
#   'indicativo': '2462',
#   'nombre': 'PUERTO DE NAVACERRADA',
#   'indsinop': '08215',
#   'longitud': '040038W'},
#  {'latitud': '415944N',
#   'provincia': 'PALENCIA',
#   'altitud': '874',
#   'indicativo': '2400E',
#   'nombre': 'AUTILLA DEL PINO',
#   'indsinop': '08072',
#   'longitud': '043610W'},
#  {'latitud': '422103N',
#   'provincia': 'PALENCIA',
#   'altitud': '830',
#   'indicativo': '2374X',
#   'nombre': 'CARRIÓN DE LOS CONDES',
#   'indsinop': '08068',
#   'longitud': '043702W'},
#  {'latitud': '425214N',
#   'provincia': 'PALENCIA',
#   'altitud': '1140',
#   'indicativo': '2235U',
#   'nombre': 'CERVERA DE PISUERGA',
#   'indsinop': '08058',
#   'longitud': '043112W'},
#  {'latitud': '420018N',
#   'provincia': 'PALENCIA',
#   'altitud': '750',
#   'indicativo': '2401',
#   'nombre': 'PALENCIA, OBSERVATORIO',
#   'indsinop': '',
#   'longitud': '043145W'},
#  {'latitud': '402118N',
#   'provincia': 'SALAMANCA',
#   'altitud': '1960',
#   'indicativo': '2491C',
#   'nombre': 'LA COVATILLA, ESTACIÓN DE ESQUÍ',
#   'indsinop': '08205',
#   'longitud': '054124W'},
#  {'latitud': '403806N',
#   'provincia': 'SALAMANCA',
#   'altitud': '680',
#   'indicativo': '2946X',
#   'nombre': 'SAELICES EL CHICO',
#   'indsinop': '08195',
#   'longitud': '063600W'},
#  {'latitud': '405734N',
#   'provincia': 'SALAMANCA',
#   'altitud': '790',
#   'indicativo': '2867',
#   'nombre': 'SALAMANCA AEROPUERTO',
#   'indsinop': '08202',
#   'longitud': '052954W'},
#  {'latitud': '405727N',
#   'provincia': 'SALAMANCA',
#   'altitud': '775',
#   'indicativo': '2870',
#   'nombre': 'SALAMANCA',
#   'indsinop': '08201',
#   'longitud': '053944W'},
#  {'latitud': '410041N',
#   'provincia': 'SALAMANCA',
#   'altitud': '769',
#   'indicativo': '2916A',
#   'nombre': 'VITIGUDINO',
#   'indsinop': '08129',
#   'longitud': '062616W'},
#  {'latitud': '411131N',
#   'provincia': 'SEGOVIA',
#   'altitud': '1798',
#   'indicativo': '2150H',
#   'nombre': 'LA PINILLA, ESTACIÓN DE ESQUÍ',
#   'indsinop': '08143',
#   'longitud': '032831W'},
#  {'latitud': '405648N',
#   'provincia': 'SEGOVIA',
#   'altitud': '990',
#   'indicativo': '2465A',
#   'nombre': 'SEGOVIA, INSTITUTO',
#   'indsinop': '',
#   'longitud': '040657W'},
#  {'latitud': '405643N',
#   'provincia': 'SEGOVIA',
#   'altitud': '1005',
#   'indicativo': '2465',
#   'nombre': 'SEGOVIA',
#   'indsinop': '08213',
#   'longitud': '040735W'},
#  {'latitud': '414630N',
#   'provincia': 'SORIA',
#   'altitud': '1082',
#   'indicativo': '2030',
#   'nombre': 'SORIA',
#   'indsinop': '08148',
#   'longitud': '022859W'},
#  {'latitud': '411933N',
#   'provincia': 'VALLADOLID',
#   'altitud': '740',
#   'indicativo': '2503X',
#   'nombre': 'OLMEDO',
#   'indsinop': '08142',
#   'longitud': '044113W'},
#  {'latitud': '414243N',
#   'provincia': 'VALLADOLID',
#   'altitud': '846',
#   'indicativo': '2539',
#   'nombre': 'VALLADOLID AEROPUERTO',
#   'indsinop': '08140',
#   'longitud': '045120W'},
#  {'latitud': '413827N',
#   'provincia': 'VALLADOLID',
#   'altitud': '735',
#   'indicativo': '2422',
#   'nombre': 'VALLADOLID',
#   'indsinop': '08141',
#   'longitud': '044516W'},
#  {'latitud': '420039N',
#   'provincia': 'ZAMORA',
#   'altitud': '715',
#   'indicativo': '2755X',
#   'nombre': 'BENAVENTE',
#   'indsinop': '08056',
#   'longitud': '054000W'},
#  {'latitud': '415629N',
#   'provincia': 'ZAMORA',
#   'altitud': '850',
#   'indicativo': '2775X',
#   'nombre': 'VILLARDECIERVOS',
#   'indsinop': '08125',
#   'longitud': '061647W'},
#  {'latitud': '413056N',
#   'provincia': 'ZAMORA',
#   'altitud': '656',
#   'indicativo': '2614',
#   'nombre': 'ZAMORA',
#   'indsinop': '08130',
#   'longitud': '054407W'},
#  {'latitud': '401719N',
#   'provincia': 'AVILA',
#   'altitud': '630',
#   'indicativo': '3391',
#   'nombre': 'SOTILLO DE LA ADRADA',
#   'indsinop': '08208',
#   'longitud': '043527W'},
#  {'latitud': '392833N',
#   'provincia': 'CACERES',
#   'altitud': '459',
#   'indicativo': '3469',
#   'nombre': 'CÁCERES, CIUDAD',
#   'indsinop': '',
#   'longitud': '062235W'},
#  {'latitud': '392817N',
#   'provincia': 'CACERES',
#   'altitud': '394',
#   'indicativo': '3469A',
#   'nombre': 'CÁCERES',
#   'indsinop': '08261',
#   'longitud': '062020W'},
#  {'latitud': '400013N',
#   'provincia': 'CACERES',
#   'altitud': '313',
#   'indicativo': '3526X',
#   'nombre': 'CORIA',
#   'indsinop': '08251',
#   'longitud': '063327W'},
#  {'latitud': '395645N',
#   'provincia': 'CACERES',
#   'altitud': '269',
#   'indicativo': '3434X',
#   'nombre': 'NAVALMORAL DE LA MATA',
#   'indsinop': '08254',
#   'longitud': '053457W'},
#  {'latitud': '400235N',
#   'provincia': 'CACERES',
#   'altitud': '415',
#   'indicativo': '3519X',
#   'nombre': 'PLASENCIA',
#   'indsinop': '08252',
#   'longitud': '060509W'},
#  {'latitud': '392857N',
#   'provincia': 'CACERES',
#   'altitud': '503',
#   'indicativo': '3463X',
#   'nombre': 'TRUJILLO',
#   'indsinop': '08263',
#   'longitud': '055115W'},
#  {'latitud': '392453N',
#   'provincia': 'CACERES',
#   'altitud': '444',
#   'indicativo': '3576X',
#   'nombre': 'VALENCIA DE ALCÁNTARA',
#   'indsinop': '08260',
#   'longitud': '071352W'},
#  {'latitud': '403149N',
#   'provincia': 'CUENCA',
#   'altitud': '928',
#   'indicativo': '3044X',
#   'nombre': 'CAÑIZARES',
#   'indsinop': '08230',
#   'longitud': '020900W'},
#  {'latitud': '400041N',
#   'provincia': 'CUENCA',
#   'altitud': '808',
#   'indicativo': '3094B',
#   'nombre': 'TARANCÓN',
#   'indsinop': '08277',
#   'longitud': '030117W'},
#  {'latitud': '403933N',
#   'provincia': 'GUADALAJARA',
#   'altitud': '639',
#   'indicativo': '3168C',
#   'nombre': 'GUADALAJARA, EL SERRANILLO',
#   'indsinop': '08226',
#   'longitud': '031024W'},
#  {'latitud': '403805N',
#   'provincia': 'GUADALAJARA',
#   'altitud': '685',
#   'indicativo': '3168A',
#   'nombre': 'GUADALAJARA, INSTITUTO',
#   'indsinop': '',
#   'longitud': '031000W'},
#  {'latitud': '403749N',
#   'provincia': 'GUADALAJARA',
#   'altitud': '721',
#   'indicativo': '3168D',
#   'nombre': 'GUADALAJARA',
#   'indsinop': '08226',
#   'longitud': '030900W'},
#  {'latitud': '405030N',
#   'provincia': 'GUADALAJARA',
#   'altitud': '1062',
#   'indicativo': '3013',
#   'nombre': 'MOLINA DE ARAGÓN',
#   'indsinop': '08232',
#   'longitud': '015244W'},
#  {'latitud': '410511N',
#   'provincia': 'GUADALAJARA',
#   'altitud': '1005',
#   'indicativo': '3130C',
#   'nombre': 'SIGÜENZA',
#   'indsinop': '08150',
#   'longitud': '023705W'},
#  {'latitud': '400402N',
#   'provincia': 'MADRID',
#   'altitud': '540',
#   'indicativo': '3100B',
#   'nombre': 'ARANJUEZ',
#   'indsinop': '08229',
#   'longitud': '033246W'},
#  {'latitud': '410025N',
#   'provincia': 'MADRID',
#   'altitud': '1030',
#   'indicativo': '3110C',
#   'nombre': 'BUITRAGO DEL LOZOYA',
#   'indsinop': '08146',
#   'longitud': '033649W'},
#  {'latitud': '404146N',
#   'provincia': 'MADRID',
#   'altitud': '1004',
#   'indicativo': '3191E',
#   'nombre': 'COLMENAR VIEJO',
#   'indsinop': '08219',
#   'longitud': '034554W'},
#  {'latitud': '401758N',
#   'provincia': 'MADRID',
#   'altitud': '620',
#   'indicativo': '3200',
#   'nombre': 'GETAFE',
#   'indsinop': '08224',
#   'longitud': '034320W'},
#  {'latitud': '402800N',
#   'provincia': 'MADRID',
#   'altitud': '609',
#   'indicativo': '3129',
#   'nombre': 'MADRID AEROPUERTO',
#   'indsinop': '08221',
#   'longitud': '033320W'},
#  {'latitud': '402706N',
#   'provincia': 'MADRID',
#   'altitud': '664',
#   'indicativo': '3194U',
#   'nombre': 'MADRID, CIUDAD UNIVERSITARIA',
#   'indsinop': '08220',
#   'longitud': '034327W'},
#  {'latitud': '402232N',
#   'provincia': 'MADRID',
#   'altitud': '690',
#   'indicativo': '3196',
#   'nombre': 'MADRID, CUATRO VIENTOS',
#   'indsinop': '08223',
#   'longitud': '034710W'},
#  {'latitud': '402443N',
#   'provincia': 'MADRID',
#   'altitud': '667',
#   'indicativo': '3195',
#   'nombre': 'MADRID, RETIRO',
#   'indsinop': '08222',
#   'longitud': '034041W'},
#  {'latitud': '404223N',
#   'provincia': 'MADRID',
#   'altitud': '1532',
#   'indicativo': '3266A',
#   'nombre': 'PUERTO ALTO DEL LEÓN',
#   'indsinop': '08217',
#   'longitud': '040831W'},
#  {'latitud': '402540N',
#   'provincia': 'MADRID',
#   'altitud': '763',
#   'indicativo': '3338',
#   'nombre': 'ROBLEDO DE CHAVELA',
#   'indsinop': '08212',
#   'longitud': '041500W'},
#  {'latitud': '410808N',
#   'provincia': 'MADRID',
#   'altitud': '1450',
#   'indicativo': '3111D',
#   'nombre': 'SOMOSIERRA',
#   'indsinop': '08145',
#   'longitud': '033449W'},
#  {'latitud': '402919N',
#   'provincia': 'MADRID',
#   'altitud': '607',
#   'indicativo': '3175',
#   'nombre': 'TORREJÓN DE ARDOZ',
#   'indsinop': '08227',
#   'longitud': '032637W'},
#  {'latitud': '393249N',
#   'provincia': 'TOLEDO',
#   'altitud': '917',
#   'indicativo': '3298X',
#   'nombre': 'SAN PABLO DE LOS MONTES',
#   'indsinop': '08270',
#   'longitud': '042102W'},
#  {'latitud': '395731N',
#   'provincia': 'TOLEDO',
#   'altitud': '372',
#   'indicativo': '3365A',
#   'nombre': 'TALAVERA DE LA REINA',
#   'indsinop': '08274',
#   'longitud': '045149W'},
#  {'latitud': '395134N',
#   'provincia': 'TOLEDO',
#   'altitud': '540',
#   'indicativo': '3259',
#   'nombre': 'TOLEDO, LORENZANA',
#   'indsinop': '',
#   'longitud': '040132W'},
#  {'latitud': '395305N',
#   'provincia': 'TOLEDO',
#   'altitud': '515',
#   'indicativo': '3260B',
#   'nombre': 'TOLEDO',
#   'indsinop': '08272',
#   'longitud': '040243W'},
#  {'latitud': '385300N',
#   'provincia': 'BADAJOZ',
#   'altitud': '185',
#   'indicativo': '4452',
#   'nombre': 'BADAJOZ AEROPUERTO',
#   'indsinop': '08330',
#   'longitud': '064850W'},
#  {'latitud': '385720N',
#   'provincia': 'BADAJOZ',
#   'altitud': '273',
#   'indicativo': '4358X',
#   'nombre': 'DON BENITO',
#   'indsinop': '08333',
#   'longitud': '055250W'},
#  {'latitud': '391010N',
#   'provincia': 'BADAJOZ',
#   'altitud': '447',
#   'indicativo': '4244X',
#   'nombre': 'HERRERA DEL DUQUE',
#   'indsinop': '08264',
#   'longitud': '050344W'},
#  {'latitud': '381755N',
#   'provincia': 'BADAJOZ',
#   'altitud': '381',
#   'indicativo': '4511C',
#   'nombre': 'JEREZ DE LOS CABALLEROS',
#   'indsinop': '08337',
#   'longitud': '064554W'},
#  {'latitud': '381354N',
#   'provincia': 'BADAJOZ',
#   'altitud': '655',
#   'indicativo': '4386B',
#   'nombre': 'LLERENA',
#   'indsinop': '08336',
#   'longitud': '060101W'},
#  {'latitud': '385457N',
#   'provincia': 'BADAJOZ',
#   'altitud': '228',
#   'indicativo': '4410X',
#   'nombre': 'MÉRIDA',
#   'indsinop': '08331',
#   'longitud': '062308W'},
#  {'latitud': '385916N',
#   'provincia': 'CIUDAD REAL',
#   'altitud': '627',
#   'indicativo': '4121C',
#   'nombre': 'CIUDAD REAL, INSTITUTO',
#   'indsinop': '',
#   'longitud': '035545W'},
#  {'latitud': '385921N',
#   'provincia': 'CIUDAD REAL',
#   'altitud': '628',
#   'indicativo': '4121',
#   'nombre': 'CIUDAD REAL',
#   'indsinop': '08348',
#   'longitud': '035513W'},
#  {'latitud': '390519N',
#   'provincia': 'CIUDAD REAL',
#   'altitud': '486',
#   'indicativo': '4220X',
#   'nombre': 'PUEBLA DE DON RODRIGO',
#   'indsinop': '08271',
#   'longitud': '043659W'},
#  {'latitud': '391009N',
#   'provincia': 'CIUDAD REAL',
#   'altitud': '662',
#   'indicativo': '4103X',
#   'nombre': 'TOMELLOSO',
#   'indsinop': '08276',
#   'longitud': '030027W'},
#  {'latitud': '384502N',
#   'provincia': 'CIUDAD REAL',
#   'altitud': '700',
#   'indicativo': '4147X',
#   'nombre': 'VALDEPEÑAS',
#   'indsinop': '08351',
#   'longitud': '032329W'},
#  {'latitud': '383105N',
#   'provincia': 'CIUDAD REAL',
#   'altitud': '804',
#   'indicativo': '4148',
#   'nombre': 'VISO DEL MARQUÉS',
#   'indsinop': '08345',
#   'longitud': '033400W'},
#  {'latitud': '382955N',
#   'provincia': 'CORDOBA',
#   'altitud': '551',
#   'indicativo': '4267X',
#   'nombre': 'HINOJOSA DEL DUQUE',
#   'indsinop': '08335',
#   'longitud': '050716W'},
#  {'latitud': '392500N',
#   'provincia': 'CUENCA',
#   'altitud': '728',
#   'indicativo': '4090Y',
#   'nombre': 'SAN CLEMENTE',
#   'indsinop': '08256',
#   'longitud': '022514W'},
#  {'latitud': '375207N',
#   'provincia': 'HUELVA',
#   'altitud': '572',
#   'indicativo': '4560Y',
#   'nombre': 'ALAJAR',
#   'indsinop': '08380',
#   'longitud': '064030W'},
#  {'latitud': '371141N',
#   'provincia': 'HUELVA',
#   'altitud': '2',
#   'indicativo': '4549Y',
#   'nombre': 'AYAMONTE',
#   'indsinop': '08381',
#   'longitud': '072342W'},
#  {'latitud': '371642N',
#   'provincia': 'HUELVA',
#   'altitud': '19',
#   'indicativo': '4642E',
#   'nombre': 'HUELVA, RONDA ESTE',
#   'indsinop': '08383',
#   'longitud': '065442W'},
#  {'latitud': '371524N',
#   'provincia': 'HUELVA',
#   'altitud': '17',
#   'indicativo': '4605',
#   'nombre': 'HUELVA',
#   'indsinop': '',
#   'longitud': '065659W'},
#  {'latitud': '392931N',
#   'provincia': 'TOLEDO',
#   'altitud': '690',
#   'indicativo': '4067',
#   'nombre': 'MADRIDEJOS',
#   'indsinop': '08273',
#   'longitud': '033142W'},
#  {'latitud': '393551N',
#   'provincia': 'TOLEDO',
#   'altitud': '691',
#   'indicativo': '4061X',
#   'nombre': 'QUINTANAR DE LA ORDEN',
#   'indsinop': '08275',
#   'longitud': '030249W'},
#  {'latitud': '362959N',
#   'provincia': 'CADIZ',
#   'altitud': '2',
#   'indicativo': '5973',
#   'nombre': 'CÁDIZ',
#   'indsinop': '08452',
#   'longitud': '061528W'},
#  {'latitud': '364538N',
#   'provincia': 'CADIZ',
#   'altitud': '913',
#   'indicativo': '5911A',
#   'nombre': 'GRAZALEMA',
#   'indsinop': '08455',
#   'longitud': '052227W'},
#  {'latitud': '364502N',
#   'provincia': 'CADIZ',
#   'altitud': '27',
#   'indicativo': '5960',
#   'nombre': 'JEREZ DE LA FRONTERA AEROPUERTO',
#   'indsinop': '08451',
#   'longitud': '060321W'},
#  {'latitud': '363820N',
#   'provincia': 'CADIZ',
#   'altitud': '21',
#   'indicativo': '5910',
#   'nombre': 'ROTA, BASE NAVAL',
#   'indsinop': '08449',
#   'longitud': '061957W'},
#  {'latitud': '362756N',
#   'provincia': 'CADIZ',
#   'altitud': '28',
#   'indicativo': '5972X',
#   'nombre': 'SAN FERNANDO',
#   'indsinop': '08453',
#   'longitud': '061220W'},
#  {'latitud': '361444N',
#   'provincia': 'CADIZ',
#   'altitud': '186',
#   'indicativo': '5995B',
#   'nombre': 'VEJER DE LA FRONTERA',
#   'indsinop': '08457',
#   'longitud': '055754W'},
#  {'latitud': '355344N',
#   'provincia': 'CEUTA',
#   'altitud': '200',
#   'indicativo': '5000A',
#   'nombre': 'CEUTA, MONTE HACHO',
#   'indsinop': '',
#   'longitud': '051732W'},
#  {'latitud': '355319N',
#   'provincia': 'CEUTA',
#   'altitud': '87',
#   'indicativo': '5000C',
#   'nombre': 'CEUTA',
#   'indsinop': '60320',
#   'longitud': '052049W'},
#  {'latitud': '375056N',
#   'provincia': 'CORDOBA',
#   'altitud': '90',
#   'indicativo': '5402',
#   'nombre': 'CÓRDOBA AEROPUERTO',
#   'indsinop': '08410',
#   'longitud': '045048W'},
#  {'latitud': '373322N',
#   'provincia': 'CORDOBA',
#   'altitud': '650',
#   'indicativo': '5427X',
#   'nombre': 'DOÑA MENCÍA',
#   'indsinop': '08412',
#   'longitud': '042114W'},
#  {'latitud': '381959N',
#   'provincia': 'CORDOBA',
#   'altitud': '750',
#   'indicativo': '5390Y',
#   'nombre': 'VILLANUEVA DE CÓRDOBA',
#   'indsinop': '08346',
#   'longitud': '043632W'},
#  {'latitud': '373021N',
#   'provincia': 'GRANADA',
#   'altitud': '785',
#   'indicativo': '5047E',
#   'nombre': 'BAZA',
#   'indsinop': '08424',
#   'longitud': '024406W'},
#  {'latitud': '371123N',
#   'provincia': 'GRANADA',
#   'altitud': '567',
#   'indicativo': '5530E',
#   'nombre': 'GRANADA AEROPUERTO',
#   'indsinop': '08419',
#   'longitud': '034722W'},
#  {'latitud': '370814N',
#   'provincia': 'GRANADA',
#   'altitud': '687',
#   'indicativo': '5514',
#   'nombre': 'GRANADA BASE AÉREA',
#   'indsinop': '08420',
#   'longitud': '033753W'},
#  {'latitud': '375140N',
#   'provincia': 'GRANADA',
#   'altitud': '1092',
#   'indicativo': '5051X',
#   'nombre': 'HUÉSCAR',
#   'indsinop': '08423',
#   'longitud': '023910W'},
#  {'latitud': '370940N',
#   'provincia': 'GRANADA',
#   'altitud': '760',
#   'indicativo': '5582A',
#   'nombre': 'LOJA',
#   'indsinop': '08414',
#   'longitud': '040910W'},
#  {'latitud': '370553N',
#   'provincia': 'HUELVA',
#   'altitud': '41',
#   'indicativo': '5860E',
#   'nombre': 'MOGUER, EL ARENOSILLO',
#   'indsinop': '08384',
#   'longitud': '064417W'},
#  {'latitud': '380123N',
#   'provincia': 'JAEN',
#   'altitud': '202',
#   'indicativo': '5298X',
#   'nombre': 'ANDÚJAR',
#   'indsinop': '08347',
#   'longitud': '040348W'},
#  {'latitud': '381853N',
#   'provincia': 'JAEN',
#   'altitud': '580',
#   'indicativo': '5181D',
#   'nombre': 'ARROYO DEL OJANCO',
#   'indsinop': '08352',
#   'longitud': '025323W'},
#  {'latitud': '375457N',
#   'provincia': 'JAEN',
#   'altitud': '782',
#   'indicativo': '5038X',
#   'nombre': 'CAZORLA',
#   'indsinop': '08353',
#   'longitud': '030014W'},
#  {'latitud': '374635N',
#   'provincia': 'JAEN',
#   'altitud': '510',
#   'indicativo': '5270',
#   'nombre': 'JAÉN, INSTITUTO',
#   'indsinop': '',
#   'longitud': '034720W'},
#  {'latitud': '374639N',
#   'provincia': 'JAEN',
#   'altitud': '580',
#   'indicativo': '5270B',
#   'nombre': 'JAÉN',
#   'indsinop': '08417',
#   'longitud': '034832W'},
#  {'latitud': '382040N',
#   'provincia': 'JAEN',
#   'altitud': '770',
#   'indicativo': '5246',
#   'nombre': 'SANTA ELENA',
#   'indsinop': '08350',
#   'longitud': '033207W'},
#  {'latitud': '382921N',
#   'provincia': 'JAEN',
#   'altitud': '862',
#   'indicativo': '5192',
#   'nombre': 'VILLARRODRIGO',
#   'indsinop': '08354',
#   'longitud': '023815W'},
#  {'latitud': '375535N',
#   'provincia': 'SEVILLA',
#   'altitud': '550',
#   'indicativo': '5704B',
#   'nombre': 'CAZALLA DE LA SIERRA',
#   'indsinop': '08392',
#   'longitud': '054611W'},
#  {'latitud': '373058N',
#   'provincia': 'SEVILLA',
#   'altitud': '130',
#   'indicativo': '5641X',
#   'nombre': 'ÉCIJA',
#   'indsinop': '08395',
#   'longitud': '050506W'},
#  {'latitud': '371140N',
#   'provincia': 'SEVILLA',
#   'altitud': '410',
#   'indicativo': '5612B',
#   'nombre': 'LA RODA DE ANDALUCÍA',
#   'indsinop': '08399',
#   'longitud': '044612W'},
#  {'latitud': '370952N',
#   'provincia': 'SEVILLA',
#   'altitud': '87',
#   'indicativo': '5796',
#   'nombre': 'MORÓN DE LA FRONTERA',
#   'indsinop': '08397',
#   'longitud': '053641W'},
#  {'latitud': '372500N',
#   'provincia': 'SEVILLA',
#   'altitud': '34',
#   'indicativo': '5783',
#   'nombre': 'SEVILLA AEROPUERTO',
#   'indsinop': '08391',
#   'longitud': '055245W'},
#  {'latitud': '370829N',
#   'provincia': 'ALMERIA',
#   'altitud': '869',
#   'indicativo': '6302A',
#   'nombre': 'ABLA',
#   'indsinop': '08427',
#   'longitud': '024647W'},
#  {'latitud': '364450N',
#   'provincia': 'ALMERIA',
#   'altitud': '8',
#   'indicativo': '6277B',
#   'nombre': 'ADRA',
#   'indsinop': '08486',
#   'longitud': '030114W'},
#  {'latitud': '355618N',
#   'provincia': 'ALMERIA',
#   'altitud': '15',
#   'indicativo': '6381',
#   'nombre': 'ALBORÁN',
#   'indsinop': '08490',
#   'longitud': '030210W'},
#  {'latitud': '365047N',
#   'provincia': 'ALMERIA',
#   'altitud': '21',
#   'indicativo': '6325O',
#   'nombre': 'ALMERÍA AEROPUERTO',
#   'indsinop': '08487',
#   'longitud': '022125W'},
#  {'latitud': '364952N',
#   'provincia': 'ALMERIA',
#   'altitud': '7',
#   'indicativo': '6297',
#   'nombre': 'ALMERÍA',
#   'indsinop': '',
#   'longitud': '022720W'},
#  {'latitud': '365849N',
#   'provincia': 'ALMERIA',
#   'altitud': '16',
#   'indicativo': '6332X',
#   'nombre': 'CARBONERAS',
#   'indsinop': '08488',
#   'longitud': '015413W'},
#  {'latitud': '372326N',
#   'provincia': 'ALMERIA',
#   'altitud': '300',
#   'indicativo': '6367B',
#   'nombre': 'HUÉRCAL-OVERA',
#   'indsinop': '08428',
#   'longitud': '015637W'},
#  {'latitud': '364113N',
#   'provincia': 'ALMERIA',
#   'altitud': '3',
#   'indicativo': '6293X',
#   'nombre': 'ROQUETAS DE MAR',
#   'indsinop': '08492',
#   'longitud': '024206W'},
#  {'latitud': '360050N',
#   'provincia': 'CADIZ',
#   'altitud': '32',
#   'indicativo': '6001',
#   'nombre': 'TARIFA',
#   'indsinop': '08458',
#   'longitud': '053556W'},
#  {'latitud': '364322N',
#   'provincia': 'GRANADA',
#   'altitud': '12',
#   'indicativo': '6268X',
#   'nombre': 'MOTRIL',
#   'indsinop': '08485',
#   'longitud': '033149W'},
#  {'latitud': '370146N',
#   'provincia': 'MALAGA',
#   'altitud': '408',
#   'indicativo': '6106X',
#   'nombre': 'ANTEQUERA',
#   'indsinop': '08413',
#   'longitud': '044454W'},
#  {'latitud': '362501N',
#   'provincia': 'MALAGA',
#   'altitud': '19',
#   'indicativo': '6058I',
#   'nombre': 'ESTEPONA',
#   'indsinop': '08463',
#   'longitud': '050918W'},
#  {'latitud': '363219N',
#   'provincia': 'MALAGA',
#   'altitud': '8',
#   'indicativo': '6084X',
#   'nombre': 'FUENGIROLA',
#   'indsinop': '08480',
#   'longitud': '043706W'},
#  {'latitud': '363958N',
#   'provincia': 'MALAGA',
#   'altitud': '5',
#   'indicativo': '6155A',
#   'nombre': 'MÁLAGA AEROPUERTO',
#   'indsinop': '08482',
#   'longitud': '042856W'},
#  {'latitud': '364304N',
#   'provincia': 'MALAGA',
#   'altitud': '54',
#   'indicativo': '6156X',
#   'nombre': 'MÁLAGA, CENTRO METEOROLÓGICO',
#   'indsinop': '08481',
#   'longitud': '042854W'},
#  {'latitud': '364300N',
#   'provincia': 'MALAGA',
#   'altitud': '25',
#   'indicativo': '6172O',
#   'nombre': 'MÁLAGA, PUERTO',
#   'indsinop': '08479',
#   'longitud': '042511W'},
#  {'latitud': '364459N',
#   'provincia': 'MALAGA',
#   'altitud': '766',
#   'indicativo': '6032B',
#   'nombre': 'RONDA',
#   'indsinop': '08443',
#   'longitud': '051006W'},
#  {'latitud': '364335N',
#   'provincia': 'MALAGA',
#   'altitud': '3',
#   'indicativo': '6205X',
#   'nombre': 'TORROX',
#   'indsinop': '08484',
#   'longitud': '035726W'},
#  {'latitud': '351635N',
#   'provincia': 'MELILLA',
#   'altitud': '52',
#   'indicativo': '6000A',
#   'nombre': 'MELILLA',
#   'indsinop': '60338',
#   'longitud': '025723W'},
#  {'latitud': '383231N',
#   'provincia': 'ALBACETE',
#   'altitud': '646',
#   'indicativo': '7096B',
#   'nombre': 'HELLÍN',
#   'indsinop': '08355',
#   'longitud': '014211W'},
#  {'latitud': '382359N',
#   'provincia': 'ALICANTE',
#   'altitud': '575',
#   'indicativo': '7247X',
#   'nombre': 'PINOSO ',
#   'indsinop': '08357',
#   'longitud': '010217W'},
#  {'latitud': '372502N',
#   'provincia': 'MURCIA',
#   'altitud': '26',
#   'indicativo': '7002Y',
#   'nombre': 'ÁGUILAS',
#   'indsinop': '08432',
#   'longitud': '013513W'},
#  {'latitud': '375728N',
#   'provincia': 'MURCIA',
#   'altitud': '75',
#   'indicativo': '7228',
#   'nombre': 'ALCANTARILLA, BASE AÉREA',
#   'indsinop': '08429',
#   'longitud': '011343W'},
#  {'latitud': '380609N',
#   'provincia': 'MURCIA',
#   'altitud': '643',
#   'indicativo': '7119B',
#   'nombre': 'CARAVACA DE LA CRUZ',
#   'indsinop': '08365',
#   'longitud': '015238W'},
#  {'latitud': '373604N',
#   'provincia': 'MURCIA',
#   'altitud': '17',
#   'indicativo': '7012C',
#   'nombre': 'CARTAGENA',
#   'indsinop': '08434',
#   'longitud': '005916W'},
#  {'latitud': '381358N',
#   'provincia': 'MURCIA',
#   'altitud': '265',
#   'indicativo': '7145D',
#   'nombre': 'CIEZA',
#   'indsinop': '08363',
#   'longitud': '012250W'},
#  {'latitud': '373917N',
#   'provincia': 'MURCIA',
#   'altitud': '312',
#   'indicativo': '7209',
#   'nombre': 'LORCA',
#   'indsinop': '08426',
#   'longitud': '014114W'},
#  {'latitud': '380007N',
#   'provincia': 'MURCIA',
#   'altitud': '61',
#   'indicativo': '7178I',
#   'nombre': 'MURCIA',
#   'indsinop': '08430',
#   'longitud': '011015W'},
#  {'latitud': '374720N',
#   'provincia': 'MURCIA',
#   'altitud': '4',
#   'indicativo': '7031',
#   'nombre': 'SAN JAVIER AEROPUERTO',
#   'indsinop': '08433',
#   'longitud': '004812W'},
#  {'latitud': '374642N',
#   'provincia': 'MURCIA',
#   'altitud': '4',
#   'indicativo': '7031X',
#   'nombre': 'SAN JAVIER AEROPUERTO',
#   'indsinop': '08433',
#   'longitud': '004821W'},
#  {'latitud': '383606N',
#   'provincia': 'MURCIA',
#   'altitud': '640',
#   'indicativo': '7275C',
#   'nombre': 'YECLA',
#   'indsinop': '08356',
#   'longitud': '010935W'},
#  {'latitud': '385715N',
#   'provincia': 'ALBACETE',
#   'altitud': '702',
#   'indicativo': '8175',
#   'nombre': 'ALBACETE BASE AÉREA',
#   'indsinop': '08280',
#   'longitud': '015123W'},
#  {'latitud': '390020N',
#   'provincia': 'ALBACETE',
#   'altitud': '676',
#   'indicativo': '8178D',
#   'nombre': 'ALBACETE',
#   'indsinop': '08279',
#   'longitud': '015144W'},
#  {'latitud': '385609N',
#   'provincia': 'ALBACETE',
#   'altitud': '880',
#   'indicativo': '8177A',
#   'nombre': 'CHINCHILLA',
#   'indsinop': '08278',
#   'longitud': '013936W'},
#  {'latitud': '382221N',
#   'provincia': 'ALICANTE',
#   'altitud': '81',
#   'indicativo': '8025',
#   'nombre': 'ALICANTE/ALACANT',
#   'indsinop': '08359',
#   'longitud': '002939W'},
#  {'latitud': '381658N',
#   'provincia': 'ALICANTE',
#   'altitud': '43',
#   'indicativo': '8019',
#   'nombre': 'ALICANTE-ELCHE AEROPUERTO',
#   'indsinop': '08360',
#   'longitud': '003415W'},
#  {'latitud': '384701N',
#   'provincia': 'ALICANTE',
#   'altitud': '15',
#   'indicativo': '8050X',
#   'nombre': 'JÁVEA/ XÀBIA',
#   'indsinop': '08370',
#   'longitud': '001004E'},
#  {'latitud': '395921N',
#   'provincia': 'CASTELLON',
#   'altitud': '23',
#   'indicativo': '8501',
#   'nombre': 'CASTELLÓ DE LA PLANA',
#   'indsinop': '',
#   'longitud': '000156W'},
#  {'latitud': '395726N',
#   'provincia': 'CASTELLON',
#   'altitud': '43',
#   'indicativo': '8500A',
#   'nombre': 'CASTELLÓN - ALMASSORA',
#   'indsinop': '08286',
#   'longitud': '000419W'},
#  {'latitud': '402600N',
#   'provincia': 'CASTELLON',
#   'altitud': '1131',
#   'indicativo': '8489X',
#   'nombre': 'VILLAFRANCA DEL CID/VILLAFRANCA',
#   'indsinop': '08241',
#   'longitud': '001521W'},
#  {'latitud': '403315N',
#   'provincia': 'CASTELLON',
#   'altitud': '111',
#   'indicativo': '8523X',
#   'nombre': 'VINARÒS',
#   'indsinop': '08239',
#   'longitud': '002547E'},
#  {'latitud': '400402N',
#   'provincia': 'CUENCA',
#   'altitud': '948',
#   'indicativo': '8096',
#   'nombre': 'CUENCA',
#   'indsinop': '08231',
#   'longitud': '020755W'},
#  {'latitud': '402102N',
#   'provincia': 'TERUEL',
#   'altitud': '900',
#   'indicativo': '8368U',
#   'nombre': 'TERUEL',
#   'indsinop': '08235',
#   'longitud': '010727W'},
#  {'latitud': '385544N',
#   'provincia': 'VALENCIA',
#   'altitud': '5',
#   'indicativo': '8058X',
#   'nombre': 'OLIVA',
#   'indsinop': '08282',
#   'longitud': '000545W'},
#  {'latitud': '391105N',
#   'provincia': 'VALENCIA',
#   'altitud': '12',
#   'indicativo': '8325X',
#   'nombre': 'POLINYÀ DE XÚQUER',
#   'indsinop': '08287',
#   'longitud': '002219W'},
#  {'latitud': '393432N',
#   'provincia': 'VALENCIA',
#   'altitud': '758',
#   'indicativo': '8309X',
#   'nombre': 'UTIEL',
#   'indsinop': '08281',
#   'longitud': '011441W'},
#  {'latitud': '392906N',
#   'provincia': 'VALENCIA',
#   'altitud': '56',
#   'indicativo': '8414A',
#   'nombre': 'VALENCIA AEROPUERTO',
#   'indsinop': '08284',
#   'longitud': '002829W'},
#  {'latitud': '392850N',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'indicativo': '8416Y',
#   'nombre': 'VALÈNCIA, VIVEROS',
#   'indsinop': '08285',
#   'longitud': '002159W'},
#  {'latitud': '392850N',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'indsinop': '08285',
#   'longitud': '002159W'},
#  {'latitud': '390006N',
#   'provincia': 'VALENCIA',
#   'altitud': '88',
#   'indicativo': '8293X',
#   'nombre': 'XÀTIVA',
#   'indsinop': '08290',
#   'longitud': '003125W'},
#  {'latitud': '425255N',
#   'provincia': 'ARABA/ALAVA',
#   'altitud': '513',
#   'indicativo': '9091O',
#   'nombre': 'FORONDA-TXOKIZA',
#   'indsinop': '08080',
#   'longitud': '024406W'},
#  {'latitud': '425059N',
#   'provincia': 'ARABA/ALAVA',
#   'altitud': '521',
#   'indicativo': '9087',
#   'nombre': 'VITORIA AERÓDROMO',
#   'indsinop': '',
#   'longitud': '023922W'},
#  {'latitud': '425219N',
#   'provincia': 'ARABA/ALAVA',
#   'altitud': '513',
#   'indicativo': '9091R',
#   'nombre': 'VITORIA GASTEIZ AEROPUERTO',
#   'indsinop': '08080',
#   'longitud': '024358W'},
#  {'latitud': '422516N',
#   'provincia': 'BURGOS',
#   'altitud': '820',
#   'indicativo': '9111',
#   'nombre': 'BELORADO',
#   'indsinop': '08077',
#   'longitud': '031013W'},
#  {'latitud': '425512N',
#   'provincia': 'BURGOS',
#   'altitud': '580',
#   'indicativo': '9051',
#   'nombre': 'MEDINA DE POMAR',
#   'indsinop': '08063',
#   'longitud': '032858W'},
#  {'latitud': '425931N',
#   'provincia': 'CANTABRIA',
#   'altitud': '870',
#   'indicativo': '9001D',
#   'nombre': 'REINOSA',
#   'indsinop': '08032',
#   'longitud': '040938W'},
#  {'latitud': '424823N',
#   'provincia': 'CANTABRIA',
#   'altitud': '720',
#   'indicativo': '9019B',
#   'nombre': 'VALDERREDIBLE, POLIENTES   ',
#   'indsinop': '08033',
#   'longitud': '035602W'},
#  {'latitud': '402955N',
#   'provincia': 'CASTELLON',
#   'altitud': '1220',
#   'indicativo': '9563X',
#   'nombre': 'CASTELLFORT',
#   'indsinop': '08237',
#   'longitud': '001112W'},
#  {'latitud': '421957N',
#   'provincia': 'GIRONA',
#   'altitud': '1703',
#   'indicativo': '9585',
#   'nombre': 'LA MOLINA',
#   'indsinop': '08117',
#   'longitud': '015622E'},
#  {'latitud': '424232N',
#   'provincia': 'HUESCA',
#   'altitud': '1040',
#   'indicativo': '9208E',
#   'nombre': 'ARAGÜÉS DEL PUERTO',
#   'indsinop': '08095',
#   'longitud': '004023W'},
#  {'latitud': '423748N',
#   'provincia': 'HUESCA',
#   'altitud': '992',
#   'indicativo': '9784P',
#   'nombre': 'BIELSA',
#   'indsinop': '08103',
#   'longitud': '001329E'},
#  {'latitud': '420504N',
#   'provincia': 'HUESCA',
#   'altitud': '546',
#   'indicativo': '9898',
#   'nombre': 'HUESCA, AEROPUERTO',
#   'indsinop': '08094',
#   'longitud': '001932W'},
#  {'latitud': '423444N',
#   'provincia': 'HUESCA',
#   'altitud': '823',
#   'indicativo': '9201K',
#   'nombre': 'JACA',
#   'indsinop': '08091',
#   'longitud': '003249W'},
#  {'latitud': '423736N',
#   'provincia': 'HUESCA',
#   'altitud': '1020',
#   'indicativo': '9814A',
#   'nombre': 'TORLA',
#   'indsinop': '08101',
#   'longitud': '000642W'},
#  {'latitud': '422708N',
#   'provincia': 'LA RIOJA',
#   'altitud': '353',
#   'indicativo': '9170',
#   'nombre': 'LOGROÑO, AEROPUERTO',
#   'indsinop': '08084',
#   'longitud': '021952W'},
#  {'latitud': '422117N',
#   'provincia': 'LLEIDA',
#   'altitud': '677',
#   'indicativo': '9619',
#   'nombre': "LA SEU D'URGELL",
#   'indsinop': '08115',
#   'longitud': '012747E'},
#  {'latitud': '413702N',
#   'provincia': 'LLEIDA',
#   'altitud': '199',
#   'indicativo': '9771',
#   'nombre': 'LLEIDA, OBSERVATORIO',
#   'indsinop': '',
#   'longitud': '003716E'},
#  {'latitud': '413734N',
#   'provincia': 'LLEIDA',
#   'altitud': '185',
#   'indicativo': '9771C',
#   'nombre': 'LLEIDA',
#   'indsinop': '08171',
#   'longitud': '003553E'},
#  {'latitud': '424201N',
#   'provincia': 'LLEIDA',
#   'altitud': '1161',
#   'indicativo': '9990X',
#   'nombre': 'NAUT ARAN, ARTIES ',
#   'indsinop': '08107',
#   'longitud': '005237E'},
#  {'latitud': '421219N',
#   'provincia': 'LLEIDA',
#   'altitud': '807',
#   'indicativo': '9698U',
#   'nombre': 'TALARN',
#   'indsinop': '08112',
#   'longitud': '005155E'},
#  {'latitud': '413902N',
#   'provincia': 'LLEIDA',
#   'altitud': '388',
#   'indicativo': '9720X',
#   'nombre': 'TÀRREGA',
#   'indsinop': '08173',
#   'longitud': '010858E'},
#  {'latitud': '424634N',
#   'provincia': 'NAVARRA',
#   'altitud': '572',
#   'indicativo': '9263X',
#   'nombre': 'ARANGUREN, ILUNDAIN  ',
#   'indsinop': '08089',
#   'longitud': '013157W'},
#  {'latitud': '421155N',
#   'provincia': 'NAVARRA',
#   'altitud': '295',
#   'indicativo': '9294E',
#   'nombre': 'BARDENAS REALES, BASE AÉREA ',
#   'indsinop': '08087',
#   'longitud': '012831W'},
#  {'latitud': '421225N',
#   'provincia': 'NAVARRA',
#   'altitud': '268',
#   'indicativo': '9283X',
#   'nombre': 'CADREITA',
#   'indsinop': '08153',
#   'longitud': '014241W'},
#  {'latitud': '424637N',
#   'provincia': 'NAVARRA',
#   'altitud': '459',
#   'indicativo': '9263D',
#   'nombre': 'PAMPLONA, AEROPUERTO',
#   'indsinop': '08085',
#   'longitud': '013900W'},
#  {'latitud': '424904N',
#   'provincia': 'NAVARRA',
#   'altitud': '450',
#   'indicativo': '9262',
#   'nombre': 'PAMPLONA',
#   'indsinop': '',
#   'longitud': '013818W'},
#  {'latitud': '404913N',
#   'provincia': 'TARRAGONA',
#   'altitud': '50',
#   'indicativo': '9981A',
#   'nombre': 'ESTACIÓN DE TORTOSA (ROQUETES)',
#   'indsinop': '08238',
#   'longitud': '002936E'},
#  {'latitud': '404157N',
#   'provincia': 'TARRAGONA',
#   'altitud': '1',
#   'indicativo': '9987P',
#   'nombre': "SANT JAUME D'ENVEJA",
#   'indsinop': '08240',
#   'longitud': '004836E'},
#  {'latitud': '410329N',
#   'provincia': 'TERUEL',
#   'altitud': '334',
#   'indicativo': '9573X',
#   'nombre': 'ALCAÑIZ',
#   'indsinop': '08164',
#   'longitud': '000830W'},
#  {'latitud': '405154N',
#   'provincia': 'TERUEL',
#   'altitud': '932',
#   'indicativo': '9381',
#   'nombre': 'CALAMOCHA, AERÓDROMO',
#   'indsinop': '',
#   'longitud': '011818W'},
#  {'latitud': '405534N',
#   'provincia': 'TERUEL',
#   'altitud': '890',
#   'indicativo': '9381I',
#   'nombre': 'CALAMOCHA',
#   'indsinop': '08233',
#   'longitud': '011736W'},
#  {'latitud': '405648N',
#   'provincia': 'TERUEL',
#   'altitud': '466',
#   'indicativo': '9569A',
#   'nombre': 'CALANDA',
#   'indsinop': '08166',
#   'longitud': '001416W'},
#  {'latitud': '413121N',
#   'provincia': 'ZARAGOZA',
#   'altitud': '357',
#   'indicativo': '9576C',
#   'nombre': 'BUJARALOZ',
#   'indsinop': '08165',
#   'longitud': '001028W'},
#  {'latitud': '411952N',
#   'provincia': 'ZARAGOZA',
#   'altitud': '582',
#   'indicativo': '9394X',
#   'nombre': 'CALATAYUD',
#   'indsinop': '08156',
#   'longitud': '013843W'},
#  {'latitud': '410652N',
#   'provincia': 'ZARAGOZA',
#   'altitud': '779',
#   'indicativo': '9390',
#   'nombre': 'DAROCA',
#   'indsinop': '08157',
#   'longitud': '012436W'},
#  {'latitud': '422927N',
#   'provincia': 'ZARAGOZA',
#   'altitud': '626',
#   'indicativo': '9244X',
#   'nombre': 'SOS DEL REY CATÓLICO',
#   'indsinop': '08090',
#   'longitud': '011249W'},
#  {'latitud': '413938N',
#   'provincia': 'ZARAGOZA',
#   'altitud': '249',
#   'indicativo': '9434',
#   'nombre': 'ZARAGOZA, AEROPUERTO',
#   'indsinop': '08160',
#   'longitud': '010015W'},
#  {'latitud': '413715N',
#   'provincia': 'ZARAGOZA',
#   'altitud': '254',
#   'indicativo': '9434P',
#   'nombre': 'ZARAGOZA, VALDESPARTERA',
#   'indsinop': '08159',
#   'longitud': '005606W'},
#  {'latitud': '394300N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '57',
#   'indicativo': 'B569X',
#   'nombre': 'CAPDEPERA',
#   'indsinop': '08311',
#   'longitud': '032841E'},
#  {'latitud': '394924N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '490',
#   'indicativo': 'B013X',
#   'nombre': 'ESCORCA, LLUC',
#   'indsinop': '08304',
#   'longitud': '025309E'},
#  {'latitud': '385235N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '6',
#   'indicativo': 'B954',
#   'nombre': 'IBIZA, AEROPUERTO',
#   'indsinop': '08373',
#   'longitud': '012304E'},
#  {'latitud': '395117N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '91',
#   'indicativo': 'B893',
#   'nombre': 'MENORCA, AEROPUERTO',
#   'indsinop': '08314',
#   'longitud': '041256E'},
#  {'latitud': '393339N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '8',
#   'indicativo': 'B278',
#   'nombre': 'PALMA DE MALLORCA, AEROPUERTO',
#   'indsinop': '08306',
#   'longitud': '024412E'},
#  {'latitud': '393319N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '3',
#   'indicativo': 'B228',
#   'nombre': 'PALMA, PUERTO',
#   'indsinop': '08301',
#   'longitud': '023731E'},
#  {'latitud': '393118N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '120',
#   'indicativo': 'B346X',
#   'nombre': 'PORRERES',
#   'indsinop': '08310',
#   'longitud': '030109E'},
#  {'latitud': '392452N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '17',
#   'indicativo': 'B434X',
#   'nombre': 'PORTOCOLOM  ',
#   'indsinop': '08309',
#   'longitud': '031618E'},
#  {'latitud': '394457N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '40',
#   'indicativo': 'B691Y',
#   'nombre': 'SA POBLA',
#   'indsinop': '08312',
#   'longitud': '030100E'},
#  {'latitud': '394406N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '1030',
#   'indicativo': 'B248',
#   'nombre': 'SIERRA DE ALFABIA, BUNYOLA',
#   'indsinop': '08303',
#   'longitud': '024247E'},
#  {'latitud': '282641N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '25',
#   'indicativo': 'C249I',
#   'nombre': 'FUERTEVENTURA AEROPUERTO',
#   'indsinop': '60035',
#   'longitud': '135147W'},
#  {'latitud': '275504N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '32',
#   'indicativo': 'C649I',
#   'nombre': 'GRAN CANARIA AEROPUERTO',
#   'indsinop': '60030',
#   'longitud': '152343W'},
#  {'latitud': '280003N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '10',
#   'indicativo': 'C619I',
#   'nombre': 'LA ALDEA DE SAN NICOLÁS',
#   'indsinop': '60027',
#   'longitud': '154850W'},
#  {'latitud': '285707N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '14',
#   'indicativo': 'C029O',
#   'nombre': 'LANZAROTE AEROPUERTO',
#   'indsinop': '60040',
#   'longitud': '133601W'},
#  {'latitud': '280647N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '15',
#   'indicativo': 'C659M',
#   'nombre': 'LAS PALMAS DE GRAN CANARIA, PL. DE LA FERIA',
#   'indsinop': '60032',
#   'longitud': '152517W'},
#  {'latitud': '280523N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '55',
#   'indicativo': 'C659H',
#   'nombre': 'LAS PALMAS DE GRAN CANARIA, SAN CRISTOBAL',
#   'indsinop': '60029',
#   'longitud': '152458W'},
#  {'latitud': '274409N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '6',
#   'indicativo': 'C689E',
#   'nombre': 'MASPALOMAS',
#   'indsinop': '60037',
#   'longitud': '153545W'},
#  {'latitud': '274859N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '10',
#   'indicativo': 'C629X',
#   'nombre': 'MOGÁN, PUERTO',
#   'indsinop': '60036',
#   'longitud': '154551W'},
#  {'latitud': '280257N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '15',
#   'indicativo': 'C229J',
#   'nombre': 'PÁJARA',
#   'indsinop': '60034',
#   'longitud': '142129W'},
#  {'latitud': '291355N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '10',
#   'indicativo': 'C839I',
#   'nombre': 'TEGUISE',
#   'indsinop': '',
#   'longitud': '133007W'},
#  {'latitud': '281906N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '115',
#   'indicativo': 'C439J',
#   'nombre': 'GÜÍMAR',
#   'indsinop': '60018',
#   'longitud': '162256W'},
#  {'latitud': '274908N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '32',
#   'indicativo': 'C929I',
#   'nombre': 'HIERRO AEROPUERTO',
#   'indsinop': '60001',
#   'longitud': '175320W'},
#  {'latitud': '281832N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '2371',
#   'indicativo': 'C430E',
#   'nombre': 'IZAÑA',
#   'indsinop': '60010',
#   'longitud': '162958W'},
#  {'latitud': '283759N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '33',
#   'indicativo': 'C139E',
#   'nombre': 'LA PALMA AEROPUERTO',
#   'indsinop': '60005',
#   'longitud': '174518W'},
#  {'latitud': '282505N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '25',
#   'indicativo': 'C459Z',
#   'nombre': 'PUERTO DE LA CRUZ',
#   'indsinop': '60012',
#   'longitud': '163253W'},
#  {'latitud': '280523N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '15',
#   'indicativo': 'C329Z',
#   'nombre': 'SAN SEBASTIÁN DE LA GOMERA',
#   'indsinop': '60008',
#   'longitud': '170641W'},
#  {'latitud': '282748N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '35',
#   'indicativo': 'C449C',
#   'nombre': 'STA.CRUZ DE TENERIFE',
#   'indsinop': '60020',
#   'longitud': '161519W'},
#  {'latitud': '283545N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '62',
#   'indicativo': 'C129Z',
#   'nombre': 'TAZACORTE',
#   'indsinop': '60004',
#   'longitud': '175455W'},
#  {'latitud': '282839N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '632',
#   'indicativo': 'C447A',
#   'nombre': 'TENERIFE NORTE AEROPUERTO',
#   'indsinop': '60015',
#   'longitud': '161946W'},
#  {'latitud': '280249N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '64',
#   'indicativo': 'C429I',
#   'nombre': 'TENERIFE SUR AEROPUERTO',
#   'indsinop': '60025',
#   'longitud': '163340W'}]

# %%
# get all the IDEMA codes

api = '/api/observacion/convencional/todas'

response = requests.request("GET", url+api, headers=headers, params=querystring)

if response.status_code == 200:
    all_observatories = get_data( response)
else:
    print(response)
    
all_observatories
# Out:
# [{'idema': '0009X',
#   'lon': 0.963335,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 406.0,
#   'vmax': 3.6,
#   'vv': 1.8,
#   'dv': 261.0,
#   'lat': 41.213894,
#   'dmax': 240.0,
#   'ubi': 'ALFORJA',
#   'hr': 91.0,
#   'tamin': 8.8,
#   'ta': 9.5,
#   'tamax': 9.7},
#  {'idema': '0016A',
#   'lon': 1.178894,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 71.0,
#   'vmax': 6.7,
#   'vv': 3.5,
#   'dv': 330.0,
#   'lat': 41.14972,
#   'dmax': 310.0,
#   'ubi': 'REUS/AEROPUERTO',
#   'pres': 1013.3,
#   'hr': 76.0,
#   'stdvv': 0.2,
#   'ts': 13.4,
#   'pres_nmar': 1022.5,
#   'tamin': 13.1,
#   'ta': 13.1,
#   'tamax': 13.7,
#   'tpr': 8.9,
#   'vis': 25.3,
#   'stddv': 2.0,
#   'inso': 0.0},
#  {'idema': '0034X',
#   'lon': 1.260838,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 233.0,
#   'lat': 41.293053,
#   'ubi': 'VALLS',
#   'hr': 84.0,
#   'tamin': 11.2,
#   'ta': 11.2,
#   'tamax': 12.1},
#  {'idema': '0042Y',
#   'lon': 1.249167,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 55.0,
#   'vmax': 2.1,
#   'vv': 0.9,
#   'dv': 347.0,
#   'lat': 41.123894,
#   'dmax': 342.0,
#   'ubi': 'TARRAGONA  FAC. GEOGRAFIA',
#   'hr': 76.0,
#   'tamin': 14.9,
#   'ta': 14.9,
#   'tamax': 15.4},
#  {'idema': '0061X',
#   'lon': 1.519269,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 632.0,
#   'vmax': 3.5,
#   'vv': 1.2,
#   'dv': 292.0,
#   'lat': 41.417053,
#   'dmax': 307.0,
#   'ubi': 'PONTONS',
#   'hr': 77.0,
#   'tamin': 7.8,
#   'ta': 7.8,
#   'tamax': 10.0},
#  {'idema': '0066X',
#   'lon': 1.676942,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 177.0,
#   'vmax': 1.7,
#   'vv': 0.7,
#   'dv': 6.0,
#   'lat': 41.33028,
#   'dmax': 322.0,
#   'ubi': 'VILAFRANCA DEL PENEDÈS',
#   'hr': 82.0,
#   'tamin': 11.5,
#   'ta': 11.5,
#   'tamax': 12.6},
#  {'idema': '0073X',
#   'lon': 1.852626,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 58.0,
#   'vmax': 0.7,
#   'vv': 0.2,
#   'dv': 259.0,
#   'lat': 41.243786,
#   'dmax': 327.0,
#   'ubi': 'SITGES-VALLCARCA',
#   'hr': 80.0,
#   'tamin': 13.2,
#   'ta': 13.2,
#   'tamax': 13.7},
#  {'idema': '0076',
#   'lon': 2.069995,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 4.0,
#   'vmax': 2.6,
#   'vv': 1.1,
#   'dv': 340.0,
#   'lat': 41.29278,
#   'dmax': 330.0,
#   'ubi': 'BARCELONA/AEROPUERTO',
#   'pres': 1021.7,
#   'hr': 75.0,
#   'stdvv': 0.3,
#   'ts': 14.4,
#   'pres_nmar': 1022.3,
#   'tamin': 16.2,
#   'ta': 16.3,
#   'tamax': 18.3,
#   'tpr': 11.9,
#   'vis': 26.0,
#   'stddv': 107.0,
#   'inso': 0.0},
#  {'idema': '0092X',
#   'lon': 1.857494,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 682.0,
#   'vmax': 5.1,
#   'vv': 0.9,
#   'dv': 73.0,
#   'lat': 42.101387,
#   'dmax': 90.0,
#   'ubi': 'BERGA  INSTITUTO',
#   'hr': 72.0,
#   'tamin': 11.2,
#   'ta': 11.2,
#   'tamax': 11.7},
#  {'idema': '0106X',
#   'lon': 1.872504,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 361.0,
#   'vmax': 3.2,
#   'vv': 1.6,
#   'dv': 345.0,
#   'lat': 41.866386,
#   'dmax': 310.0,
#   'ubi': 'BALSARENY',
#   'hr': 79.0,
#   'tamin': 9.7,
#   'ta': 9.7,
#   'tamax': 11.8},
#  {'idema': '0114X',
#   'lon': 2.026561,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 700.0,
#   'vmax': 2.3,
#   'vv': 1.2,
#   'dv': 333.0,
#   'lat': 42.007057,
#   'dmax': 42.0,
#   'ubi': 'PRATS DE LLUÇANÈS',
#   'hr': 86.0,
#   'tamin': 9.4,
#   'ta': 9.4,
#   'tamax': 12.0},
#  {'idema': '0120X',
#   'lon': 2.09539,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 742.0,
#   'vmax': 2.4,
#   'vv': 0.8,
#   'dv': 79.0,
#   'lat': 41.81328,
#   'dmax': 62.0,
#   'ubi': 'MOIÀ',
#   'hr': 92.0,
#   'tamin': 12.5,
#   'ta': 12.5,
#   'tamax': 12.8},
#  {'idema': '0149X',
#   'lon': 1.84028,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 291.0,
#   'vmax': 3.6,
#   'vv': 1.0,
#   'dv': 263.0,
#   'lat': 41.71988,
#   'dmax': 200.0,
#   'ubi': 'MANRESA',
#   'pres': 988.3,
#   'hr': 70.0,
#   'ts': 11.2,
#   'pres_nmar': 1022.8,
#   'tamin': 14.4,
#   'ta': 14.4,
#   'tamax': 16.1,
#   'tpr': 9.0,
#   'vis': 20.0,
#   'inso': 0.0,
#   'tss5cm': 16.1,
#   'psoltp': 0.0,
#   'pliqt': 0.0},
#  {'idema': '0158X',
#   'lon': 1.839223,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 738.0,
#   'lat': 41.594444,
#   'ubi': 'MONTSERRAT',
#   'hr': 71.0,
#   'tamin': 12.4,
#   'ta': 12.7,
#   'tamax': 12.7},
#  {'idema': '0171X',
#   'lon': 1.617778,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 313.0,
#   'vmax': 2.8,
#   'vv': 1.0,
#   'dv': 278.0,
#   'lat': 41.578888,
#   'dmax': 285.0,
#   'ubi': 'IGUALADA',
#   'hr': 56.0,
#   'tamin': 12.3,
#   'ta': 12.9,
#   'tamax': 15.2,
#   'tpr': 4.3,
#   'rviento': 39.0},
#  {'idema': '0194D',
#   'lon': 1.885,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 647.0,
#   'lat': 41.40819,
#   'ubi': 'CORBERA  PIC D?AGULLES ',
#   'hr': 93.0,
#   'tamin': 11.5,
#   'ta': 12.1,
#   'tamax': 12.1},
#  {'idema': '0201D',
#   'lon': 2.200001,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 6.0,
#   'vmax': 4.8,
#   'vv': 1.4,
#   'dv': 74.0,
#   'lat': 41.390556,
#   'dmax': 96.0,
#   'ubi': 'BARCELONA CMT',
#   'hr': 91.0,
#   'tamin': 17.8,
#   'ta': 17.8,
#   'tamax': 18.3,
#   'tpr': 16.3,
#   'rviento': 110.0},
#  {'idema': '0201X',
#   'lon': 2.173886,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 5.0,
#   'vmax': 2.5,
#   'vv': 0.6,
#   'dv': 108.0,
#   'lat': 41.374996,
#   'dmax': 110.0,
#   'ubi': 'BARCELONA  DRASSANES',
#   'hr': 82.0,
#   'tamin': 18.5,
#   'ta': 18.5,
#   'tamax': 18.7},
#  {'idema': '0222X',
#   'lon': 2.168412,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.4,
#   'alt': 175.0,
#   'vmax': 2.5,
#   'vv': 1.8,
#   'dv': 298.0,
#   'lat': 41.612663,
#   'dmax': 300.0,
#   'ubi': 'CALDES DE MONTBUI',
#   'hr': 89.0,
#   'tamin': 14.4,
#   'ta': 14.4,
#   'tamax': 15.4},
#  {'idema': '0244X',
#   'lon': 2.362637,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 56.0,
#   'vmax': 3.1,
#   'vv': 1.9,
#   'dv': 345.0,
#   'lat': 41.504894,
#   'dmax': 357.0,
#   'ubi': 'VILASSAR DE DALT',
#   'hr': 80.0,
#   'tamin': 16.9,
#   'ta': 17.0,
#   'tamax': 17.2},
#  {'idema': '0252D',
#   'lon': 2.54,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 74.0,
#   'vmax': 3.8,
#   'vv': 1.9,
#   'dv': 12.0,
#   'lat': 41.587223,
#   'dmax': 8.0,
#   'ubi': 'ARENYS DE MAR',
#   'hr': 84.0,
#   'tamin': 15.1,
#   'ta': 15.3,
#   'tamax': 15.7,
#   'tpr': 12.6,
#   'rviento': 70.0},
#  {'idema': '0255B',
#   'lon': 2.696949,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 40.0,
#   'vmax': 3.5,
#   'vv': 1.2,
#   'dv': 52.0,
#   'lat': 41.650833,
#   'dmax': 347.0,
#   'ubi': 'SANTA SUSANA',
#   'hr': 83.0,
#   'tamin': 16.5,
#   'ta': 16.5,
#   'tamax': 17.0,
#   'tpr': 13.6,
#   'rviento': 62.0},
#  {'idema': '0260X',
#   'lon': 2.431023,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 936.0,
#   'lat': 41.760063,
#   'ubi': 'FONTMARTINA',
#   'hr': 83.0,
#   'tamin': 9.4,
#   'ta': 9.4,
#   'tamax': 9.9},
#  {'idema': '0281Y',
#   'lon': 2.805112,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 45.0,
#   'vmax': 6.1,
#   'vv': 4.5,
#   'dv': 7.0,
#   'lat': 41.677055,
#   'dmax': 5.0,
#   'ubi': 'BLANES JARDIN BOTANICO',
#   'hr': 85.0,
#   'tamin': 16.6,
#   'ta': 16.6,
#   'tamax': 16.7},
#  {'idema': '0284X',
#   'lon': 3.030933,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 14.0,
#   'vmax': 3.7,
#   'vv': 1.9,
#   'dv': 272.0,
#   'lat': 41.807816,
#   'dmax': 292.0,
#   'ubi': 'CASTELL PLATJA D?ARO',
#   'hr': 88.0,
#   'tamin': 16.2,
#   'ta': 16.2,
#   'tamax': 16.8},
#  {'idema': '0312X',
#   'lon': 2.364353,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 851.0,
#   'vmax': 0.9,
#   'vv': 0.3,
#   'dv': 292.0,
#   'lat': 42.258446,
#   'dmax': 7.0,
#   'ubi': 'SANT PAU DE SEGURIES',
#   'hr': 96.0,
#   'tamin': 11.0,
#   'ta': 11.0,
#   'tamax': 11.7},
#  {'idema': '0320I',
#   'lon': 2.102774,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 1151.0,
#   'vmax': 4.1,
#   'vv': 2.4,
#   'dv': 316.0,
#   'lat': 42.31688,
#   'dmax': 292.0,
#   'ubi': 'PLANOLES',
#   'hr': 78.0,
#   'tamin': 7.6,
#   'ta': 7.6,
#   'tamax': 8.6},
#  {'idema': '0324A',
#   'lon': 2.196187,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 675.0,
#   'lat': 42.191387,
#   'ubi': 'RIPOLL',
#   'hr': 88.0,
#   'tamin': 8.8,
#   'ta': 8.8,
#   'tamax': 9.9,
#   'tpr': 7.0,
#   'rviento': 0.0},
#  {'idema': '0360X',
#   'lon': 2.551007,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 337.0,
#   'vmax': 0.6,
#   'vv': 0.0,
#   'dv': 90.0,
#   'lat': 42.052837,
#   'dmax': 80.0,
#   'ubi': 'LES PLANES D?HOSTOLES',
#   'hr': 93.0,
#   'tamin': 11.2,
#   'ta': 11.2,
#   'tamax': 12.7},
#  {'idema': '0363X',
#   'lon': 2.513329,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 810.0,
#   'vmax': 1.6,
#   'vv': 0.8,
#   'dv': 356.0,
#   'lat': 41.880833,
#   'dmax': 335.0,
#   'ubi': 'SANT HILARI',
#   'hr': 95.0,
#   'tamin': 8.2,
#   'ta': 8.2,
#   'tamax': 9.1},
#  {'idema': '0367',
#   'lon': 2.763329,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 143.0,
#   'vmax': 3.1,
#   'vv': 2.1,
#   'dv': 330.0,
#   'lat': 41.911667,
#   'dmax': 320.0,
#   'ubi': 'GIRONA/COSTA BRAVA',
#   'pres': 1006.5,
#   'hr': 93.0,
#   'stdvv': 0.3,
#   'ts': 14.7,
#   'pres_nmar': 1021.9,
#   'tamin': 14.5,
#   'ta': 14.7,
#   'tamax': 14.9,
#   'tpr': 13.6,
#   'stddv': 4.0,
#   'inso': 0.0},
#  {'idema': '0370E',
#   'lon': 2.819442,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 76.0,
#   'vmax': 1.7,
#   'vv': 0.0,
#   'dv': 286.0,
#   'lat': 41.972332,
#   'dmax': 315.0,
#   'ubi': 'GIRONA-PARC MIGDIA',
#   'hr': 87.0,
#   'tamin': 15.2,
#   'ta': 15.2,
#   'tamax': 16.4},
#  {'idema': '0372C',
#   'lon': 2.763611,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 157.0,
#   'vmax': 1.9,
#   'vv': 0.9,
#   'dv': 273.0,
#   'lat': 42.104443,
#   'dmax': 268.0,
#   'ubi': 'PORQUERES',
#   'hr': 86.0,
#   'tamin': 14.5,
#   'ta': 14.5,
#   'tamax': 15.5,
#   'tpr': 12.2,
#   'rviento': 30.0},
#  {'idema': '0385X',
#   'lon': 3.201389,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 1.0,
#   'vmax': 4.2,
#   'vv': 2.4,
#   'dv': 339.0,
#   'lat': 42.053886,
#   'dmax': 325.0,
#   'ubi': 'L?ESTARTIT',
#   'hr': 86.0,
#   'tamin': 17.1,
#   'ta': 17.1,
#   'tamax': 17.7},
#  {'idema': '0394X',
#   'lon': 2.471827,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 350.0,
#   'vmax': 0.8,
#   'vv': 0.2,
#   'dv': 130.0,
#   'lat': 42.210556,
#   'dmax': 265.0,
#   'ubi': 'VALL DE BIANYA',
#   'hr': 94.0,
#   'tamin': 12.9,
#   'ta': 12.9,
#   'tamax': 13.7},
#  {'idema': '0411X',
#   'lon': 3.093053,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 2.0,
#   'vmax': 1.8,
#   'vv': 0.8,
#   'dv': 304.0,
#   'lat': 42.224834,
#   'dmax': 285.0,
#   'ubi': 'CASTELLO D?EMPURIES',
#   'hr': 89.0,
#   'tamin': 15.0,
#   'ta': 15.0,
#   'tamax': 15.1},
#  {'idema': '0413A',
#   'lon': 2.75558,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 355.0,
#   'vmax': 1.2,
#   'vv': 0.8,
#   'dv': 278.0,
#   'lat': 42.386925,
#   'dmax': 292.0,
#   'ubi': 'MAÇANET DE CABRENYS',
#   'hr': 91.0,
#   'tamin': 13.0,
#   'ta': 13.0,
#   'tamax': 14.8},
#  {'idema': '0421X',
#   'lon': 3.006114,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 100.0,
#   'vmax': 3.6,
#   'vv': 2.3,
#   'dv': 30.0,
#   'lat': 42.38988,
#   'dmax': 50.0,
#   'ubi': 'ESPOLLA  LES ALBERES',
#   'hr': 82.0,
#   'tamin': 14.3,
#   'ta': 14.3,
#   'tamax': 14.7},
#  {'idema': '0429X',
#   'lon': 2.960328,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 45.0,
#   'vmax': 1.8,
#   'vv': 0.8,
#   'dv': 354.0,
#   'lat': 42.259083,
#   'dmax': 345.0,
#   'ubi': 'FIGUERES  LES ASPRES',
#   'hr': 80.0,
#   'tamin': 17.1,
#   'ta': 17.1,
#   'tamax': 17.4},
#  {'idema': '0433D',
#   'lon': 3.315831,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 76.0,
#   'vv': 2.5,
#   'dv': 267.0,
#   'lat': 42.31904,
#   'ubi': 'EVC_CABO DE CREUS',
#   'pres': 1010.0,
#   'hr': 99.0,
#   'tamin': 16.7,
#   'ta': 16.9,
#   'tamax': 16.9,
#   'tpr': 16.7,
#   'rviento': 87.0},
#  {'idema': '1002Y',
#   'lon': -1.542961,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 183.0,
#   'vmax': 0.3,
#   'vv': 0.0,
#   'dv': 0.0,
#   'lat': 43.135723,
#   'dmax': 188.0,
#   'ubi': 'BAZTÁN  IRURITA',
#   'hr': 91.0,
#   'stdvv': 0.0,
#   'tamin': 6.9,
#   'ta': 6.9,
#   'tamax': 8.3,
#   'tpr': 5.5,
#   'stddv': 0.0},
#  {'idema': '1010X',
#   'lon': -1.675786,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 54.0,
#   'vmax': 0.1,
#   'vv': 0.0,
#   'dv': 161.0,
#   'lat': 43.27869,
#   'dmax': 140.0,
#   'ubi': 'BERA',
#   'hr': 92.0,
#   'tamin': 8.6,
#   'ta': 8.6,
#   'tamax': 9.5},
#  {'idema': '1012P',
#   'lon': -1.796536,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 120.0,
#   'vmax': 1.8,
#   'vv': 0.4,
#   'dv': 55.0,
#   'lat': 43.32641,
#   'dmax': 332.0,
#   'ubi': 'IRUN-LAPIZE',
#   'hr': 79.0,
#   'tamin': 13.5,
#   'ta': 13.5,
#   'tamax': 14.1},
#  {'idema': '1014A',
#   'lon': -1.792116,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 4.0,
#   'vmax': 3.1,
#   'vv': 2.4,
#   'dv': 190.0,
#   'lat': 43.357075,
#   'dmax': 180.0,
#   'ubi': 'SAN SEBASTIÁN/FUENTERRABIA',
#   'pres': 1021.7,
#   'hr': 82.0,
#   'stdvv': 0.2,
#   'ts': 14.1,
#   'pres_nmar': 1022.7,
#   'tamin': 11.9,
#   'ta': 12.0,
#   'tamax': 13.0,
#   'tpr': 9.0,
#   'stddv': 6.0},
#  {'idema': '1021X',
#   'lon': -1.878823,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 165.0,
#   'vmax': 1.8,
#   'vv': 0.5,
#   'dv': 239.0,
#   'lat': 43.213833,
#   'dmax': 135.0,
#   'ubi': 'RENTERIA (PRESA DEL AÑARBE)',
#   'hr': 96.0,
#   'tamin': 10.1,
#   'ta': 10.1,
#   'tamax': 11.1},
#  {'idema': '1025A',
#   'lon': -2.256663,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 255.0,
#   'vmax': 1.3,
#   'vv': 0.6,
#   'dv': 258.0,
#   'lat': 43.015553,
#   'dmax': 125.0,
#   'ubi': 'SEGURA LASTALA',
#   'hr': 85.0,
#   'tamin': 9.0,
#   'ta': 9.0,
#   'tamax': 10.0},
#  {'idema': '1025X',
#   'lon': -2.232037,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 255.0,
#   'vmax': 1.0,
#   'vv': 0.1,
#   'dv': 360.0,
#   'lat': 43.054634,
#   'dmax': 332.0,
#   'ubi': 'ARRIARAN',
#   'hr': 88.0,
#   'tamin': 9.6,
#   'ta': 9.6,
#   'tamax': 11.0},
#  {'idema': '1026X',
#   'lon': -2.184273,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 290.0,
#   'vmax': 1.7,
#   'vv': 0.3,
#   'dv': 27.0,
#   'lat': 43.05816,
#   'dmax': 280.0,
#   'ubi': 'ORDIZIA-ARETA',
#   'hr': 83.0,
#   'tamin': 10.7,
#   'ta': 10.7,
#   'tamax': 11.5},
#  {'idema': '1033X',
#   'lon': -1.950836,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 520.0,
#   'vmax': 0.6,
#   'vv': 0.0,
#   'dv': 327.0,
#   'lat': 43.085,
#   'dmax': 307.0,
#   'ubi': 'ARESO ',
#   'hr': 93.0,
#   'tamin': 8.1,
#   'ta': 8.1,
#   'tamax': 9.0},
#  {'idema': '1037X',
#   'lon': -2.337095,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 460.0,
#   'lat': 43.051796,
#   'ubi': 'LEGAZPIA',
#   'hr': 85.0,
#   'tamin': 8.4,
#   'ta': 8.4,
#   'tamax': 9.3},
#  {'idema': '1038X',
#   'lon': -2.267175,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 180.0,
#   'vmax': 1.8,
#   'vv': 0.6,
#   'dv': 242.0,
#   'lat': 43.172577,
#   'dmax': 237.0,
#   'ubi': 'AZPEITIA-IBAIEDER',
#   'hr': 84.0,
#   'tamin': 10.2,
#   'ta': 10.2,
#   'tamax': 11.4},
#  {'idema': '1041A',
#   'lon': -2.251035,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 28.0,
#   'vmax': 4.2,
#   'vv': 2.9,
#   'dv': 181.0,
#   'lat': 43.30214,
#   'dmax': 179.0,
#   'ubi': 'ZUMAYA FARO',
#   'hr': 91.0,
#   'tamin': 12.3,
#   'ta': 12.4,
#   'tamax': 13.4,
#   'tpr': 11.0,
#   'rviento': 103.0},
#  {'idema': '1044X',
#   'lon': -2.589645,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 617.0,
#   'lat': 43.057835,
#   'ubi': 'ARAMAYONA ECHAGÜEN',
#   'hr': 75.0,
#   'tamin': 9.1,
#   'ta': 9.1,
#   'tamax': 9.4},
#  {'idema': '1048X',
#   'lon': -2.465715,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 308.0,
#   'lat': 43.02505,
#   'ubi': 'ARETXABALETA-EMBALSE URKULU',
#   'hr': 87.0,
#   'tamin': 8.9,
#   'ta': 8.9,
#   'tamax': 10.2},
#  {'idema': '1049N',
#   'lon': -2.495827,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 470.0,
#   'vmax': 1.0,
#   'vv': 0.6,
#   'dv': 210.0,
#   'lat': 43.138332,
#   'dmax': 187.0,
#   'ubi': 'ELGETA',
#   'hr': 89.0,
#   'tamin': 9.3,
#   'ta': 9.3,
#   'tamax': 9.8},
#  {'idema': '1050J',
#   'lon': -2.413218,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 119.0,
#   'vmax': 1.2,
#   'vv': 0.0,
#   'dv': 0.0,
#   'lat': 43.209293,
#   'dmax': 28.0,
#   'ubi': 'ELGOIBAR IBERDROLA',
#   'pres': 1008.3,
#   'hr': 87.0,
#   'pres_nmar': 1022.8,
#   'tamin': 9.6,
#   'ta': 9.6,
#   'tamax': 10.6,
#   'tpr': 7.6,
#   'rviento': 3.0},
#  {'idema': '1052A',
#   'lon': -2.397148,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 150.0,
#   'vmax': 2.1,
#   'vv': 1.1,
#   'dv': 176.0,
#   'lat': 43.31722,
#   'dmax': 172.0,
#   'ubi': 'MUTRIKU-GALDONAMENDI',
#   'hr': 64.0,
#   'tamin': 13.4,
#   'ta': 13.4,
#   'tamax': 13.9},
#  {'idema': '1056K',
#   'lon': -2.671184,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 45.0,
#   'vmax': 2.2,
#   'vv': 1.8,
#   'dv': 245.0,
#   'lat': 43.34239,
#   'dmax': 255.0,
#   'ubi': 'FORUA-GAITOKA',
#   'hr': 92.0,
#   'tamin': 10.8,
#   'ta': 10.8,
#   'tamax': 11.9},
#  {'idema': '1057B',
#   'lon': -2.752762,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 93.0,
#   'vmax': 3.6,
#   'vv': 2.8,
#   'dv': 242.0,
#   'lat': 43.453907,
#   'dmax': 240.0,
#   'ubi': 'MACHICHACO FARO',
#   'hr': 83.0,
#   'tamin': 13.2,
#   'ta': 13.4,
#   'tamax': 13.4},
#  {'idema': '1059X',
#   'lon': -3.021602,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 90.0,
#   'vmax': 2.0,
#   'vv': 1.3,
#   'dv': 167.0,
#   'lat': 43.375088,
#   'dmax': 169.0,
#   'ubi': 'PUNTA GALEA ',
#   'pres': 1012.4,
#   'hr': 93.0,
#   'rviento': 36.0},
#  {'idema': '1060X',
#   'lon': -3.005452,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 240.0,
#   'vmax': 2.1,
#   'vv': 0.0,
#   'dv': 192.0,
#   'lat': 43.05024,
#   'dmax': 247.0,
#   'ubi': 'AMURRIO (INSTITUTO)',
#   'hr': 84.0,
#   'tamin': 9.5,
#   'ta': 9.5,
#   'tamax': 11.4},
#  {'idema': '1064L',
#   'lon': -2.860274,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 270.0,
#   'vmax': 2.6,
#   'vv': 0.5,
#   'dv': 184.0,
#   'lat': 43.096333,
#   'dmax': 197.0,
#   'ubi': 'OROZCO- IBARRA',
#   'hr': 82.0,
#   'tamin': 9.3,
#   'ta': 9.3,
#   'tamax': 10.6},
#  {'idema': '1069Y',
#   'lon': -2.644187,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 747.0,
#   'lat': 43.09923,
#   'ubi': 'URKIOLA (SANTUARIO)',
#   'hr': 78.0,
#   'tamin': 9.0,
#   'ta': 9.2,
#   'tamax': 9.3},
#  {'idema': '1074C',
#   'lon': -2.706153,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 100.0,
#   'vmax': 1.0,
#   'vv': 0.6,
#   'dv': 132.0,
#   'lat': 43.202892,
#   'dmax': 152.0,
#   'ubi': 'AMOREBIETA-SAN MIGUEL DUDEA',
#   'hr': 90.0,
#   'tamin': 10.6,
#   'ta': 10.6,
#   'tamax': 11.7},
#  {'idema': '1078C',
#   'lon': -3.209649,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 210.0,
#   'lat': 43.180576,
#   'ubi': 'BALMASEDA-SALINILLAS',
#   'hr': 85.0,
#   'tamin': 10.2,
#   'ta': 10.2,
#   'tamax': 12.0},
#  {'idema': '1078I',
#   'lon': -3.104777,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 208.0,
#   'vmax': 0.0,
#   'vv': 0.0,
#   'dv': 0.0,
#   'lat': 43.203384,
#   'dmax': 354.0,
#   'ubi': 'GÜEÑES',
#   'pres': 997.6,
#   'hr': 65.0,
#   'pres_nmar': 1022.7,
#   'tamin': 11.0,
#   'ta': 11.1,
#   'tamax': 12.3,
#   'tpr': 4.8,
#   'rviento': 0.0},
#  {'idema': '1082',
#   'lon': -2.906304,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 42.0,
#   'vmax': 2.6,
#   'vv': 1.5,
#   'dv': 80.0,
#   'lat': 43.29795,
#   'dmax': 90.0,
#   'ubi': 'BILBAO/AEROPUERTO',
#   'pres': 1018.2,
#   'hr': 86.0,
#   'stdvv': 0.0,
#   'ts': 10.9,
#   'pres_nmar': 1023.0,
#   'tamin': 10.8,
#   'ta': 10.9,
#   'tamax': 12.1,
#   'tpr': 8.7,
#   'stddv': 5.0,
#   'inso': 0.0},
#  {'idema': '1083B',
#   'lon': -3.168615,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 177.0,
#   'vmax': 0.0,
#   'vv': 0.0,
#   'dv': 83.0,
#   'lat': 43.27972,
#   'dmax': 335.0,
#   'ubi': 'SOPUERTA-JARRALTA',
#   'hr': 91.0,
#   'tamin': 9.9,
#   'ta': 9.9,
#   'tamax': 10.7},
#  {'idema': '1083L',
#   'lon': -3.233884,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 45.0,
#   'vmax': 1.6,
#   'vv': 0.7,
#   'dv': 291.0,
#   'lat': 43.39473,
#   'dmax': 258.0,
#   'ubi': 'CASTRO URDIALES-EDAR',
#   'hr': 91.0,
#   'tamin': 12.6,
#   'ta': 12.8,
#   'tamax': 13.2,
#   'tpr': 11.3,
#   'rviento': 34.0},
#  {'idema': '1089U',
#   'lon': -3.47083,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 80.0,
#   'vmax': 1.0,
#   'vv': 0.4,
#   'dv': 249.0,
#   'lat': 43.255833,
#   'dmax': 292.0,
#   'ubi': 'RAMALES DE LA VICTORIA-ETAP',
#   'hr': 95.0,
#   'tamin': 9.3,
#   'ta': 9.3,
#   'tamax': 10.3},
#  {'idema': '1096X',
#   'lon': -3.469721,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 10.0,
#   'vmax': 2.8,
#   'vv': 0.6,
#   'dv': 148.0,
#   'lat': 43.39667,
#   'dmax': 167.0,
#   'ubi': 'TRETO',
#   'hr': 95.0,
#   'tamin': 11.0,
#   'ta': 11.0,
#   'tamax': 11.6},
#  {'idema': '1109X',
#   'lon': -3.831385,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 3.0,
#   'vmax': 2.1,
#   'vv': 1.3,
#   'dv': 200.0,
#   'lat': 43.42861,
#   'dmax': 200.0,
#   'ubi': 'SANTANDER AEROPUERTO',
#   'pres': 1022.8,
#   'hr': 93.0,
#   'stdvv': 0.2,
#   'ts': 11.1,
#   'pres_nmar': 1023.5,
#   'tamin': 11.2,
#   'ta': 11.5,
#   'tamax': 12.9,
#   'tpr': 10.4,
#   'stddv': 6.0,
#   'inso': 0.0},
#  {'idema': '1111X',
#   'lon': -3.800431,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 52.0,
#   'vmax': 2.7,
#   'vv': 1.9,
#   'dv': 228.0,
#   'lat': 43.491055,
#   'dmax': 238.0,
#   'ubi': 'SANTANDER CMT',
#   'pres': 1015.7,
#   'hr': 94.0,
#   'stdvv': 0.4,
#   'ts': 14.7,
#   'pres_nmar': 1022.7,
#   'tamin': 15.2,
#   'ta': 15.3,
#   'tamax': 15.3,
#   'tpr': 14.3,
#   'vis': 16.3,
#   'stddv': 17.0,
#   'inso': 0.0,
#   'tss5cm': 16.2,
#   'vmaxu': 2.8,
#   'dvu': 223.0,
#   'pacutp': 0.0,
#   'vvu': 1.8,
#   'stdvvu': 0.6,
#   'stddvu': 10.0,
#   'dmaxu': 222.0,
#   'tss20cm': 16.3},
#  {'idema': '1124E',
#   'lon': -3.849351,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 195.7,
#   'vmax': 0.9,
#   'vv': 0.1,
#   'dv': 194.0,
#   'lat': 43.2456,
#   'dmax': 207.0,
#   'ubi': 'VILLACARRIEDO - SANTIBAÑEZ',
#   'hr': 92.0,
#   'tamin': 10.5,
#   'ta': 10.5,
#   'tamax': 11.4},
#  {'idema': '1135C',
#   'lon': -4.214141,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 460.0,
#   'vmax': 1.2,
#   'vv': 0.0,
#   'dv': 191.0,
#   'lat': 43.146942,
#   'dmax': 117.0,
#   'ubi': 'BÁRCENA MAYOR-TORIZ',
#   'hr': 100.0,
#   'tamin': 8.3,
#   'ta': 8.4,
#   'tamax': 8.5},
#  {'idema': '1152C',
#   'lon': -4.048612,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 105.0,
#   'vmax': 1.3,
#   'vv': 0.5,
#   'dv': 126.0,
#   'lat': 43.271942,
#   'dmax': 212.0,
#   'ubi': 'SAN FELICES DE BUELNA-TARRIBA',
#   'hr': 92.0,
#   'tamin': 10.5,
#   'ta': 10.7,
#   'tamax': 11.5},
#  {'idema': '1154H',
#   'lon': -4.027419,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 110.0,
#   'vmax': 4.0,
#   'vv': 3.3,
#   'dv': 232.0,
#   'lat': 43.358517,
#   'dmax': 235.0,
#   'ubi': 'TORRELAVEGA-SIERRAPANDO',
#   'hr': 86.0,
#   'tamin': 12.5,
#   'ta': 12.5,
#   'tamax': 13.5},
#  {'idema': '1159',
#   'lon': -4.392103,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 38.0,
#   'vmax': 3.7,
#   'vv': 2.7,
#   'dv': 207.0,
#   'lat': 43.393456,
#   'dmax': 202.0,
#   'ubi': 'SAN VICENTE  FARO',
#   'pres': 1018.0,
#   'hr': 91.0,
#   'pres_nmar': 1022.7,
#   'tamin': 12.7,
#   'ta': 12.7,
#   'tamax': 13.7,
#   'tpr': 11.2,
#   'rviento': 89.0},
#  {'idema': '1167B',
#   'lon': -4.812779,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 1100.0,
#   'vmax': 1.3,
#   'vv': 0.4,
#   'dv': 267.0,
#   'lat': 43.143894,
#   'dmax': 240.0,
#   'ubi': 'FUENTE DÉ-TELEFÉRICO',
#   'hr': 80.0,
#   'tamin': 8.2,
#   'ta': 8.2,
#   'tamax': 8.3},
#  {'idema': '1174I',
#   'lon': -4.601783,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 250.0,
#   'vmax': 1.3,
#   'vv': 0.0,
#   'dv': 177.0,
#   'lat': 43.18286,
#   'dmax': 127.0,
#   'ubi': 'TAMA',
#   'hr': 72.0,
#   'tamin': 11.3,
#   'ta': 11.3,
#   'tamax': 12.2},
#  {'idema': '1176A',
#   'lon': -4.668234,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 940.0,
#   'vmax': 2.1,
#   'vv': 0.7,
#   'dv': 182.0,
#   'lat': 43.255714,
#   'dmax': 202.0,
#   'ubi': 'TRESVISO',
#   'hr': 71.0,
#   'tamin': 9.8,
#   'ta': 9.8,
#   'tamax': 10.2},
#  {'idema': '1178Y',
#   'lon': -4.931762,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 953.0,
#   'lat': 43.145374,
#   'ubi': 'SOTO DE VALDEÓN (AUTOMATICA)',
#   'hr': 88.0,
#   'tamin': 8.5,
#   'ta': 8.5,
#   'tamax': 8.7},
#  {'idema': '1179B',
#   'lon': -4.852774,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 458.0,
#   'vmax': 3.2,
#   'vv': 0.2,
#   'dv': 344.0,
#   'lat': 43.31111,
#   'dmax': 250.0,
#   'ubi': 'CARREÑA DE CABRALES',
#   'hr': 84.0,
#   'tamin': 12.4,
#   'ta': 12.5,
#   'tamax': 12.6},
#  {'idema': '1183X',
#   'lon': -4.748056,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 10.0,
#   'vmax': 3.5,
#   'vv': 2.4,
#   'dv': 221.0,
#   'lat': 43.420277,
#   'dmax': 220.0,
#   'ubi': 'LLANES',
#   'pres': 1021.3,
#   'hr': 70.0,
#   'ts': 13.9,
#   'pres_nmar': 1022.5,
#   'tamin': 14.4,
#   'ta': 14.8,
#   'tamax': 14.9,
#   'tpr': 9.4,
#   'vis': 20.0,
#   'inso': 0.0,
#   'tss5cm': 14.9,
#   'psoltp': 0.0,
#   'pliqt': 0.0},
#  {'idema': '1186P',
#   'lon': -5.119247,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 370.0,
#   'vmax': 1.6,
#   'vv': 1.0,
#   'dv': 33.0,
#   'lat': 43.266632,
#   'dmax': 60.0,
#   'ubi': 'AMIEVA  PANIZALES',
#   'hr': 88.0,
#   'tamin': 11.8,
#   'ta': 11.8,
#   'tamax': 12.0},
#  {'idema': '1199X',
#   'lon': -5.396674,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 280.0,
#   'vmax': 1.0,
#   'vv': 0.1,
#   'dv': 351.0,
#   'lat': 43.377834,
#   'dmax': 55.0,
#   'ubi': 'BARGAÉU PILOÑA',
#   'hr': 90.0,
#   'tamin': 12.9,
#   'ta': 12.9,
#   'tamax': 13.5},
#  {'idema': '1203D',
#   'lon': -5.247153,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 30.0,
#   'vmax': 2.1,
#   'vv': 0.8,
#   'dv': 252.0,
#   'lat': 43.49235,
#   'dmax': 250.0,
#   'ubi': 'COLUNGA',
#   'hr': 93.0,
#   'tamin': 14.1,
#   'ta': 14.1,
#   'tamax': 14.5},
#  {'idema': '1207U',
#   'lon': -5.621111,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.6,
#   'alt': 26.0,
#   'vmax': 1.7,
#   'vv': 0.9,
#   'dv': 147.0,
#   'lat': 43.523056,
#   'dmax': 108.0,
#   'ubi': 'GIJÓN-CAMPUS',
#   'pres': 1019.3,
#   'hr': 97.0,
#   'stdvv': 0.2,
#   'ts': 15.7,
#   'pres_nmar': 1023.2,
#   'tamin': 14.5,
#   'ta': 14.5,
#   'tamax': 15.4,
#   'tpr': 14.0,
#   'vis': 3.5,
#   'stddv': 13.0,
#   'inso': 0.0,
#   'tss5cm': 16.5,
#   'pacutp': 0.72,
#   'tss20cm': 16.6},
#  {'idema': '1208H',
#   'lon': -5.700833,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.2,
#   'alt': 5.0,
#   'vmax': 0.9,
#   'vv': 0.2,
#   'dv': 270.0,
#   'lat': 43.559723,
#   'dmax': 277.0,
#   'ubi': 'GIJÓN  MUSEL',
#   'pres': 1021.9,
#   'hr': 96.0,
#   'tamin': 15.6,
#   'ta': 15.9,
#   'tamax': 16.2,
#   'rviento': 7.0},
#  {'idema': '1210X',
#   'lon': -5.848572,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.1,
#   'alt': 100.0,
#   'vmax': 2.7,
#   'vv': 0.9,
#   'dv': 192.0,
#   'lat': 43.655926,
#   'dmax': 265.0,
#   'ubi': 'CABO PEÑAS',
#   'hr': 94.0,
#   'tamin': 15.0,
#   'ta': 15.0,
#   'tamax': 15.4,
#   'tpr': 14.0,
#   'rviento': 55.0},
#  {'idema': '1212E',
#   'lon': -6.044173,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 127.0,
#   'vmax': 3.1,
#   'vv': 1.2,
#   'dv': 170.0,
#   'lat': 43.56694,
#   'dmax': 190.0,
#   'ubi': 'ASTURIAS/AVILÉS',
#   'pres': 1007.1,
#   'hr': 92.0,
#   'stdvv': 0.2,
#   'ts': 15.2,
#   'pres_nmar': 1037.0,
#   'tamin': 14.4,
#   'ta': 14.5,
#   'tamax': 14.7,
#   'tpr': 13.3,
#   'stddv': 5.0,
#   'inso': 0.0},
#  {'idema': '1221D',
#   'lon': -5.776392,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.8,
#   'alt': 1480.0,
#   'vmax': 3.1,
#   'vv': 1.7,
#   'dv': 182.0,
#   'lat': 42.978607,
#   'dmax': 162.0,
#   'ubi': 'PAJARES - VALGRANDE',
#   'hr': 81.0,
#   'tamin': 6.8,
#   'ta': 7.6,
#   'tamax': 7.6,
#   'tpr': 4.5,
#   'rviento': 54.0},
#  {'idema': '1223P',
#   'lon': -5.822748,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.2,
#   'alt': 370.0,
#   'vmax': 2.3,
#   'vv': 0.0,
#   'dv': 353.0,
#   'lat': 43.132706,
#   'dmax': 235.0,
#   'ubi': 'RONZÓN',
#   'hr': 92.0,
#   'tamin': 13.1,
#   'ta': 13.1,
#   'tamax': 13.8},
#  {'idema': '1226X',
#   'lon': -5.476919,
#   'fint': '2021-10-24T20:00:00',
#   'alt': 750.0,
#   'vmax': 1.7,
#   'vv': 0.2,
#   'dv': 117.0,
#   'lat': 43.095177,
#   'dmax': 137.0,
#   'ubi': 'CUEVAS DE FELECHOSA'},
#  {'idema': '1234P',
#   'lon': -5.819274,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.2,
#   'alt': 170.0,
#   'vmax': 1.5,
#   'vv': 0.3,
#   'dv': 290.0,
#   'lat': 43.274883,
#   'dmax': 307.0,
#   'ubi': 'MIERES-BAÍÑA',
#   'hr': 95.0,
#   'tamin': 14.4,
#   'ta': 14.4,
#   'tamax': 14.9},
#  {'idema': '1249X',
#   'lon': -5.873889,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.2,
#   'alt': 336.0,
#   'vmax': 2.0,
#   'vv': 0.9,
#   'dv': 96.0,
#   'lat': 43.353333,
#   'dmax': 73.0,
#   'ubi': 'OVIEDO',
#   'pres': 983.0,
#   'hr': 94.0,
#   'stdvv': 0.2,
#   'ts': 13.3,
#   'pres_nmar': 1023.1,
#   'tamin': 13.7,
#   'ta': 13.7,
#   'tamax': 14.0,
#   'tpr': 12.7,
#   'vis': 12.5,
#   'stddv': 12.0,
#   'inso': 0.0,
#   'tss5cm': 14.4,
#   'pacutp': 0.18,
#   'tss20cm': 14.6},
#  {'idema': '1272B',
#   'lon': -6.386539,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.2,
#   'alt': 280.0,
#   'vmax': 1.7,
#   'vv': 0.6,
#   'dv': 231.0,
#   'lat': 43.290276,
#   'dmax': 315.0,
#   'ubi': 'SOUTU  LA BARCA',
#   'hr': 97.0,
#   'tamin': 12.5,
#   'ta': 12.5,
#   'tamax': 13.2},
#  {'idema': '1276F',
#   'lon': -6.256944,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.2,
#   'alt': 670.0,
#   'vmax': 1.2,
#   'vv': 0.0,
#   'dv': 326.0,
#   'lat': 43.1,
#   'dmax': 275.0,
#   'ubi': 'POLA DE SOMIEDO-DEPURADORA',
#   'hr': 97.0,
#   'tamin': 11.6,
#   'ta': 11.6,
#   'tamax': 12.0},
#  {'idema': '1279X',
#   'lon': -6.230729,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 240.0,
#   'vmax': 1.9,
#   'vv': 0.6,
#   'dv': 339.0,
#   'lat': 43.425,
#   'dmax': 65.0,
#   'ubi': 'CAMUÑO',
#   'hr': 96.0,
#   'tamin': 13.2,
#   'ta': 13.2,
#   'tamax': 13.8},
#  {'idema': '1283U',
#   'lon': -6.469998,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 60.0,
#   'vmax': 5.9,
#   'vv': 4.0,
#   'dv': 161.0,
#   'lat': 43.569164,
#   'dmax': 219.0,
#   'ubi': 'CABO BUSTO',
#   'pres': 1014.5,
#   'hr': 80.0,
#   'ts': 14.1,
#   'pres_nmar': 1021.7,
#   'tamin': 14.6,
#   'ta': 14.6,
#   'tamax': 16.3,
#   'tpr': 11.2,
#   'vis': 20.0,
#   'inso': 0.0,
#   'tss5cm': 15.8,
#   'psoltp': 0.0},
#  {'idema': '1297E',
#   'lon': -7.017618,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 1020.0,
#   'vmax': 2.2,
#   'vv': 0.6,
#   'dv': 343.0,
#   'lat': 42.768578,
#   'dmax': 355.0,
#   'ubi': 'CERVANTES-BAZAL',
#   'hr': 89.0,
#   'tamin': 8.0,
#   'ta': 8.0,
#   'tamax': 8.8},
#  {'idema': '1302F',
#   'lon': -6.472407,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 1.2,
#   'alt': 1310.0,
#   'vmax': 1.0,
#   'vv': 0.4,
#   'dv': 312.0,
#   'lat': 42.95527,
#   'dmax': 62.0,
#   'ubi': 'DEGAÑA  COTO CORTÉS',
#   'hr': 97.0,
#   'tamin': 8.1,
#   'ta': 8.1,
#   'tamax': 8.2},
#  {'idema': '1309C',
#   'lon': -6.884876,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 780.0,
#   'vmax': 2.8,
#   'vv': 0.1,
#   'dv': 255.0,
#   'lat': 43.027412,
#   'dmax': 222.0,
#   'ubi': 'SAN ANTOLIN DE IBIAS-LINARES',
#   'hr': 95.0,
#   'tamin': 9.6,
#   'ta': 9.6,
#   'tamax': 10.1},
#  {'idema': '1327A',
#   'lon': -6.673332,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 410.0,
#   'vmax': 4.9,
#   'vv': 0.7,
#   'dv': 114.0,
#   'lat': 43.465553,
#   'dmax': 192.0,
#   'ubi': 'ONETA',
#   'hr': 89.0,
#   'tamin': 11.9,
#   'ta': 11.9,
#   'tamax': 12.3},
#  {'idema': '1331A',
#   'lon': -7.031388,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 40.0,
#   'vmax': 4.5,
#   'vv': 1.8,
#   'dv': 212.0,
#   'lat': 43.524723,
#   'dmax': 192.0,
#   'ubi': 'CASTROPOL',
#   'hr': 83.0,
#   'tamin': 13.6,
#   'ta': 13.7,
#   'tamax': 14.0,
#   'tpr': 10.9,
#   'rviento': 83.0},
#  {'idema': '1341B',
#   'lon': -7.06098,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 340.0,
#   'vmax': 5.0,
#   'vv': 1.1,
#   'dv': 205.0,
#   'lat': 43.415546,
#   'dmax': 202.0,
#   'ubi': 'OURIA DE TARAMUNDI',
#   'hr': 93.0,
#   'tamin': 11.6,
#   'ta': 11.6,
#   'tamax': 12.3},
#  {'idema': '1342X',
#   'lon': -7.082971,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 43.0,
#   'vmax': 8.3,
#   'vv': 4.7,
#   'dv': 203.0,
#   'lat': 43.540653,
#   'dmax': 195.0,
#   'ubi': 'RIBADEO  VILAFRAMIL',
#   'hr': 77.0,
#   'tamin': 15.7,
#   'ta': 15.8,
#   'tamax': 15.9},
#  {'idema': '1344X',
#   'lon': -7.361736,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 125.0,
#   'lat': 43.43133,
#   'ubi': 'MONDOÑEDO',
#   'hr': 90.0,
#   'tamin': 12.9,
#   'ta': 12.9,
#   'tamax': 13.6},
#  {'idema': '1347T',
#   'lon': -7.357091,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 80.0,
#   'lat': 43.651047,
#   'ubi': 'BURELA',
#   'hr': 85.0,
#   'tamin': 13.6,
#   'ta': 13.9,
#   'tamax': 14.2},
#  {'idema': '1351',
#   'lon': -7.684722,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 80.0,
#   'vmax': 5.7,
#   'vv': 3.9,
#   'dv': 265.0,
#   'lat': 43.78611,
#   'dmax': 259.0,
#   'ubi': 'ESTACA DE BARES',
#   'pres': 1011.0,
#   'hr': 81.0,
#   'ts': 16.0,
#   'tamin': 15.2,
#   'ta': 15.4,
#   'tamax': 15.6,
#   'inso': 0.0,
#   'tss5cm': 15.7,
#   'psoltp': 0.0,
#   'pliqt': 0.0},
#  {'idema': '1354C',
#   'lon': -8.262222,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 4.0,
#   'vmax': 3.0,
#   'vv': 1.4,
#   'dv': 200.0,
#   'lat': 43.47639,
#   'dmax': 218.0,
#   'ubi': 'FERROL-LA GRAÑA',
#   'pres': 1021.5,
#   'hr': 91.0,
#   'pres_nmar': 1022.0,
#   'tamin': 14.9,
#   'ta': 15.0,
#   'tamax': 15.4,
#   'tpr': 13.6,
#   'rviento': 35.0},
#  {'idema': '1363X',
#   'lon': -7.861476,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 343.0,
#   'lat': 43.44597,
#   'ubi': 'AS PONTES A AEROSA',
#   'hr': 96.0,
#   'tamin': 12.1,
#   'ta': 12.1,
#   'tamax': 12.7},
#  {'idema': '1387',
#   'lon': -8.421517,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.2,
#   'alt': 58.0,
#   'vmax': 6.7,
#   'vv': 3.3,
#   'dv': 170.0,
#   'lat': 43.36597,
#   'dmax': 228.0,
#   'ubi': 'A CORUÑA',
#   'pres': 1014.8,
#   'hr': 89.0,
#   'stdvv': 0.7,
#   'ts': 15.1,
#   'pres_nmar': 1022.7,
#   'tamin': 15.3,
#   'ta': 15.4,
#   'tamax': 15.8,
#   'tpr': 13.6,
#   'vis': 20.0,
#   'stddv': 17.0,
#   'inso': 0.0,
#   'tss5cm': 16.4,
#   'pacutp': 0.09,
#   'tss20cm': 16.8},
#  {'idema': '1387D',
#   'lon': -8.4418,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 132.0,
#   'vmax': 4.4,
#   'vv': 2.4,
#   'dv': 163.0,
#   'lat': 43.363308,
#   'dmax': 230.0,
#   'ubi': 'BENS-A CORUÑA',
#   'pres': 1006.5,
#   'hr': 92.0,
#   'stdvv': 0.3,
#   'pres_nmar': 1038.3,
#   'tamin': 14.3,
#   'ta': 14.6,
#   'tamax': 14.7,
#   'tpr': 13.4,
#   'stddv': 4.9},
#  {'idema': '1387E',
#   'lon': -8.371975,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.4,
#   'alt': 98.0,
#   'vmax': 5.1,
#   'vv': 1.5,
#   'dv': 150.0,
#   'lat': 43.306953,
#   'dmax': 210.0,
#   'ubi': 'A CORUÑA/ALVEDRO',
#   'pres': 1010.4,
#   'hr': 94.0,
#   'stdvv': 0.0,
#   'ts': 14.2,
#   'pres_nmar': 1022.8,
#   'tamin': 14.3,
#   'ta': 14.3,
#   'tamax': 15.1,
#   'tpr': 13.4,
#   'vis': 4.7,
#   'stddv': 7.0,
#   'inso': 0.0},
#  {'idema': '1390X',
#   'lon': -8.711001,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 98.0,
#   'lat': 43.203583,
#   'ubi': 'CARBALLO',
#   'hr': 97.0,
#   'tamin': 14.4,
#   'ta': 14.4,
#   'tamax': 14.6},
#  {'idema': '1393',
#   'lon': -9.210829,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 50.0,
#   'vmax': 4.6,
#   'vv': 3.5,
#   'dv': 192.0,
#   'lat': 43.160557,
#   'dmax': 200.0,
#   'ubi': 'CABO VILAN',
#   'hr': 87.0,
#   'tamin': 14.2,
#   'ta': 14.2,
#   'tamax': 14.5,
#   'tpr': 12.1,
#   'rviento': 130.0},
#  {'idema': '1399',
#   'lon': -9.046929,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 287.0,
#   'lat': 43.057446,
#   'ubi': 'VIMIANZO-CASTRELO',
#   'hr': 100.0,
#   'tamin': 13.2,
#   'ta': 13.2,
#   'tamax': 13.4},
#  {'idema': '1400',
#   'lon': -9.291434,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 230.0,
#   'vmax': 5.7,
#   'vv': 2.8,
#   'dv': 235.0,
#   'lat': 42.924828,
#   'dmax': 218.0,
#   'ubi': 'FISTERRA',
#   'pres': 994.9,
#   'hr': 97.0,
#   'ts': 13.1,
#   'pres_nmar': 1022.3,
#   'tamin': 14.1,
#   'ta': 14.1,
#   'tamax': 14.4,
#   'tpr': 13.7,
#   'vis': 20.0,
#   'inso': 0.0,
#   'tss5cm': 15.0,
#   'psoltp': 0.0,
#   'pliqt': 0.0},
#  {'idema': '1406X',
#   'lon': -8.99369,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 10.4,
#   'alt': 340.0,
#   'lat': 42.93525,
#   'ubi': 'MAZARICOS-A PICOTA',
#   'hr': 98.0,
#   'tamin': 13.1,
#   'ta': 13.1,
#   'tamax': 13.2},
#  {'idema': '1410X',
#   'lon': -8.022249,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 500.0,
#   'lat': 43.037876,
#   'ubi': 'SOBRADO DOS MONXES',
#   'hr': 100.0,
#   'tamin': 9.0,
#   'ta': 9.3,
#   'tamax': 9.4},
#  {'idema': '1428',
#   'lon': -8.410515,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 370.0,
#   'vmax': 3.1,
#   'vv': 2.1,
#   'dv': 180.0,
#   'lat': 42.888012,
#   'dmax': 170.0,
#   'ubi': 'SANTIAGO DE COMPOSTELA/LABACOLLA',
#   'pres': 979.6,
#   'hr': 96.0,
#   'stdvv': 0.2,
#   'ts': 13.3,
#   'pres_nmar': 1023.1,
#   'tamin': 12.7,
#   'ta': 12.7,
#   'tamax': 13.1,
#   'tpr': 12.1,
#   'vis': 12.4,
#   'stddv': 5.0,
#   'inso': 0.0,
#   'tss5cm': 13.3,
#   'tss20cm': 12.8},
#  {'idema': '1435C',
#   'lon': -8.876227,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 128.0,
#   'vmax': 3.4,
#   'vv': 1.7,
#   'dv': 142.0,
#   'lat': 42.80014,
#   'dmax': 135.0,
#   'ubi': 'NOIA',
#   'hr': 97.0,
#   'tamin': 14.0,
#   'ta': 14.1,
#   'tamax': 14.1},
#  {'idema': '1437P',
#   'lon': -8.923611,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 685.0,
#   'vv': 5.9,
#   'dv': 253.0,
#   'lat': 42.720554,
#   'ubi': 'EVC_NOIA',
#   'pres': 944.0,
#   'hr': 99.0,
#   'tamin': 11.3,
#   'ta': 11.3,
#   'tamax': 11.4,
#   'tpr': 11.1,
#   'rviento': 195.0},
#  {'idema': '1442U',
#   'lon': -8.892333,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 10.0,
#   'lat': 42.643887,
#   'ubi': 'BOIRO',
#   'hr': 94.0,
#   'tamin': 14.2,
#   'ta': 14.2,
#   'tamax': 14.3},
#  {'idema': '1446X',
#   'lon': -7.768333,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 680.0,
#   'lat': 42.809723,
#   'ubi': 'MONTERROSO',
#   'hr': 99.0,
#   'tamin': 9.9,
#   'ta': 9.9,
#   'tamax': 10.4},
#  {'idema': '1466A',
#   'lon': -8.257892,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 435.0,
#   'vmax': 4.0,
#   'vv': 2.2,
#   'dv': 123.0,
#   'lat': 42.700886,
#   'dmax': 117.0,
#   'ubi': 'SILLEDA',
#   'hr': 96.0,
#   'tamin': 10.3,
#   'ta': 10.3,
#   'tamax': 11.1},
#  {'idema': '1468X',
#   'lon': -8.501806,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 269.0,
#   'lat': 42.69361,
#   'ubi': 'A ESTRADA',
#   'hr': 98.0,
#   'tamin': 11.2,
#   'ta': 11.2,
#   'tamax': 12.3},
#  {'idema': '1473A',
#   'lon': -8.627222,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 100.0,
#   'vmax': 1.1,
#   'vv': 0.0,
#   'dv': 25.0,
#   'lat': 42.738335,
#   'dmax': 350.0,
#   'ubi': 'PADRÓN',
#   'hr': 94.0,
#   'tamin': 13.0,
#   'ta': 13.1,
#   'tamax': 13.5,
#   'tpr': 12.1,
#   'rviento': 1.0},
#  {'idema': '1475X',
#   'lon': -8.555833,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 240.0,
#   'vmax': 1.8,
#   'vv': 0.2,
#   'dv': 165.0,
#   'lat': 42.87611,
#   'dmax': 134.0,
#   'ubi': 'SANTIAGO DE COMPOSTELA',
#   'hr': 92.0,
#   'tamin': 13.9,
#   'ta': 14.0,
#   'tamax': 14.1,
#   'tpr': 12.7,
#   'rviento': 19.0},
#  {'idema': '1476R',
#   'lon': -8.714807,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 210.0,
#   'lat': 42.749836,
#   'ubi': 'CASAS DO PORTO',
#   'hr': 99.0,
#   'tamin': 13.6,
#   'ta': 13.7,
#   'tamax': 13.7},
#  {'idema': '1477V',
#   'lon': -8.774642,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 32.0,
#   'vmax': 1.5,
#   'vv': 1.0,
#   'dv': 162.0,
#   'lat': 42.584843,
#   'dmax': 82.0,
#   'ubi': 'VILAGARCIA DE AROUSA',
#   'hr': 99.0,
#   'tamin': 13.0,
#   'ta': 13.2,
#   'tamax': 13.3},
#  {'idema': '1484C',
#   'lon': -8.615833,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 108.0,
#   'vmax': 2.2,
#   'vv': 1.3,
#   'dv': 88.0,
#   'lat': 42.43833,
#   'dmax': 103.0,
#   'ubi': 'PONTEVEDRA',
#   'pres': 1008.9,
#   'hr': 96.0,
#   'stdvv': 0.3,
#   'ts': 10.1,
#   'pres_nmar': 1022.5,
#   'tamin': 12.4,
#   'ta': 12.4,
#   'tamax': 12.9,
#   'tpr': 11.8,
#   'vis': 14.9,
#   'stddv': 14.0,
#   'inso': 0.0,
#   'tss5cm': 16.0,
#   'pacutp': 0.0,
#   'tss20cm': 16.8},
#  {'idema': '1489A',
#   'lon': -8.451243,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 395.0,
#   'vmax': 2.1,
#   'vv': 0.7,
#   'dv': 359.0,
#   'lat': 42.40705,
#   'dmax': 342.0,
#   'ubi': 'A LAMA',
#   'hr': 94.0,
#   'tamin': 9.9,
#   'ta': 9.9,
#   'tamax': 10.6},
#  {'idema': '1495',
#   'lon': -8.623765,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 261.0,
#   'vmax': 4.6,
#   'vv': 2.7,
#   'dv': 220.0,
#   'lat': 42.238617,
#   'dmax': 220.0,
#   'ubi': 'VIGO/PEINADOR',
#   'pres': 992.5,
#   'hr': 98.0,
#   'stdvv': 0.4,
#   'ts': 10.8,
#   'pres_nmar': 1023.5,
#   'tamin': 11.3,
#   'ta': 11.3,
#   'tamax': 11.7,
#   'tpr': 11.0,
#   'stddv': 4.0,
#   'inso': 0.0},
#  {'idema': '1496X',
#   'lon': -8.724167,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 120.0,
#   'vmax': 1.6,
#   'vv': 0.4,
#   'dv': 81.0,
#   'lat': 42.230556,
#   'dmax': 127.0,
#   'ubi': 'VIGO-O CASTRO',
#   'hr': 98.0,
#   'tamin': 12.5,
#   'ta': 12.5,
#   'tamax': 12.8},
#  {'idema': '1505',
#   'lon': -7.457222,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 445.0,
#   'vmax': 3.9,
#   'vv': 0.4,
#   'dv': 174.0,
#   'lat': 43.11139,
#   'dmax': 190.0,
#   'ubi': 'LUGO/ROZAS',
#   'pres': 970.7,
#   'hr': 93.0,
#   'stdvv': 0.2,
#   'ts': 8.5,
#   'pres_nmar': 1023.7,
#   'tamin': 10.8,
#   'ta': 10.8,
#   'tamax': 11.4,
#   'tpr': 9.7,
#   'vis': 18.8,
#   'stddv': 78.0,
#   'inso': 0.0,
#   'tss5cm': 13.8,
#   'pacutp': 0.0,
#   'tss20cm': 14.3},
#  {'idema': '1518A',
#   'lon': -7.5525,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 442.0,
#   'vmax': 1.7,
#   'vv': 0.1,
#   'dv': 138.0,
#   'lat': 42.998333,
#   'dmax': 125.0,
#   'ubi': 'LUGO-COL.FINGOI',
#   'hr': 96.0,
#   'tamin': 10.6,
#   'ta': 10.6,
#   'tamax': 11.1},
#  {'idema': '1521I',
#   'lon': -7.499579,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 403.0,
#   'lat': 42.845276,
#   'ubi': 'O PARAMO',
#   'hr': 97.0,
#   'tamin': 10.5,
#   'ta': 10.5,
#   'tamax': 11.6},
#  {'idema': '1521X',
#   'lon': -7.18517,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 1080.0,
#   'vmax': 2.9,
#   'vv': 1.3,
#   'dv': 202.0,
#   'lat': 42.86377,
#   'dmax': 147.0,
#   'ubi': 'BECERREA-PENAMAIOR',
#   'hr': 98.0,
#   'tamin': 7.6,
#   'ta': 7.7,
#   'tamax': 8.1},
#  {'idema': '1535I',
#   'lon': -7.704599,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 552.0,
#   'vv': 0.0,
#   'dv': 179.0,
#   'lat': 42.63472,
#   'ubi': 'EVC_O SAVIÑAO',
#   'pres': 958.0,
#   'hr': 99.0,
#   'tamin': 10.9,
#   'ta': 11.0,
#   'tamax': 11.3,
#   'tpr': 10.9,
#   'rviento': 0.0},
#  {'idema': '1541B',
#   'lon': -6.333886,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.4,
#   'alt': 958.0,
#   'vmax': 1.3,
#   'vv': 0.4,
#   'dv': 113.0,
#   'lat': 42.928886,
#   'dmax': 350.0,
#   'ubi': 'VILLABLINO',
#   'hr': 97.0,
#   'tamin': 9.9,
#   'ta': 9.9,
#   'tamax': 9.9},
#  {'idema': '1542',
#   'lon': -6.414164,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.2,
#   'alt': 1530.0,
#   'vmax': 6.9,
#   'vv': 2.4,
#   'dv': 158.0,
#   'lat': 42.994164,
#   'dmax': 336.0,
#   'ubi': 'PUERTO DE LEITARIEGOS',
#   'pres': 852.9,
#   'hr': 89.0,
#   'ts': 8.8,
#   'tamin': 7.2,
#   'ta': 7.7,
#   'tamax': 7.9,
#   'tpr': 5.9,
#   'vis': 20.0,
#   'inso': 0.0,
#   'tss5cm': 9.1,
#   'geo850': {'value': 1559.1, 'present': True}},
#  {'idema': '1549',
#   'lon': -6.6,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.6,
#   'alt': 534.0,
#   'vmax': 1.7,
#   'vv': 0.7,
#   'dv': 89.0,
#   'lat': 42.56389,
#   'dmax': 205.0,
#   'ubi': 'PONFERRADA',
#   'pres': 960.7,
#   'hr': 89.0,
#   'stdvv': 0.1,
#   'ts': 12.5,
#   'pres_nmar': 1023.5,
#   'tamin': 12.8,
#   'ta': 12.8,
#   'tamax': 13.6,
#   'tpr': 11.0,
#   'vis': 20.0,
#   'stddv': 13.0,
#   'inso': 0.0,
#   'tss5cm': 15.8,
#   'pacutp': 0.37,
#   'tss20cm': 16.2},
#  {'idema': '1561I',
#   'lon': -6.673564,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.4,
#   'alt': 770.0,
#   'lat': 42.76604,
#   'ubi': 'VILLAR DE OTERO (LOS TROBOS)',
#   'hr': 92.0,
#   'tamin': 11.4,
#   'ta': 11.4,
#   'tamax': 11.8},
#  {'idema': '1583X',
#   'lon': -6.99314,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 315.0,
#   'lat': 42.41562,
#   'ubi': 'O BARCO DE VALDEORRAS',
#   'hr': 89.0,
#   'tamin': 13.4,
#   'ta': 13.4,
#   'tamax': 13.6},
#  {'idema': '1631E',
#   'lon': -7.282498,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 840.0,
#   'vmax': 2.3,
#   'vv': 0.4,
#   'dv': 41.0,
#   'lat': 42.339447,
#   'dmax': 95.0,
#   'ubi': 'POBRA DE TRIVES SAN MAMEDE',
#   'pres': 926.4,
#   'hr': 92.0,
#   'ts': 9.3,
#   'tamin': 9.8,
#   'ta': 9.8,
#   'tamax': 10.3,
#   'tpr': 8.5,
#   'inso': 0.0,
#   'tss5cm': 11.0,
#   'psoltp': 0.0,
#   'pliqt': 0.0,
#   'geo925': 852.6},
#  {'idema': '1639X',
#   'lon': -7.383609,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.2,
#   'alt': 990.0,
#   'vmax': 3.4,
#   'vv': 0.6,
#   'dv': 201.0,
#   'lat': 42.260277,
#   'dmax': 172.0,
#   'ubi': 'CHANDREXA DE QUEIXA',
#   'hr': 94.0,
#   'tamin': 9.4,
#   'ta': 9.4,
#   'tamax': 9.7},
#  {'idema': '1679A',
#   'lon': -7.510804,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 291.0,
#   'vmax': 0.1,
#   'vv': 0.0,
#   'dv': 1.0,
#   'lat': 42.53177,
#   'dmax': 2.0,
#   'ubi': 'MONFORTE DE LEMOS',
#   'hr': 92.0,
#   'tamin': 11.9,
#   'ta': 11.9,
#   'tamax': 12.6},
#  {'idema': '1690A',
#   'lon': -7.859722,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 143.0,
#   'vmax': 1.5,
#   'vv': 0.5,
#   'dv': 79.0,
#   'lat': 42.32528,
#   'dmax': 70.0,
#   'ubi': 'OURENSE',
#   'pres': 1005.0,
#   'hr': 93.0,
#   'stdvv': 0.2,
#   'ts': 11.9,
#   'pres_nmar': 1022.9,
#   'tamin': 12.5,
#   'ta': 12.5,
#   'tamax': 13.1,
#   'tpr': 11.4,
#   'vis': 8.8,
#   'stddv': 67.0,
#   'inso': 0.0,
#   'tss5cm': 16.3,
#   'pacutp': 0.0,
#   'tss20cm': 15.6},
#  {'idema': '1696O',
#   'lon': -8.277961,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 610.0,
#   'lat': 42.468056,
#   'ubi': 'BEARIZ',
#   'hr': 99.0,
#   'tamin': 9.9,
#   'ta': 9.9,
#   'tamax': 10.3},
#  {'idema': '1700X',
#   'lon': -8.0925,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 400.0,
#   'vmax': 0.0,
#   'vv': 0.0,
#   'dv': 0.0,
#   'lat': 42.42139,
#   'dmax': 163.0,
#   'ubi': 'O CARBALLIÑO',
#   'hr': 95.0,
#   'tamin': 12.0,
#   'ta': 12.1,
#   'tamax': 12.5,
#   'tpr': 11.3,
#   'rviento': 0.0},
#  {'idema': '1701X',
#   'lon': -8.129121,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 112.0,
#   'vmax': 0.9,
#   'vv': 0.4,
#   'dv': 116.0,
#   'lat': 42.29988,
#   'dmax': 95.0,
#   'ubi': 'RIBADAVIA',
#   'hr': 100.0,
#   'tamin': 12.6,
#   'ta': 12.7,
#   'tamax': 12.7},
#  {'idema': '1706A',
#   'lon': -7.796051,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 492.0,
#   'lat': 42.182903,
#   'ubi': 'ALLARIZ-RIMELO',
#   'hr': 89.0,
#   'tamin': 10.3,
#   'ta': 10.3,
#   'tamax': 11.5},
#  {'idema': '1719',
#   'lon': -8.281009,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 560.0,
#   'lat': 42.217995,
#   'ubi': 'A CAÑIZA',
#   'hr': 94.0,
#   'tamin': 9.7,
#   'ta': 9.7,
#   'tamax': 10.7},
#  {'idema': '1723X',
#   'lon': -8.4927,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 90.0,
#   'lat': 42.182224,
#   'ubi': 'PONTEAREAS-CANEDO',
#   'hr': 100.0,
#   'tamin': 10.8,
#   'ta': 11.0,
#   'tamax': 11.2},
#  {'idema': '1730E',
#   'lon': -8.847444,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 55.0,
#   'lat': 41.94398,
#   'ubi': 'O ROSAL',
#   'hr': 94.0,
#   'tamin': 13.9,
#   'ta': 13.9,
#   'tamax': 14.2},
#  {'idema': '1735X',
#   'lon': -7.733611,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 616.0,
#   'vmax': 1.8,
#   'vv': 0.2,
#   'dv': 305.0,
#   'lat': 42.079166,
#   'dmax': 283.0,
#   'ubi': 'XINZO DE LIMIA',
#   'hr': 90.0,
#   'tamin': 8.2,
#   'ta': 8.2,
#   'tamax': 9.9,
#   'tpr': 6.7,
#   'rviento': 22.0},
#  {'idema': '1738U',
#   'lon': -7.988838,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 730.0,
#   'lat': 41.934116,
#   'ubi': 'MUIÑOS-PRADO',
#   'hr': 93.0,
#   'tamin': 10.0,
#   'ta': 10.1,
#   'tamax': 10.2},
#  {'idema': '1740',
#   'lon': -4.12433,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 150.0,
#   'vmax': 2.5,
#   'vv': 1.6,
#   'dv': 208.0,
#   'lat': 43.37724,
#   'dmax': 215.0,
#   'ubi': 'ALTAMIRA',
#   'hr': 85.0,
#   'tamin': 13.2,
#   'ta': 13.4,
#   'tamax': 13.6},
#  {'idema': '2005Y',
#   'lon': -2.782777,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 1197.0,
#   'lat': 41.967773,
#   'ubi': 'VINUESA',
#   'hr': 73.0,
#   'tamin': 3.7,
#   'ta': 3.7,
#   'tamax': 4.5},
#  {'idema': '2017Y',
#   'lon': -2.494163,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 1260.0,
#   'vmax': 4.2,
#   'vv': 2.6,
#   'dv': 358.0,
#   'lat': 41.99583,
#   'dmax': 5.0,
#   'ubi': 'BARRIOMARTIN-EL ROBLEDO',
#   'hr': 70.0,
#   'tamin': 4.7,
#   'ta': 4.8,
#   'tamax': 5.6},
#  {'idema': '2030',
#   'lon': -2.483063,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 1082.0,
#   'vmax': 1.6,
#   'vv': 0.6,
#   'dv': 349.0,
#   'lat': 41.775017,
#   'dmax': 58.0,
#   'ubi': 'SORIA',
#   'pres': 899.2,
#   'hr': 51.0,
#   'stdvv': 0.2,
#   'ts': 5.6,
#   'tamin': 8.5,
#   'ta': 8.5,
#   'tamax': 11.0,
#   'tpr': -1.0,
#   'vis': 2.0,
#   'stddv': 53.0,
#   'inso': 0.0,
#   'tss5cm': 13.9,
#   'pacutp': 0.0,
#   'tss20cm': 14.2,
#   'geo850': {'value': 1545.4, 'present': True}},
#  {'idema': '2044B',
#   'lon': -2.507534,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 1100.0,
#   'vmax': 2.0,
#   'vv': 0.7,
#   'dv': 245.0,
#   'lat': 41.600582,
#   'dmax': 242.0,
#   'ubi': 'LUBIA-CEDER',
#   'hr': 57.0,
#   'tamin': 5.6,
#   'ta': 5.6,
#   'tamax': 8.6},
#  {'idema': '2048A',
#   'lon': -2.420281,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 978.0,
#   'vmax': 1.8,
#   'vv': 1.6,
#   'dv': 61.0,
#   'lat': 41.41944,
#   'dmax': 57.0,
#   'ubi': 'MORON DE ALMAZAN ',
#   'hr': 69.0,
#   'tamin': 2.9,
#   'ta': 2.9,
#   'tamax': 4.7},
#  {'idema': '2059B',
#   'lon': -2.783338,
# ...
#   'ta': 9.8,
#   'tamax': 10.8,
#   'tpr': 9.0,
#   'vis': 7.8,
#   'stddv': 14.0,
#   'inso': 0.0,
#   'tss5cm': 13.7,
#   'pacutp': 0.0,
#   'tss20cm': 14.3},
#  {'idema': '1518A',
#   'lon': -7.5525,
#   'fint': '2021-10-24T21:00:00',
#   'prec': 0.0,
#   'alt': 442.0,
#   'vmax': 2.5,
#   'vv': 0.2,
#   'dv': 130.0,
#   'lat': 42.998333,
#   'dmax': 127.0,
#   'ubi': 'LUGO-COL.FINGOI',
#   'hr': 96.0,
#   'tamin': 10.4,
#   'ta': 10.5,
#   'tamax': 10.8},
#  {'idema': '1521I',
#   'lon': -7.499579,
#   'fint': '2021-10-24T21:00:00',
#   'prec': 0.0,
#   'alt': 403.0,
#   'lat': 42.845276,
#   'ubi': 'O PARAMO',
#   'hr': 98.0,
#   'tamin': 9.3,
#   'ta': 9.3,
#   'tamax': 10.2},
#  {'idema': '1521X',
#   'lon': -7.18517,
#   'fint': '2021-10-24T21:00:00',
#   'prec': 0.0,
#   'alt': 1080.0,
#   'vmax': 4.2,
#   'vv': 1.7,
#   'dv': 217.0,
#   'lat': 42.86377,
#   'dmax': 232.0,
#   'ubi': 'BECERREA-PENAMAIOR',
#   'hr': 98.0,
#   'tamin': 7.7,
#   'ta': 7.7,
#   'tamax': 7.8},
#  {'idema': '1535I',
#   'lon': -7.704599,
#   'fint': '2021-10-24T21:00:00',
#   'prec': 0.0,
#   'alt': 552.0,
#   'vv': 0.0,
#   'dv': 200.0,
#   'lat': 42.63472,
#   'ubi': 'EVC_O SAVIÑAO',
#   'pres': 958.0,
#   'hr': 99.0,
#   'tamin': 10.4,
#   'ta': 10.4,
#   'tamax': 10.9,
#   'tpr': 10.3,
#   'rviento': 0.0},
#  {'idema': '1541B',
#   'lon': -6.333886,
#   'fint': '2021-10-24T21:00:00',
#   'prec': 0.2,
#   'alt': 958.0,
#   'vmax': 1.3,
#   'vv': 0.9,
#   'dv': 349.0,
#   'lat': 42.928886,
#   'dmax': 347.0,
#   'ubi': 'VILLABLINO',
#   'hr': 98.0,
#   'tamin': 9.8,
#   'ta': 9.8,
#   'tamax': 9.9},
#  {'idema': '1542',
#   'lon': -6.414164,
#   'fint': '2021-10-24T21:00:00',
#   'prec': 0.0,
#   'alt': 1530.0,
#   'vmax': 3.3,
#   'vv': 1.2,
#   'dv': 128.0,
#   'lat': 42.994164,
#   'dmax': 150.0,
#   'ubi': 'PUERTO DE LEITARIEGOS',
#   'pres': 852.7,
#   'hr': 94.0,
#   'ts': 8.6,
#   'tamin': 6.9,
#   'ta': 6.9,
#   'tamax': 7.7,
#   'inso': 0.0,
#   'tss5cm': 9.2},
#  {'idema': '1549',
#   'lon': -6.6,
#   'fint': '2021-10-24T21:00:00',
#   'prec': 0.0,
#   'alt': 534.0,
#   'vmax': 1.4,
#   'vv': 0.6,
#   'dv': 334.0,
#   'lat': 42.56389,
#   'dmax': 350.0,
#   'ubi': 'PONFERRADA',
#   'pres': 960.5,
#   'hr': 90.0,
#   'stdvv': 0.2,
#   'ts': 12.3,
#   'pres_nmar': 1023.3,
#   'tamin': 12.5,
#   'ta': 12.5,
#   'tamax': 12.8,
#   'tpr': 10.9,
#   'vis': 20.0,
#   'stddv': 126.0,
#   'inso': 0.0,
#   'tss5cm': 15.6,
#   'pacutp': 0.0,
#   'tss20cm': 16.1},
#  {'idema': '1561I',
#   'lon': -6.673564,
#   'fint': '2021-10-24T21:00:00',
#   'prec': 0.0,
#   'alt': 770.0,
#   'lat': 42.76604,
#   'ubi': 'VILLAR DE OTERO (LOS TROBOS)',
#   'hr': 94.0,
#   'tamin': 11.2,
#   'ta': 11.2,
#   'tamax': 11.4},
#  {'idema': '1583X',
#   'lon': -6.99314,
#   'fint': '2021-10-24T21:00:00',
#   'prec': 0.0,
#   'alt': 315.0,
#   'lat': 42.41562,
#   'ubi': 'O BARCO DE VALDEORRAS',
#   'hr': 89.0,
#   'tamin': 12.5,
#   'ta': 12.5,
#   'tamax': 13.3},
#  {'idema': '1631E',
#   'lon': -7.282498,
#   'fint': '2021-10-24T21:00:00',
#   'prec': 0.0,
#   'alt': 840.0,
#   'vmax': 2.4,
#   'vv': 1.4,
#   'dv': 290.0,
#   'lat': 42.339447,
#   'dmax': 288.0,
#   'ubi': 'POBRA DE TRIVES SAN MAMEDE',
#   'pres': 926.3,
#   'hr': 92.0,
#   'ts': 7.8,
#   'tamin': 8.4,
#   'ta': 8.4,
#   'tamax': 9.8,
#   'tpr': 7.1,
#   'inso': 0.0,
#   'tss5cm': 11.0,
#   'psoltp': 0.0,
#   'pliqt': 0.0,
#   'geo925': 851.6},
#  {'idema': '1639X',
#   'lon': -7.383609,
#   'fint': '2021-10-24T21:00:00',
#   'prec': 0.0,
#   'alt': 990.0,
#   'vmax': 1.7,
#   'vv': 0.1,
#   'dv': 81.0,
#   'lat': 42.260277,
#   'dmax': 290.0,
#   'ubi': 'CHANDREXA DE QUEIXA',
#   'hr': 98.0,
#   'tamin': 8.6,
#   'ta': 8.6,
#   'tamax': 9.3},
#  {'idema': '1679A',
#   'lon': -7.510804,
#   'fint': '2021-10-24T21:00:00',
#   'prec': 0.0,
#   'alt': 291.0,
#   'vmax': 0.0,
#   'vv': 0.0,
#   'dv': 2.0,
#   'lat': 42.53177,
#   'dmax': 2.0,
#   'ubi': 'MONFORTE DE LEMOS',
#   'hr': 95.0,
#   'tamin': 11.4,
#   'ta': 11.5,
#   'tamax': 11.8},
#  {'idema': '1690A',
#   'lon': -7.859722,
#   'fint': '2021-10-24T21:00:00',
#   'prec': 0.0,
#   'alt': 143.0,
#   'vmax': 2.2,
#   'vv': 0.4,
#   'dv': 98.0,
#   'lat': 42.32528,
#   'dmax': 275.0,
#   'ubi': 'OURENSE',
#   'pres': 1005.2,
#   'hr': 93.0,
#   'stdvv': 0.2,
#   'ts': 12.9,
#   'pres_nmar': 1023.1,
#   'tamin': 12.1,
#   'ta': 12.1,
#   'tamax': 12.5,
#   'tpr': 11.0,
#   'vis': 8.7,
#   'stddv': 102.0,
#   'inso': 0.0,
#   'tss5cm': 16.3,
#   'pacutp': 0.0,
#   'tss20cm': 15.5},
#  {'idema': '1696O',
#   'lon': -8.277961,
#   'fint': '2021-10-24T21:00:00',
#   'prec': 0.0,
#   'alt': 610.0,
#   'lat': 42.468056,
#   'ubi': 'BEARIZ',
#   'hr': 100.0,
#   'tamin': 9.5,
#   'ta': 9.5,
#   'tamax': 9.8},
#  {'idema': '1700X',
#   'lon': -8.0925,
#   'fint': '2021-10-24T21:00:00',
#   'prec': 0.0,
#   'alt': 400.0,
#   'vmax': 0.0,
#   'vv': 0.0,
#   'dv': 0.0,
#   'lat': 42.42139,
#   'dmax': 288.0,
#   'ubi': 'O CARBALLIÑO',
#   'hr': 96.0,
#   'tamin': 11.9,
#   'ta': 12.1,
#   'tamax': 12.1,
#   'tpr': 11.4,
#   'rviento': 0.0},
#  {'idema': '1701X',
#   'lon': -8.129121,
#   'fint': '2021-10-24T21:00:00',
#   'prec': 0.0,
#   'alt': 112.0,
#   'vmax': 0.7,
#   'vv': 0.1,
#   'dv': 69.0,
#   'lat': 42.29988,
#   'dmax': 112.0,
#   'ubi': 'RIBADAVIA',
#   'hr': 100.0,
#   'tamin': 12.6,
#   'ta': 12.6,
#   'tamax': 12.7},
#  {'idema': '1706A',
#   'lon': -7.796051,
#   'fint': '2021-10-24T21:00:00',
#   'prec': 0.0,
#   'alt': 492.0,
#   'lat': 42.182903,
#   'ubi': 'ALLARIZ-RIMELO',
#   'hr': 94.0,
#   'tamin': 9.2,
#   'ta': 9.2,
#   'tamax': 10.1},
#  {'idema': '1719',
#   'lon': -8.281009,
#   'fint': '2021-10-24T21:00:00',
#   'prec': 0.0,
#   'alt': 560.0,
#   'lat': 42.217995,
#   'ubi': 'A CAÑIZA',
#   'hr': 99.0,
#   'tamin': 9.2,
#   'ta': 9.9,
#   'tamax': 9.9},
#  {'idema': '1723X',
#   'lon': -8.4927,
#   'fint': '2021-10-24T21:00:00',
#   'prec': 0.0,
#   'alt': 90.0,
#   'lat': 42.182224,
#   'ubi': 'PONTEAREAS-CANEDO',
#   'hr': 100.0,
#   'tamin': 10.5,
#   'ta': 10.6,
#   'tamax': 11.0},
#  {'idema': '1730E',
#   'lon': -8.847444,
#   'fint': '2021-10-24T21:00:00',
#   'prec': 0.0,
#   'alt': 55.0,
#   'lat': 41.94398,
#   'ubi': 'O ROSAL',
#   'hr': 95.0,
#   'tamin': 13.8,
#   'ta': 13.8,
#   'tamax': 13.8},
#  {'idema': '1735X',
#   'lon': -7.733611,
#   'fint': '2021-10-24T21:00:00',
#   'prec': 0.0,
#   'alt': 616.0,
#   'vmax': 1.1,
#   'vv': 0.5,
#   'dv': 256.0,
#   'lat': 42.079166,
#   'dmax': 300.0,
#   'ubi': 'XINZO DE LIMIA',
#   'hr': 91.0,
#   'tamin': 7.8,
#   'ta': 8.6,
#   'tamax': 8.6,
#   'tpr': 7.3,
#   'rviento': 16.0},
#  {'idema': '1738U',
#   'lon': -7.988838,
#   'fint': '2021-10-24T21:00:00',
#   'prec': 0.0,
#   'alt': 730.0,
#   'lat': 41.934116,
#   'ubi': 'MUIÑOS-PRADO',
#   'hr': 93.0,
#   'tamin': 10.2,
#   'ta': 10.2,
#   'tamax': 10.3},
#  {'idema': '1740',
#   'lon': -4.12433,
#   'fint': '2021-10-24T21:00:00',
#   'prec': 0.0,
#   'alt': 150.0,
#   'vmax': 3.2,
#   'vv': 1.8,
#   'dv': 214.0,
#   'lat': 43.37724,
#   'dmax': 200.0,
#   'ubi': 'ALTAMIRA',
#   'hr': 82.0,
#   'tamin': 13.0,
#   'ta': 13.2,
#   'tamax': 13.3},
#  {'idema': '2005Y',
#   'lon': -2.782777,
#   'fint': '2021-10-24T21:00:00',
#   'prec': 0.0,
#   'alt': 1197.0,
#   'lat': 41.967773,
#   'ubi': 'VINUESA',
#   'hr': 77.0,
#   'tamin': 2.3,
#   'ta': 2.3,
#   'tamax': 4.2},
#  {'idema': '2017Y',
#   'lon': -2.494163,
#   'fint': '2021-10-24T21:00:00',
#   'prec': 0.0,
#   'alt': 1260.0,
#   'vmax': 3.6,
#   'vv': 2.7,
#   'dv': 355.0,
#   'lat': 41.99583,
#   'dmax': 7.0,
#   'ubi': 'BARRIOMARTIN-EL ROBLEDO',
#   'hr': 73.0,
#   'tamin': 4.1,
#   'ta': 4.1,
#   'tamax': 4.7},
#  {'idema': '2030',
#   'lon': -2.483063,
#   'fint': '2021-10-24T21:00:00',
#   'prec': 0.0,
#   'alt': 1082.0,
#   'vmax': 1.3,
#   'vv': 0.5,
#   'dv': 73.0,
#   'lat': 41.775017,
#   'dmax': 13.0,
#   'ubi': 'SORIA',
#   'pres': 899.5,
#   'hr': 62.0,
#   'stdvv': 0.2,
#   'ts': 3.9,
#   'tamin': 6.8,
#   'ta': 6.8,
#   'tamax': 8.5,
#   'tpr': 0.0,
#   'vis': 12.3,
#   'stddv': 17.0,
#   'inso': 0.0,
#   'tss5cm': 13.6,
#   'pacutp': 0.0,
#   'tss20cm': 14.0,
#   'geo850': {'value': 1545.4, 'present': True}},
#  {'idema': '2044B',
#   'lon': -2.507534,
#   'fint': '2021-10-24T21:00:00',
#   'prec': 0.0,
#   'alt': 1100.0,
#   'vmax': 1.7,
#   'vv': 0.7,
#   'dv': 287.0,
#   'lat': 41.600582,
#   'dmax': 270.0,
#   'ubi': 'LUBIA-CEDER',
#   'hr': 58.0,
#   'tamin': 5.6,
#   'ta': 6.3,
#   'tamax': 6.3},
#  {'idema': '2048A',
#   'lon': -2.420281,
#   'fint': '2021-10-24T21:00:00',
#   'prec': 0.0,
#   'alt': 978.0,
#   'vmax': 1.7,
#   'vv': 0.6,
#   'dv': 116.0,
#   'lat': 41.41944,
#   'dmax': 67.0,
#   'ubi': 'MORON DE ALMAZAN ',
#   'hr': 76.0,
#   'tamin': 1.8,
#   'ta': 1.8,
#   'tamax': 2.6},
#  {'idema': '2059B',
#   'lon': -2.783338,
#   'fint': '2021-10-24T21:00:00',
#   'prec': 0.0,
#   'alt': 1042.0,
#   'vmax': 1.0,
#   'vv': 0.5,
#   'dv': 161.0,
#   'lat': 41.34972,
#   'dmax': 135.0,
#   'ubi': 'LA RIBA DE ESCALOTE',
#   'hr': 61.0,
#   'tamin': 6.1,
#   'ta': 6.1,
#   'tamax': 7.5},
#  {'idema': '2084Y',
#   'lon': -3.047008,
#   'fint': '2021-10-24T21:00:00',
#   'prec': 0.0,
#   'alt': 960.0,
#   'lat': 41.721848,
#   'ubi': 'UCERO',
#   'hr': 79.0,
#   'tamin': 2.5,
#   'ta': 2.5,
#   'tamax': 3.2},
#  {'idema': '2092',
#   'lon': -3.086949,
#   'fint': '2021-10-24T21:00:00',
#   'prec': 0.0,
#   'alt': 932.0,
#   'vmax': 1.1,
#   'vv': 0.4,
#   'dv': 85.0,
#   'lat': 41.589443,
#   'dmax': 125.0,
#   'ubi': 'BURGO DE OSMA-POZUELOS',
#   'hr': 71.0,
#   'tamin': 3.2,
#   'ta': 3.2,
#   'tamax': 5.1},
#  {'idema': '2096B',
#   'lon': -3.251385,
#   'fint': '2021-10-24T21:00:00',
#   'prec': 0.0,
#   'alt': 1150.0,
#   'vmax': 2.0,
#   'vv': 1.1,
#   'dv': 156.0,
#   'lat': 41.373608,
#   'dmax': 155.0,
#   'ubi': 'LICERAS-CAÑADA DEHESA',
#   'hr': 54.0,
#   'tamin': 7.2,
#   'ta': 7.8,
#   'tamax': 8.0},
#  {'idema': '2106B',
#   'lon': -3.381929,
#   'fint': '2021-10-24T21:00:00',
#   'prec': 0.0,
#   'alt': 955.0,
#   'vmax': 2.1,
#   'vv': 1.4,
#   'dv': 142.0,
#   'lat': 41.745846,
#   'dmax': 135.0,
#   'ubi': 'CORUÑA DEL CONDE',
#   'hr': 51.0,
#   'tamin': 8.5,
#   'ta': 8.5,
#   'tamax': 9.8},
#  {'idema': '2117D',
#   'lon': -3.742777,
#   'fint': '2021-10-24T21:00:00',
#   'prec': 0.0,
#   'alt': 790.0,
#   'vmax': 1.5,
#   'vv': 0.9,
#   'dv': 85.0,
#   'lat': 41.665836,
#   'dmax': 79.0,
#   'ubi': 'ARANDA DE DUERO',
#   'pres': 931.6,
#   'hr': 65.0,
#   'ts': 3.1,
#   'tamin': 4.1,
#   'ta': 4.2,
#   'tamax': 5.7,
#   'tpr': -1.7,
#   'vis': 12.9,
#   'inso': 0.0,
#   'tss5cm': 9.5,
#   'psoltp': 0.0,
#   'pliqt': 0.0,
#   'geo925': 847.8},
#  {'idema': '2140A',
#   'lon': -3.785871,
#   'fint': '2021-10-24T21:00:00',
#   'prec': 0.0,
#   'alt': 1135.0,
#   'vmax': 1.9,
#   'vv': 1.0,
#   'dv': 171.0,
#   'lat': 41.464554,
#   'dmax': 215.0,
#   'ubi': 'ALDEANUEVA DE SERREZUELA-EL CERRO',
#   'hr': 50.0,
#   'tamin': 9.7,
#   'ta': 9.7,
#   'tamax': 10.8},
#  {'idema': '2150H',
#   'lon': -3.475165,
#   'fint': '2021-10-24T21:00:00',
#   'prec': 0.0,
#   'alt': 1798.0,
#   'vmax': 4.2,
#   'vv': 3.3,
#   'dv': 201.0,
#   'lat': 41.19193,
#   'dmax': 194.0,
#   'ubi': 'LA PINILLA  ESTACIÓN DE ESQUÍ',
#   'pres': 826.1,
#   'hr': 60.0,
#   'ts': 2.5,
#   'tamin': 4.7,
#   'ta': 4.8,
#   'tamax': 5.6,
#   'tpr': -2.2,
#   'vis': 20.0,
#   'inso': 0.0,
#   'tss5cm': 7.6,
#   'psoltp': 0.0,
#   'pliqt': 0.0,
#   'geo850': {'value': 1565.8, 'present': True}},
#  {'idema': '2166Y',
#   'lon': -4.124787,
#   'fint': '2021-10-24T21:00:00',
#   'prec': 0.0,
#   'alt': 756.0,
#   'lat': 41.593098,
#   'ubi': 'PEÑAFIEL(FABRICA DE QUESOS)',
#   'hr': 66.0,
#   'tamin': 5.2,
#   'ta': 5.2,
#   'tamax': 6.6},
#  {'idema': '2172Y',
#   'lon': -4.405497,
#   'fint': '2021-10-24T21:00:00',
#   'prec': 0.0,
#   'alt': 725.0,
#   'vmax': 1.2,
#   'vv': 0.1,
#   'dv': 46.0,
#   'lat': 41.611877,
#   'dmax': 120.0,
#   'ubi': 'SARDÓN DE DUERO',
#   'hr': 75.0,
#   'tamin': 2.9,
#   'ta': 2.9,
#   'tamax': 4.2},
#  {'idema': '2182C',
#   'lon': -3.790216,
#   'fint': '2021-10-24T21:00:00',
#   'prec': 0.0,
#   'alt': 1107.0,
#   'vmax': 3.1,
#   'vv': 2.6,
#   'dv': 131.0,
#   'lat': 41.13386,
#   'dmax': 132.0,
#   'ubi': 'RADES',
#   'hr': 56.0,
#   'tamin': 7.9,
#   'ta': 8.1,
#   'tamax': 8.6},
#  {'idema': '2192C',
#   'lon': -4.26545,
#   'fint': '2021-10-24T21:00:00',
#   'prec': 0.0,
#   'alt': 795.0,
#   'vmax': 1.8,
#   'vv': 0.7,
#   'dv': 104.0,
#   'lat': 41.383553,
#   'dmax': 107.0,
#   'ubi': 'CUELLAR',
#   'hr': 82.0,
#   'tamin': 1.9,
#   'ta': 2.0,
#   'tamax': 2.7},
#  {'idema': '2235U',
#   'lon': -4.520031,
#   'fint': '2021-10-24T21:00:00',
#   'prec': 0.0,
#   'alt': 1140.0,
#   'vmax': 6.0,
#   'vv': 2.4,
#   'dv': 295.0,
#   'lat': 42.87062,
#   'dmax': 285.0,
#   'ubi': 'CERVERA DE PISUERGA',
#   'pres': 892.4,
#   'hr': 68.0,
#   'ts': 2.3,
#   'tamin': 7.1,
#   'ta': 7.4,
#   'tamax': 8.6,
#   'tpr': 1.9,
#   'vis': 20.0,
#   'inso': 0.0,
#   'tss5cm': 9.3,
#   'psoltp': 0.0,
#   'pliqt': 0.0,
#   'geo850': {'value': 1539.1, 'present': True}},
#  {'idema': '2243A',
#   'lon': -4.277134,
#   'fint': '2021-10-24T21:00:00',
#   'prec': 0.0,
#   'alt': 910.0,
#   'vmax': 1.9,
#   'vv': 0.1,
#   'dv': 344.0,
#   'lat': 42.79806,
#   'dmax': 355.0,
#   'ubi': 'AGUILAR DE CAMPOO',
#   'hr': 78.0,
#   'tamin': 4.6,
#   'ta': 4.6,
#   'tamax': 6.2},
#  {'idema': '2276B',
#   'lon': -4.575109,
#   'fint': '2021-10-24T21:00:00',
#   'prec': 0.0,
#   'alt': 908.0,
#   'vmax': 3.3,
#   'vv': 0.7,
#   'dv': 25.0,
#   'lat': 42.568817,
#   'dmax': 27.0,
#   'ubi': 'VILLAELES DE VALDAVIA',
#   'hr': 80.0,
#   'tamin': 4.4,
#   'ta': 4.4,
#   'tamax': 5.8},
#  {'idema': '2285B',
#   'lon': -4.001111,
#   'fint': '2021-10-24T21:00:00',
#   'prec': 0.0,
#   'alt': 869.0,
#   'vmax': 3.3,
#   'vv': 2.8,
#   'dv': 62.0,
#   'lat': 42.523888,
#   'dmax': 57.0,
#   'ubi': 'VILLADIEGO (DEPÓSITO DE AGUA)',
#   'hr': 64.0,
#   'tamin': 7.0,
#   'ta': 7.1,
#   'tamax': 7.6},
#  {'idema': '2290Y',
#   'lon': -4.198909,
#   'fint': '2021-10-24T21:00:00',
#   'prec': 0.0,
#   'alt': 771.0,
#   'vmax': 2.5,
#   'vv': 1.2,
#   'dv': 80.0,
#   'lat': 42.251225,
#   'dmax': 62.0,
#   'ubi': 'PEDROSA DEL PRÍNCIPE',
#   'hr': 68.0,
#   'tamin': 5.2,
#   'ta': 5.3,
#   'tamax': 5.3},
#  {'idema': '2296A',
#   'lon': -1.976675,
#   'fint': '2021-10-24T21:00:00',
#   'prec': 0.0,
#   'alt': 1039.0,
#   'vmax': 1.5,
#   'vv': 0.5,
#   'dv': 183.0,
#   'lat': 41.775555,
#   'dmax': 160.0,
#   'ubi': 'OLVEGA-CAMINO VEGAFRÍA',
#   'hr': 80.0,
#   'tamin': 3.1,
#   'ta': 3.1,
#   'tamax': 4.0},
#  {'idema': '2298',
#   'lon': -3.131688,
#   'fint': '2021-10-24T21:00:00',
#   'prec': 0.0,
#   'alt': 1080.0,
#   'vmax': 3.5,
#   'vv': 1.6,
#   'dv': 138.0,
#   'lat': 41.95967,
#   'dmax': 171.0,
#   'ubi': 'PALACIOS DE LA SIERRA',
#   'pres': 900.3,
#   'hr': 74.0,
#   'ts': 2.1,
#   'tamin': 2.9,
#   'ta': 3.0,
#   'tamax': 4.0,
#   'tpr': -1.2,
#   'vis': 20.0,
#   'inso': 0.0,
#   'tss5cm': 10.4,
#   'psoltp': 0.0,
#   'pliqt': 0.0,
#   'geo850': {'value': 1543.3, 'present': True}},
#  {'idema': '2302N',
#   'lon': -3.109758,
#   'fint': '2021-10-24T21:00:00',
#   'prec': 0.0,
#   'alt': 1197.0,
#   'vmax': 0.7,
#   'vv': 0.1,
#   'dv': 212.0,
#   'lat': 42.146473,
#   'dmax': 85.0,
#   'ubi': 'MONTERRUBIO DE LA DEMANDA',
#   'hr': 75.0,
#   'tamin': 3.6,
#   'ta': 3.6,
#   'tamax': 4.7},
#  {'idema': '2311Y',
#   'lon': -3.767707,
#   'fint': '2021-10-24T21:00:00',
#   'prec': 0.0,
#   'alt': 884.0,
#   'vmax': 1.0,
#   'vv': 0.5,
#   'dv': 91.0,
#   'lat': 42.10522,
#   'dmax': 95.0,
#   'ubi': 'VILLAMAYOR DE LOS MONTES',
#   'hr': 69.0,
#   'tamin': 5.4,
#   'ta': 5.4,
#   'tamax': 6.3},
#  {'idema': '2331',
#   'lon': -3.620278,
#   'fint': '2021-10-24T21:00:00',
#   'prec': 0.0,
#   'alt': 891.0,
#   'vmax': 2.7,
#   'vv': 1.3,
#   'dv': 127.0,
#   'lat': 42.356945,
#   'dmax': 138.0,
#   'ubi': 'BURGOS/VILLAFRÍA',
#   'pres': 919.7,
#   'hr': 78.0,
#   'stdvv': 0.2,
#   'ts': 0.0,
#   'tamin': 4.3,
#   'ta': 4.3,
#   'tamax': 5.3,
#   'tpr': 0.9,
#   'stddv': 5.0,
#   'inso': 0.0,
#   'tss5cm': 11.0,
#   'pacutp': 0.0,
#   'tss20cm': 13.3,
#   'geo925': 845.0},
#  {'idema': '2362C',
#   'lon': -4.713714,
#   'fint': '2021-10-24T21:00:00',
#   'prec': 0.0,
#   'alt': 1575.0,
#   'vmax': 3.4,
#   'vv': 1.9,
#   'dv': 281.0,
#   'lat': 42.893772,
#   'dmax': 287.0,
#   'ubi': 'CAMPORREDONDO DE ALBA  CUEVA DORADA',
#   'hr': 57.0,
#   'tamin': 7.6,
#   'ta': 7.7,
#   'tamax': 7.8},
#  {'idema': '2374X',
#   'lon': -4.617359,
#   'fint': '2021-10-24T21:00:00',
#   'prec': 0.0,
#   'alt': 830.0,
#   'lat': 42.350933,
#   'ubi': 'CARRIÓN DE LOS CONDES',
#   'pres': 927.3,
#   'hr': 85.0,
#   'ts': 10.1,
#   'tamin': 4.8,
#   'ta': 4.8,
#   'tamax': 5.8,
#   'tpr': 2.5,
#   'inso': 0.0,
#   'tss5cm': 14.0,
#   'psoltp': 0.0,
#   'pliqt': 0.0,
#   'geo925': 850.3},
#  {'idema': '2400E',
#   'lon': -4.602777,
#   'fint': '2021-10-24T21:00:00',
#   'prec': 0.0,
#   'alt': 874.0,
#   'vmax': 2.6,
#   'vv': 2.2,
#   'dv': 214.0,
#   'lat': 41.99568,
#   'dmax': 238.0,
#   'ubi': 'PALENCIA-AUTILLA PINO',
#   'hr': 44.0,
#   'tamin': 10.0,
#   'ta': 10.1,
#   'tamax': 11.6,
#   'tpr': -1.7,
#   'rviento': 69.0},
#  {'idema': '2401X',
#   'lon': -4.560496,
#   'fint': '2021-10-24T21:00:00',
#   'prec': 0.0,
#   'alt': 736.0,
#   'vmax': 1.0,
#   'vv': 0.1,
#   'dv': 159.0,
#   'lat': 42.009502,
#   'dmax': 167.0,
#   'ubi': 'PALENCIA-GRANJA VIÑALTA',
#   'hr': 78.0,
#   'tamin': 5.7,
#   'ta': 5.7,
#   'tamax': 6.4},
#  ...]

# %%
tenerife_list = []

for observatory in all_observatories:
    if 'TENERIFE' in observatory['ubi']:
        tenerife_list.append(observatory)

tenerife_list
# Out:
# [{'idema': 'C429I',
#   'lon': -16.561157,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 64.0,
#   'vmax': 8.2,
#   'vv': 5.7,
#   'dv': 50.0,
#   'lat': 28.046991,
#   'dmax': 60.0,
#   'ubi': 'TENERIFE/SUR',
#   'pres': 1011.1,
#   'hr': 71.0,
#   'stdvv': 0.7,
#   'ts': 21.5,
#   'pres_nmar': 1020.1,
#   'tamin': 21.7,
#   'ta': 21.8,
#   'tamax': 22.4,
#   'tpr': 16.3,
#   'stddv': 4.0,
#   'inso': 0.0},
#  {'idema': 'C439J',
#   'lon': -16.382229,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 115.0,
#   'vmax': 8.7,
#   'vv': 7.0,
#   'dv': 53.0,
#   'lat': 28.318405,
#   'dmax': 61.0,
#   'ubi': 'TENERIFE-GÜIMAR',
#   'pres': 1005.8,
#   'hr': 68.0,
#   'pres_nmar': 1019.8,
#   'tamin': 21.3,
#   'ta': 21.3,
#   'tamax': 21.4,
#   'tpr': 15.2},
#  {'idema': 'C447A',
#   'lon': -16.329445,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 632.0,
#   'vmax': 6.2,
#   'vv': 1.3,
#   'dv': 330.0,
#   'lat': 28.477497,
#   'dmax': 50.0,
#   'ubi': 'TENERIFE/LOS RODEOS',
#   'pres': 949.7,
#   'hr': 81.0,
#   'stdvv': 0.6,
#   'ts': 14.9,
#   'pres_nmar': 1020.4,
#   'tamin': 16.4,
#   'ta': 16.5,
#   'tamax': 17.4,
#   'tpr': 13.3,
#   'vis': 30.0,
#   'stddv': 97.0,
#   'inso': 0.0},
#  {'idema': 'C449C',
#   'lon': -16.255281,
#   'fint': '2021-10-24T20:00:00',
#   'prec': 0.0,
#   'alt': 35.0,
#   'vmax': 6.0,
#   'vv': 3.4,
#   'dv': 46.0,
#   'lat': 28.463337,
#   'dmax': 40.0,
#   'ubi': 'SANTA CRUZ DE TENERIFE ',
#   'pres': 1014.5,
#   'hr': 63.0,
#   'stdvv': 1.2,
#   'ts': 21.0,
#   'pres_nmar': 1019.9,
#   'tamin': 22.1,
#   'ta': 22.1,
#   'tamax': 22.4,
#   'tpr': 14.7,
#   'vis': 19.7,
#   'stddv': 19.0,
#   'inso': 0.0,
#   'tss5cm': 24.6,
#   'pacutp': 0.0,
#   'tss20cm': 25.1},
#  {'idema': 'C429I',
#   'lon': -16.561157,
#   'fint': '2021-10-24T21:00:00',
#   'prec': 0.0,
#   'alt': 64.0,
#   'vmax': 9.3,
#   'vv': 5.5,
#   'dv': 50.0,
#   'lat': 28.046991,
#   'dmax': 70.0,
#   'ubi': 'TENERIFE/SUR',
#   'pres': 1011.6,
#   'hr': 67.0,
#   'stdvv': 0.6,
#   'ts': 21.8,
#   'pres_nmar': 1020.6,
#   'tamin': 21.8,
#   'ta': 21.9,
#   'tamax': 21.9,
#   'tpr': 15.5,
#   'stddv': 6.0,
#   'inso': 0.0},
#  {'idema': 'C439J',
#   'lon': -16.382229,
#   'fint': '2021-10-24T21:00:00',
#   'prec': 0.0,
#   'alt': 115.0,
#   'vmax': 8.0,
#   'vv': 5.5,
#   'dv': 52.0,
#   'lat': 28.318405,
#   'dmax': 58.0,
#   'ubi': 'TENERIFE-GÜIMAR',
#   'pres': 1006.6,
#   'hr': 68.0,
#   'pres_nmar': 1020.6,
#   'tamin': 21.3,
#   'ta': 21.3,
#   'tamax': 21.3,
#   'tpr': 15.2},
#  {'idema': 'C447A',
#   'lon': -16.329445,
#   'fint': '2021-10-24T21:00:00',
#   'prec': 0.0,
#   'alt': 632.0,
#   'vmax': 3.6,
#   'vv': 1.4,
#   'dv': 360.0,
#   'lat': 28.477497,
#   'dmax': 360.0,
#   'ubi': 'TENERIFE/LOS RODEOS',
#   'pres': 950.3,
#   'hr': 80.0,
#   'stdvv': 0.3,
#   'ts': 14.8,
#   'pres_nmar': 1021.1,
#   'tamin': 16.0,
#   'ta': 16.5,
#   'tamax': 16.6,
#   'tpr': 13.1,
#   'vis': 29.9,
#   'stddv': 169.0,
#   'inso': 0.0},
#  {'idema': 'C449C',
#   'lon': -16.255281,
#   'fint': '2021-10-24T21:00:00',
#   'prec': 0.0,
#   'alt': 35.0,
#   'vmax': 6.9,
#   'vv': 2.0,
#   'dv': 36.0,
#   'lat': 28.463337,
#   'dmax': 28.0,
#   'ubi': 'SANTA CRUZ DE TENERIFE ',
#   'pres': 1015.2,
#   'hr': 65.0,
#   'stdvv': 0.9,
#   'ts': 20.7,
#   'pres_nmar': 1020.6,
#   'tamin': 21.7,
#   'ta': 21.7,
#   'tamax': 22.1,
#   'tpr': 14.8,
#   'vis': 20.0,
#   'stddv': 25.0,
#   'inso': 0.0,
#   'tss5cm': 23.4,
#   'pacutp': 0.0,
#   'tss20cm': 24.8},
#  {'idema': 'C429I',
#   'lon': -16.561157,
#   'fint': '2021-10-24T22:00:00',
#   'prec': 0.0,
#   'alt': 64.0,
#   'vmax': 8.8,
#   'vv': 5.9,
#   'dv': 50.0,
#   'lat': 28.046991,
#   'dmax': 60.0,
#   'ubi': 'TENERIFE/SUR',
#   'pres': 1011.7,
#   'hr': 68.0,
#   'stdvv': 0.6,
#   'ts': 21.3,
#   'pres_nmar': 1020.7,
#   'tamin': 21.6,
#   'ta': 21.6,
#   'tamax': 22.0,
#   'tpr': 15.4,
#   'stddv': 4.0,
#   'inso': 0.0},
#  {'idema': 'C439J',
#   'lon': -16.382229,
#   'fint': '2021-10-24T22:00:00',
#   'prec': 0.0,
#   'alt': 115.0,
#   'vmax': 6.1,
#   'vv': 4.7,
#   'dv': 45.0,
#   'lat': 28.318405,
#   'dmax': 56.0,
#   'ubi': 'TENERIFE-GÜIMAR',
#   'pres': 1006.8,
#   'hr': 67.0,
#   'pres_nmar': 1020.8,
#   'tamin': 21.0,
#   'ta': 21.0,
#   'tamax': 21.3,
#   'tpr': 14.6},
#  {'idema': 'C447A',
#   'lon': -16.329445,
#   'fint': '2021-10-24T22:00:00',
#   'prec': 0.0,
#   'alt': 632.0,
#   'vmax': 4.1,
#   'vv': 0.7,
#   'dv': 360.0,
#   'lat': 28.477497,
#   'dmax': 40.0,
#   'ubi': 'TENERIFE/LOS RODEOS',
#   'pres': 950.4,
#   'hr': 82.0,
#   'stdvv': 0.5,
#   'ts': 13.6,
#   'pres_nmar': 1021.3,
#   'tamin': 15.9,
#   'ta': 16.0,
#   'tamax': 16.7,
#   'tpr': 13.0,
#   'vis': 29.5,
#   'stddv': 139.0,
#   'inso': 0.0},
#  {'idema': 'C449C',
#   'lon': -16.255281,
#   'fint': '2021-10-24T22:00:00',
#   'prec': 0.0,
#   'alt': 35.0,
#   'vmax': 6.3,
#   'vv': 2.0,
#   'dv': 33.0,
#   'lat': 28.463337,
#   'dmax': 73.0,
#   'ubi': 'SANTA CRUZ DE TENERIFE ',
#   'pres': 1015.3,
#   'hr': 64.0,
#   'stdvv': 1.1,
#   'ts': 20.9,
#   'pres_nmar': 1020.7,
#   'tamin': 21.7,
#   'ta': 21.7,
#   'tamax': 21.8,
#   'tpr': 14.6,
#   'vis': 20.0,
#   'stddv': 43.0,
#   'inso': 0.0,
#   'tss5cm': 22.5,
#   'pacutp': 0.0,
#   'tss20cm': 24.5},
#  {'idema': 'C429I',
#   'lon': -16.561157,
#   'fint': '2021-10-24T23:00:00',
#   'prec': 0.0,
#   'alt': 64.0,
#   'vmax': 9.8,
#   'vv': 4.8,
#   'dv': 40.0,
#   'lat': 28.046991,
#   'dmax': 60.0,
#   'ubi': 'TENERIFE/SUR',
#   'pres': 1011.5,
#   'hr': 69.0,
#   'stdvv': 0.7,
#   'ts': 21.1,
#   'pres_nmar': 1020.5,
#   'tamin': 21.4,
#   'ta': 21.5,
#   'tamax': 21.7,
#   'tpr': 15.6,
#   'stddv': 3.0,
#   'inso': 0.0},
#  {'idema': 'C439J',
#   'lon': -16.382229,
#   'fint': '2021-10-24T23:00:00',
#   'prec': 0.0,
#   'alt': 115.0,
#   'vmax': 4.8,
#   'vv': 1.7,
#   'dv': 322.0,
#   'lat': 28.318405,
#   'dmax': 56.0,
#   'ubi': 'TENERIFE-GÜIMAR',
#   'pres': 1006.7,
#   'hr': 69.0,
#   'pres_nmar': 1020.8,
#   'tamin': 19.4,
#   'ta': 19.4,
#   'tamax': 21.0,
#   'tpr': 13.6},
#  {'idema': 'C447A',
#   'lon': -16.329445,
#   'fint': '2021-10-24T23:00:00',
#   'prec': 0.0,
#   'alt': 632.0,
#   'vmax': 4.1,
#   'vv': 1.2,
#   'dv': 280.0,
#   'lat': 28.477497,
#   'dmax': 340.0,
#   'ubi': 'TENERIFE/LOS RODEOS',
#   'pres': 950.3,
#   'hr': 85.0,
#   'stdvv': 0.4,
#   'ts': 12.7,
#   'pres_nmar': 1021.6,
#   'tamin': 14.3,
#   'ta': 14.5,
#   'tamax': 16.1,
#   'tpr': 12.0,
#   'vis': 30.0,
#   'stddv': 17.0,
#   'inso': 0.0},
#  {'idema': 'C449C',
#   'lon': -16.255281,
#   'fint': '2021-10-24T23:00:00',
#   'prec': 0.0,
#   'alt': 35.0,
#   'vmax': 5.8,
#   'vv': 1.7,
#   'dv': 350.0,
#   'lat': 28.463337,
#   'dmax': 15.0,
#   'ubi': 'SANTA CRUZ DE TENERIFE ',
#   'pres': 1015.2,
#   'hr': 65.0,
#   'stdvv': 1.0,
#   'ts': 20.7,
#   'pres_nmar': 1020.6,
#   'tamin': 21.5,
#   'ta': 21.5,
#   'tamax': 21.7,
#   'tpr': 14.6,
#   'vis': 20.0,
#   'stddv': 27.0,
#   'inso': 0.0,
#   'tss5cm': 21.8,
#   'pacutp': 0.0,
#   'tss20cm': 24.2},
#  {'idema': 'C429I',
#   'lon': -16.561157,
#   'fint': '2021-10-25T00:00:00',
#   'prec': 0.0,
#   'alt': 64.0,
#   'vmax': 8.2,
#   'vv': 3.8,
#   'dv': 20.0,
#   'lat': 28.046991,
#   'dmax': 50.0,
#   'ubi': 'TENERIFE/SUR',
#   'pres': 1011.3,
#   'hr': 69.0,
#   'stdvv': 0.2,
#   'ts': 20.1,
#   'pres_nmar': 1020.3,
#   'tamin': 20.7,
#   'ta': 20.7,
#   'tamax': 21.5,
#   'tpr': 14.8,
#   'stddv': 1.0,
#   'inso': 0.0},
#  {'idema': 'C439J',
#   'lon': -16.382229,
#   'fint': '2021-10-25T00:00:00',
#   'prec': 0.0,
#   'alt': 115.0,
#   'vmax': 3.3,
#   'vv': 1.5,
#   'dv': 303.0,
#   'lat': 28.318405,
#   'dmax': 316.0,
#   'ubi': 'TENERIFE-GÜIMAR',
#   'pres': 1006.3,
#   'hr': 71.0,
#   'pres_nmar': 1020.5,
#   'tamin': 18.3,
#   'ta': 18.3,
#   'tamax': 19.5,
#   'tpr': 13.0},
#  {'idema': 'C447A',
#   'lon': -16.329445,
#   'fint': '2021-10-25T00:00:00',
#   'prec': 0.0,
#   'alt': 632.0,
#   'vmax': 5.1,
#   'vv': 3.7,
#   'dv': 280.0,
#   'lat': 28.477497,
#   'dmax': 280.0,
#   'ubi': 'TENERIFE/LOS RODEOS',
#   'pres': 950.0,
#   'hr': 87.0,
#   'stdvv': 0.3,
#   'ts': 13.8,
#   'pres_nmar': 1021.2,
#   'tamin': 14.6,
#   'ta': 14.9,
#   'tamax': 15.5,
#   'tpr': 12.7,
#   'vis': 28.4,
#   'stddv': 6.0,
#   'inso': 0.0},
#  {'idema': 'C449C',
#   'lon': -16.255281,
#   'fint': '2021-10-25T00:00:00',
#   'prec': 0.0,
#   'alt': 35.0,
#   'vmax': 5.7,
#   'vv': 1.0,
#   'dv': 330.0,
#   'lat': 28.463337,
#   'dmax': 15.0,
#   'ubi': 'SANTA CRUZ DE TENERIFE ',
#   'pres': 1014.9,
#   'hr': 68.0,
#   'stdvv': 0.3,
#   'ts': 19.5,
#   'pres_nmar': 1020.3,
#   'tamin': 21.1,
#   'ta': 21.1,
#   'tamax': 21.5,
#   'tpr': 15.0,
#   'vis': 20.0,
#   'stddv': 48.0,
#   'inso': 0.0,
#   'tss5cm': 21.2,
#   'pacutp': 0.0,
#   'tss20cm': 23.8},
#  {'idema': 'C429I',
#   'lon': -16.561157,
#   'fint': '2021-10-25T01:00:00',
#   'prec': 0.0,
#   'alt': 64.0,
#   'vmax': 5.7,
#   'vv': 4.4,
#   'dv': 30.0,
#   'lat': 28.046991,
#   'dmax': 30.0,
#   'ubi': 'TENERIFE/SUR',
#   'pres': 1010.7,
#   'hr': 66.0,
#   'stdvv': 0.2,
#   'ts': 19.7,
#   'pres_nmar': 1019.7,
#   'tamin': 20.1,
#   'ta': 20.2,
#   'tamax': 20.7,
#   'tpr': 13.7,
#   'stddv': 2.0,
#   'inso': 0.0},
#  {'idema': 'C439J',
#   'lon': -16.382229,
#   'fint': '2021-10-25T01:00:00',
#   'prec': 0.0,
#   'alt': 115.0,
#   'vmax': 2.6,
#   'vv': 1.6,
#   'dv': 287.0,
#   'lat': 28.318405,
#   'dmax': 316.0,
#   'ubi': 'TENERIFE-GÜIMAR',
#   'pres': 1005.9,
#   'hr': 67.0,
#   'pres_nmar': 1020.0,
#   'tamin': 17.9,
#   'ta': 19.0,
#   'tamax': 19.8,
#   'tpr': 12.7},
#  {'idema': 'C447A',
#   'lon': -16.329445,
#   'fint': '2021-10-25T01:00:00',
#   'prec': 0.0,
#   'alt': 632.0,
#   'vmax': 5.7,
#   'vv': 3.4,
#   'dv': 280.0,
#   'lat': 28.477497,
#   'dmax': 280.0,
#   'ubi': 'TENERIFE/LOS RODEOS',
#   'pres': 949.6,
#   'hr': 93.0,
#   'stdvv': 0.2,
#   'ts': 15.0,
#   'pres_nmar': 1020.5,
#   'tamin': 14.6,
#   'ta': 15.6,
#   'tamax': 15.7,
#   'tpr': 14.4,
#   'vis': 21.0,
#   'stddv': 3.0,
#   'inso': 0.0},
#  {'idema': 'C449C',
#   'lon': -16.255281,
#   'fint': '2021-10-25T01:00:00',
#   'prec': 0.0,
#   'alt': 35.0,
#   'vmax': 2.4,
#   'vv': 0.7,
#   'dv': 354.0,
#   'lat': 28.463337,
#   'dmax': 268.0,
#   'ubi': 'SANTA CRUZ DE TENERIFE ',
#   'pres': 1014.5,
#   'hr': 69.0,
#   'stdvv': 0.4,
#   'ts': 19.0,
#   'pres_nmar': 1019.9,
#   'tamin': 20.5,
#   'ta': 20.5,
#   'tamax': 21.1,
#   'tpr': 14.6,
#   'vis': 20.0,
#   'stddv': 81.0,
#   'inso': 0.0,
#   'tss5cm': 20.8,
#   'pacutp': 0.0,
#   'tss20cm': 23.5},
#  {'idema': 'C429I',
#   'lon': -16.561157,
#   'fint': '2021-10-25T02:00:00',
#   'prec': 0.0,
#   'alt': 64.0,
#   'vmax': 6.2,
#   'vv': 4.3,
#   'dv': 30.0,
#   'lat': 28.046991,
#   'dmax': 20.0,
#   'ubi': 'TENERIFE/SUR',
#   'pres': 1010.1,
#   'hr': 66.0,
#   'stdvv': 0.2,
#   'ts': 19.0,
#   'pres_nmar': 1019.2,
#   'tamin': 19.6,
#   'ta': 19.6,
#   'tamax': 20.2,
#   'tpr': 13.1,
#   'stddv': 1.0,
#   'inso': 0.0},
#  {'idema': 'C439J',
#   'lon': -16.382229,
#   'fint': '2021-10-25T02:00:00',
#   'prec': 0.0,
#   'alt': 115.0,
#   'vmax': 3.0,
#   'vv': 2.1,
#   'dv': 336.0,
#   'lat': 28.318405,
#   'dmax': 22.0,
#   'ubi': 'TENERIFE-GÜIMAR',
#   'pres': 1005.3,
#   'hr': 64.0,
#   'pres_nmar': 1019.4,
#   'tamin': 18.5,
#   'ta': 19.2,
#   'tamax': 19.5,
#   'tpr': 12.2},
#  {'idema': 'C447A',
#   'lon': -16.329445,
#   'fint': '2021-10-25T02:00:00',
#   'prec': 0.0,
#   'alt': 632.0,
#   'vmax': 5.7,
#   'vv': 3.2,
#   'dv': 330.0,
#   'lat': 28.477497,
#   'dmax': 320.0,
#   'ubi': 'TENERIFE/LOS RODEOS',
#   'pres': 949.2,
#   'hr': 90.0,
#   'stdvv': 0.3,
#   'ts': 15.5,
#   'pres_nmar': 1019.9,
#   'tamin': 15.5,
#   'ta': 16.2,
#   'tamax': 16.3,
#   'tpr': 14.5,
#   'vis': 25.2,
#   'stddv': 8.0,
#   'inso': 0.0},
#  {'idema': 'C449C',
#   'lon': -16.255281,
#   'fint': '2021-10-25T02:00:00',
#   'prec': 0.0,
#   'alt': 35.0,
#   'vmax': 3.1,
#   'vv': 0.8,
#   'dv': 308.0,
#   'lat': 28.463337,
#   'dmax': 50.0,
#   'ubi': 'SANTA CRUZ DE TENERIFE ',
#   'pres': 1014.0,
#   'hr': 68.0,
#   'stdvv': 0.4,
#   'ts': 19.9,
#   'pres_nmar': 1019.4,
#   'tamin': 20.5,
#   'ta': 21.1,
#   'tamax': 21.1,
#   'tpr': 15.0,
#   'vis': 20.0,
#   'stddv': 48.0,
#   'inso': 0.0,
#   'tss5cm': 20.8,
#   'pacutp': 0.0,
#   'tss20cm': 23.3},
#  {'idema': 'C429I',
#   'lon': -16.561157,
#   'fint': '2021-10-25T03:00:00',
#   'prec': 0.0,
#   'alt': 64.0,
#   'vmax': 6.2,
#   'vv': 4.6,
#   'dv': 10.0,
#   'lat': 28.046991,
#   'dmax': 360.0,
#   'ubi': 'TENERIFE/SUR',
#   'pres': 1009.8,
#   'hr': 65.0,
#   'stdvv': 0.3,
#   'ts': 19.5,
#   'pres_nmar': 1018.8,
#   'tamin': 19.6,
#   'ta': 20.2,
#   'tamax': 20.3,
#   'tpr': 13.5,
#   'stddv': 1.0,
#   'inso': 0.0},
#  {'idema': 'C439J',
#   'lon': -16.382229,
#   'fint': '2021-10-25T03:00:00',
#   'prec': 0.0,
#   'alt': 115.0,
#   'vmax': 6.7,
#   'vv': 5.5,
#   'dv': 40.0,
#   'lat': 28.318405,
#   'dmax': 44.0,
#   'ubi': 'TENERIFE-GÜIMAR',
#   'pres': 1004.7,
#   'hr': 66.0,
#   'pres_nmar': 1018.7,
#   'tamin': 19.2,
#   'ta': 20.9,
#   'tamax': 21.0,
#   'tpr': 14.3},
#  {'idema': 'C447A',
#   'lon': -16.329445,
#   'fint': '2021-10-25T03:00:00',
#   'prec': 0.0,
#   'alt': 632.0,
#   'vmax': 5.7,
#   'vv': 4.2,
#   'dv': 310.0,
#   'lat': 28.477497,
#   'dmax': 330.0,
#   'ubi': 'TENERIFE/LOS RODEOS',
#   'pres': 948.7,
#   'hr': 87.0,
#   'stdvv': 0.4,
#   'ts': 14.7,
#   'pres_nmar': 1019.5,
#   'tamin': 15.8,
#   'ta': 16.0,
#   'tamax': 16.3,
#   'tpr': 13.9,
#   'vis': 29.2,
#   'stddv': 10.0,
#   'inso': 0.0},
#  {'idema': 'C449C',
#   'lon': -16.255281,
#   'fint': '2021-10-25T03:00:00',
#   'prec': 0.0,
#   'alt': 35.0,
#   'vmax': 3.7,
#   'vv': 1.3,
#   'dv': 22.0,
#   'lat': 28.463337,
#   'dmax': 33.0,
#   'ubi': 'SANTA CRUZ DE TENERIFE ',
#   'pres': 1013.6,
#   'hr': 67.0,
#   'stdvv': 0.6,
#   'ts': 20.2,
#   'pres_nmar': 1019.0,
#   'tamin': 21.1,
#   'ta': 21.1,
#   'tamax': 21.2,
#   'tpr': 14.7,
#   'vis': 20.0,
#   'stddv': 31.0,
#   'inso': 0.0,
#   'tss5cm': 20.4,
#   'pacutp': 0.0,
#   'tss20cm': 23.0},
#  {'idema': 'C429I',
#   'lon': -16.561157,
#   'fint': '2021-10-25T04:00:00',
#   'prec': 0.0,
#   'alt': 64.0,
#   'vmax': 7.2,
#   'vv': 3.6,
#   'dv': 360.0,
#   'lat': 28.046991,
#   'dmax': 10.0,
#   'ubi': 'TENERIFE/SUR',
#   'pres': 1009.8,
#   'hr': 66.0,
#   'stdvv': 0.2,
#   'ts': 19.2,
#   'pres_nmar': 1018.8,
#   'tamin': 19.9,
#   'ta': 20.0,
#   'tamax': 20.5,
#   'tpr': 13.5,
#   'stddv': 188.0,
#   'inso': 0.0},
#  {'idema': 'C439J',
#   'lon': -16.382229,
#   'fint': '2021-10-25T04:00:00',
#   'prec': 0.0,
#   'alt': 115.0,
#   'vmax': 8.6,
#   'vv': 3.1,
#   'dv': 1.0,
#   'lat': 28.318405,
#   'dmax': 59.0,
#   'ubi': 'TENERIFE-GÜIMAR',
#   'pres': 1004.4,
#   'hr': 64.0,
#   'pres_nmar': 1018.4,
#   'tamin': 20.4,
#   'ta': 20.5,
#   'tamax': 21.1,
#   'tpr': 13.5},
#  {'idema': 'C447A',
#   'lon': -16.329445,
#   'fint': '2021-10-25T04:00:00',
#   'prec': 0.0,
#   'alt': 632.0,
#   'vmax': 7.2,
#   'vv': 5.1,
#   'dv': 310.0,
#   'lat': 28.477497,
#   'dmax': 320.0,
#   'ubi': 'TENERIFE/LOS RODEOS',
#   'pres': 948.5,
#   'hr': 90.0,
#   'stdvv': 0.4,
#   'ts': 14.6,
#   'pres_nmar': 1019.3,
#   'tamin': 15.5,
#   'ta': 15.8,
#   'tamax': 16.0,
#   'tpr': 14.1,
#   'vis': 23.4,
#   'stddv': 6.0,
#   'inso': 0.0},
#  {'idema': 'C449C',
#   'lon': -16.255281,
#   'fint': '2021-10-25T04:00:00',
#   'prec': 0.0,
#   'alt': 35.0,
#   'vmax': 2.3,
#   'vv': 0.8,
#   'dv': 39.0,
#   'lat': 28.463337,
#   'dmax': 40.0,
#   'ubi': 'SANTA CRUZ DE TENERIFE ',
#   'pres': 1013.2,
#   'hr': 70.0,
#   'stdvv': 0.2,
#   'ts': 18.3,
#   'pres_nmar': 1018.6,
#   'tamin': 20.3,
#   'ta': 20.3,
#   'tamax': 21.1,
#   'tpr': 14.6,
#   'vis': 20.0,
#   'stddv': 19.0,
#   'inso': 0.0,
#   'tss5cm': 20.0,
#   'pacutp': 0.0,
#   'tss20cm': 22.8},
#  {'idema': 'C429I',
#   'lon': -16.561157,
#   'fint': '2021-10-25T05:00:00',
#   'prec': 0.0,
#   'alt': 64.0,
#   'vmax': 5.7,
#   'vv': 4.4,
#   'dv': 30.0,
#   'lat': 28.046991,
#   'dmax': 30.0,
#   'ubi': 'TENERIFE/SUR',
#   'pres': 1009.8,
#   'hr': 65.0,
#   'stdvv': 0.2,
#   'ts': 18.8,
#   'pres_nmar': 1018.9,
#   'tamin': 19.4,
#   'ta': 19.6,
#   'tamax': 19.9,
#   'tpr': 12.8,
#   'stddv': 2.0,
#   'inso': 0.0},
#  {'idema': 'C439J',
#   'lon': -16.382229,
#   'fint': '2021-10-25T05:00:00',
#   'prec': 0.0,
#   'alt': 115.0,
#   'vmax': 4.2,
#   'vv': 2.1,
#   'dv': 312.0,
#   'lat': 28.318405,
#   'dmax': 103.0,
#   'ubi': 'TENERIFE-GÜIMAR',
#   'pres': 1004.5,
#   'hr': 64.0,
#   'pres_nmar': 1018.6,
#   'tamin': 19.1,
#   'ta': 19.9,
#   'tamax': 20.4,
#   'tpr': 12.8},
#  {'idema': 'C447A',
#   'lon': -16.329445,
#   'fint': '2021-10-25T05:00:00',
#   'prec': 0.0,
#   'alt': 632.0,
#   'vmax': 8.2,
#   'vv': 4.3,
#   'dv': 320.0,
#   'lat': 28.477497,
#   'dmax': 310.0,
#   'ubi': 'TENERIFE/LOS RODEOS',
#   'pres': 948.5,
#   'hr': 88.0,
#   'stdvv': 0.7,
#   'ts': 14.8,
#   'pres_nmar': 1019.3,
#   'tamin': 15.8,
#   'ta': 15.9,
#   'tamax': 16.1,
#   'tpr': 13.9,
#   'vis': 27.2,
#   'stddv': 4.0,
#   'inso': 0.0},
#  {'idema': 'C449C',
#   'lon': -16.255281,
#   'fint': '2021-10-25T05:00:00',
#   'prec': 0.0,
#   'alt': 35.0,
#   'vmax': 6.2,
#   'vv': 3.2,
#   'dv': 356.0,
#   'lat': 28.463337,
#   'dmax': 8.0,
#   'ubi': 'SANTA CRUZ DE TENERIFE ',
#   'pres': 1013.1,
#   'hr': 65.0,
#   'stdvv': 1.3,
#   'ts': 20.8,
#   'pres_nmar': 1018.5,
#   'tamin': 20.3,
#   'ta': 21.4,
#   'tamax': 21.5,
#   'tpr': 14.5,
#   'vis': 20.0,
#   'stddv': 26.0,
#   'inso': 0.0,
#   'tss5cm': 19.8,
#   'pacutp': 0.0,
#   'tss20cm': 22.6},
#  {'idema': 'C429I',
#   'lon': -16.561157,
#   'fint': '2021-10-25T06:00:00',
#   'prec': 0.0,
#   'alt': 64.0,
#   'vmax': 5.7,
#   'vv': 3.6,
#   'dv': 10.0,
#   'lat': 28.046991,
#   'dmax': 20.0,
#   'ubi': 'TENERIFE/SUR',
#   'pres': 1010.3,
#   'hr': 66.0,
#   'stdvv': 0.2,
#   'ts': 18.6,
#   'pres_nmar': 1019.4,
#   'tamin': 19.3,
#   'ta': 19.4,
#   'tamax': 19.8,
#   'tpr': 12.8,
#   'stddv': 5.0,
#   'inso': 0.0},
#  {'idema': 'C439J',
#   'lon': -16.382229,
#   'fint': '2021-10-25T06:00:00',
#   'prec': 0.0,
#   'alt': 115.0,
#   'vmax': 7.8,
#   'vv': 1.8,
#   'dv': 238.0,
#   'lat': 28.318405,
#   'dmax': 68.0,
#   'ubi': 'TENERIFE-GÜIMAR',
#   'pres': 1004.9,
#   'hr': 66.0,
#   'pres_nmar': 1018.9,
#   'tamin': 19.4,
#   'ta': 20.4,
#   'tamax': 20.8,
#   'tpr': 13.9},
#  {'idema': 'C447A',
#   'lon': -16.329445,
#   'fint': '2021-10-25T06:00:00',
#   'prec': 0.0,
#   'alt': 632.0,
#   'vmax': 7.7,
#   'vv': 5.0,
#   'dv': 320.0,
#   'lat': 28.477497,
#   'dmax': 350.0,
#   'ubi': 'TENERIFE/LOS RODEOS',
#   'pres': 948.8,
#   'hr': 87.0,
#   'stdvv': 0.4,
#   'ts': 15.5,
#   'pres_nmar': 1019.5,
#   'tamin': 15.8,
#   'ta': 16.3,
#   'tamax': 16.3,
#   'tpr': 14.1,
#   'vis': 28.8,
#   'stddv': 9.0,
#   'inso': 0.0},
#  {'idema': 'C449C',
#   'lon': -16.255281,
#   'fint': '2021-10-25T06:00:00',
#   'prec': 0.0,
#   'alt': 35.0,
#   'vmax': 9.4,
#   'vv': 1.7,
#   'dv': 29.0,
#   'lat': 28.463337,
#   'dmax': 3.0,
#   'ubi': 'SANTA CRUZ DE TENERIFE ',
#   'pres': 1013.5,
#   'hr': 66.0,
#   'stdvv': 0.6,
#   'ts': 21.4,
#   'pres_nmar': 1018.9,
#   'tamin': 21.4,
#   'ta': 21.8,
#   'tamax': 21.8,
#   'tpr': 15.2,
#   'vis': 20.0,
#   'stddv': 30.0,
#   'inso': 0.0,
#   'tss5cm': 19.8,
#   'pacutp': 0.01,
#   'tss20cm': 22.5},
#  {'idema': 'C429I',
#   'lon': -16.561157,
#   'fint': '2021-10-25T07:00:00',
#   'prec': 0.0,
#   'alt': 64.0,
#   'vmax': 5.1,
#   'vv': 3.4,
#   'dv': 360.0,
#   'lat': 28.046991,
#   'dmax': 350.0,
#   'ubi': 'TENERIFE/SUR',
#   'pres': 1010.7,
#   'hr': 65.0,
#   'stdvv': 0.2,
#   'ts': 18.8,
#   'pres_nmar': 1019.8,
#   'tamin': 19.2,
#   'ta': 19.5,
#   'tamax': 19.9,
#   'tpr': 12.7,
#   'stddv': 169.0,
#   'inso': 0.0},
#  {'idema': 'C439J',
#   'lon': -16.382229,
#   'fint': '2021-10-25T07:00:00',
#   'prec': 0.0,
#   'alt': 115.0,
#   'vmax': 2.6,
#   'vv': 1.0,
#   'dv': 174.0,
#   'lat': 28.318405,
#   'dmax': 347.0,
#   'ubi': 'TENERIFE-GÜIMAR',
#   'pres': 1005.1,
#   'hr': 68.0,
#   'pres_nmar': 1019.2,
#   'tamin': 19.5,
#   'ta': 19.6,
#   'tamax': 20.4,
#   'tpr': 13.6},
#  {'idema': 'C447A',
#   'lon': -16.329445,
#   'fint': '2021-10-25T07:00:00',
#   'prec': 0.0,
#   'alt': 632.0,
#   'vmax': 8.8,
#   'vv': 4.8,
#   'dv': 310.0,
#   'lat': 28.477497,
#   'dmax': 340.0,
#   'ubi': 'TENERIFE/LOS RODEOS',
#   'pres': 949.1,
#   'hr': 86.0,
#   'stdvv': 0.7,
#   'ts': 15.5,
#   'pres_nmar': 1019.9,
#   'tamin': 16.1,
#   'ta': 16.2,
#   'tamax': 16.6,
#   'tpr': 13.9,
#   'vis': 29.8,
#   'stddv': 10.0,
#   'inso': 0.0},
#  {'idema': 'C449C',
#   'lon': -16.255281,
#   'fint': '2021-10-25T07:00:00',
#   'prec': 0.2,
#   'alt': 35.0,
#   'vmax': 5.7,
#   'vv': 2.0,
#   'dv': 45.0,
#   'lat': 28.463337,
#   'dmax': 43.0,
#   'ubi': 'SANTA CRUZ DE TENERIFE ',
#   'pres': 1013.8,
#   'hr': 71.0,
#   'stdvv': 1.0,
#   'ts': 20.5,
#   'pres_nmar': 1019.2,
#   'tamin': 21.2,
#   'ta': 21.3,
#   'tamax': 21.8,
#   'tpr': 15.8,
#   'vis': 20.0,
#   'stddv': 26.0,
#   'inso': 0.0,
#   'tss5cm': 20.1,
#   'pacutp': 0.3,
#   'tss20cm': 22.3},
#  {'idema': 'C429I',
#   'lon': -16.561157,
#   'fint': '2021-10-25T08:00:00',
#   'prec': 0.0,
#   'alt': 64.0,
#   'vmax': 4.1,
#   'vv': 2.0,
#   'dv': 20.0,
#   'lat': 28.046991,
#   'dmax': 20.0,
#   'ubi': 'TENERIFE/SUR',
#   'pres': 1010.8,
#   'hr': 63.0,
#   'stdvv': 0.2,
#   'ts': 19.8,
#   'pres_nmar': 1019.9,
#   'tamin': 19.6,
#   'ta': 20.1,
#   'tamax': 20.2,
#   'tpr': 12.8,
#   'stddv': 8.0,
#   'inso': 0.0},
#  {'idema': 'C439J',
#   'lon': -16.382229,
#   'fint': '2021-10-25T08:00:00',
#   'prec': 0.0,
#   'alt': 115.0,
#   'vmax': 3.6,
#   'vv': 2.3,
#   'dv': 214.0,
#   'lat': 28.318405,
#   'dmax': 269.0,
#   'ubi': 'TENERIFE-GÜIMAR',
#   'pres': 1005.3,
#   'hr': 67.0,
#   'pres_nmar': 1019.4,
#   'tamin': 19.4,
#   'ta': 19.6,
#   'tamax': 20.1,
#   'tpr': 13.3},
#  {'idema': 'C447A',
#   'lon': -16.329445,
#   'fint': '2021-10-25T08:00:00',
#   'prec': 0.0,
#   'alt': 632.0,
#   'vmax': 8.8,
#   'vv': 5.7,
#   'dv': 310.0,
#   'lat': 28.477497,
#   'dmax': 310.0,
#   'ubi': 'TENERIFE/LOS RODEOS',
#   'pres': 949.2,
#   'hr': 85.0,
#   'stdvv': 1.0,
#   'ts': 15.9,
#   'pres_nmar': 1019.9,
#   'tamin': 16.1,
#   'ta': 16.6,
#   'tamax': 16.7,
#   'tpr': 14.0,
#   'vis': 27.1,
#   'stddv': 8.0,
#   'inso': 0.0},
#  {'idema': 'C449C',
#   'lon': -16.255281,
#   'fint': '2021-10-25T08:00:00',
#   'prec': 0.0,
#   'alt': 35.0,
#   'vmax': 4.9,
#   'vv': 1.7,
#   'dv': 345.0,
#   'lat': 28.463337,
#   'dmax': 55.0,
#   'ubi': 'SANTA CRUZ DE TENERIFE ',
#   'pres': 1013.9,
#   'hr': 66.0,
#   'stdvv': 0.7,
#   'ts': 20.9,
#   'pres_nmar': 1019.3,
#   'tamin': 21.3,
#   'ta': 21.7,
#   'tamax': 21.7,
#   'tpr': 15.1,
#   'vis': 20.0,
#   'stddv': 63.0,
#   'inso': 0.0,
#   'tss5cm': 20.1,
#   'pacutp': 0.0,
#   'tss20cm': 22.3},
#  {'idema': 'C429I',
#   'lon': -16.561157,
#   'fint': '2021-10-25T09:00:00',
#   'prec': 0.0,
#   'alt': 64.0,
#   'vmax': 5.7,
#   'vv': 3.2,
#   'dv': 60.0,
#   'lat': 28.046991,
#   'dmax': 60.0,
#   'ubi': 'TENERIFE/SUR',
#   'pres': 1011.4,
#   'hr': 58.0,
#   'stdvv': 0.5,
#   'ts': 25.0,
#   'pres_nmar': 1020.3,
#   'tamin': 20.2,
#   'ta': 23.4,
#   'tamax': 23.5,
#   'tpr': 14.7,
#   'stddv': 8.0,
#   'inso': 37.0},
#  {'idema': 'C439J',
#   'lon': -16.382229,
#   'fint': '2021-10-25T09:00:00',
#   'prec': 0.0,
#   'alt': 115.0,
#   'vmax': 6.3,
#   'vv': 4.6,
#   'dv': 40.0,
#   'lat': 28.318405,
#   'dmax': 55.0,
#   'ubi': 'TENERIFE-GÜIMAR',
#   'pres': 1006.0,
#   'hr': 73.0,
#   'pres_nmar': 1020.0,
#   'tamin': 19.6,
#   'ta': 21.3,
#   'tamax': 21.6,
#   'tpr': 16.2},
#  {'idema': 'C447A',
#   'lon': -16.329445,
#   'fint': '2021-10-25T09:00:00',
#   'prec': 0.0,
#   'alt': 632.0,
#   'vmax': 9.8,
#   'vv': 3.8,
#   'dv': 320.0,
#   'lat': 28.477497,
#   'dmax': 300.0,
#   'ubi': 'TENERIFE/LOS RODEOS',
#   'pres': 950.1,
#   'hr': 86.0,
#   'stdvv': 0.6,
#   'ts': 16.9,
#   'pres_nmar': 1020.7,
#   'tamin': 16.7,
#   'ta': 17.0,
#   'tamax': 17.1,
#   'tpr': 14.6,
#   'vis': 25.8,
#   'stddv': 17.0,
#   'inso': 0.0},
#  {'idema': 'C449C',
#   'lon': -16.255281,
#   'fint': '2021-10-25T09:00:00',
#   'prec': 0.0,
#   'alt': 35.0,
#   'vmax': 4.7,
#   'vv': 1.9,
#   'dv': 8.0,
#   'lat': 28.463337,
#   'dmax': 350.0,
#   'ubi': 'SANTA CRUZ DE TENERIFE ',
#   'pres': 1014.7,
#   'hr': 67.0,
#   'stdvv': 1.1,
#   'ts': 21.9,
#   'pres_nmar': 1020.1,
#   'tamin': 21.5,
#   'ta': 21.9,
#   'tamax': 21.9,
#   'tpr': 15.5,
#   'vis': 20.0,
#   'stddv': 38.0,
#   'inso': 0.0,
#   'tss5cm': 20.5,
#   'pacutp': 0.0,
#   'tss20cm': 22.3},
#  {'idema': 'C429I',
#   'lon': -16.561157,
#   'fint': '2021-10-25T10:00:00',
#   'prec': 0.0,
#   'alt': 64.0,
#   'vmax': 6.2,
#   'vv': 3.6,
#   'dv': 80.0,
#   'lat': 28.046991,
#   'dmax': 70.0,
#   'ubi': 'TENERIFE/SUR',
#   'pres': 1012.0,
#   'hr': 62.0,
#   'stdvv': 0.6,
#   'ts': 24.6,
#   'pres_nmar': 1020.9,
#   'tamin': 23.2,
#   'ta': 23.4,
#   'tamax': 24.2,
#   'tpr': 15.7,
#   'stddv': 11.0,
#   'inso': 29.0},
#  {'idema': 'C439J',
#   'lon': -16.382229,
#   'fint': '2021-10-25T10:00:00',
#   'prec': 0.0,
#   'alt': 115.0,
#   'vmax': 6.7,
#   'vv': 1.4,
#   'dv': 350.0,
#   'lat': 28.318405,
#   'dmax': 58.0,
#   'ubi': 'TENERIFE-GÜIMAR',
#   'pres': 1006.9,
#   'hr': 64.0,
#   'pres_nmar': 1020.9,
#   'tamin': 21.3,
#   'ta': 22.2,
#   'tamax': 22.3,
#   'tpr': 15.1},
#  {'idema': 'C447A',
#   'lon': -16.329445,
#   'fint': '2021-10-25T10:00:00',
#   'prec': 0.4,
#   'alt': 632.0,
#   'vmax': 7.2,
#   'vv': 4.2,
#   'dv': 320.0,
#   'lat': 28.477497,
#   'dmax': 350.0,
#   'ubi': 'TENERIFE/LOS RODEOS',
#   'pres': 950.8,
#   'hr': 91.0,
#   'stdvv': 0.6,
#   'ts': 16.6,
#   'pres_nmar': 1021.6,
#   'tamin': 16.3,
#   'ta': 16.4,
#   'tamax': 17.4,
#   'tpr': 14.9,
#   'vis': 16.1,
#   'stddv': 7.0,
#   'inso': 0.0},
#  {'idema': 'C449C',
#   'lon': -16.255281,
#   'fint': '2021-10-25T10:00:00',
#   'prec': 0.2,
#   'alt': 35.0,
#   'vmax': 8.3,
#   'vv': 2.2,
#   'dv': 350.0,
#   'lat': 28.463337,
#   'dmax': 358.0,
#   'ubi': 'SANTA CRUZ DE TENERIFE ',
#   'pres': 1015.5,
#   'hr': 67.0,
#   'stdvv': 1.1,
#   'ts': 21.4,
#   'pres_nmar': 1020.9,
#   'tamin': 21.8,
#   'ta': 21.8,
#   'tamax': 22.2,
#   'tpr': 15.4,
#   'vis': 19.3,
#   'stddv': 18.0,
#   'inso': 0.0,
#   'tss5cm': 20.8,
#   'pacutp': 0.29,
#   'tss20cm': 22.2},
#  {'idema': 'C429I',
#   'lon': -16.561157,
#   'fint': '2021-10-25T11:00:00',
#   'prec': 0.0,
#   'alt': 64.0,
#   'vmax': 9.3,
#   'vv': 7.1,
#   'dv': 90.0,
#   'lat': 28.046991,
#   'dmax': 80.0,
#   'ubi': 'TENERIFE/SUR',
#   'pres': 1012.0,
#   'hr': 66.0,
#   'stdvv': 0.8,
#   'ts': 28.3,
#   'pres_nmar': 1020.9,
#   'tamin': 23.5,
#   'ta': 24.5,
#   'tamax': 24.7,
#   'tpr': 17.7,
#   'stddv': 5.0,
#   'inso': 60.0},
#  {'idema': 'C439J',
#   'lon': -16.382229,
#   'fint': '2021-10-25T11:00:00',
#   'prec': 0.0,
#   'alt': 115.0,
#   'vmax': 8.7,
#   'vv': 7.7,
#   'dv': 78.0,
#   'lat': 28.318405,
#   'dmax': 87.0,
#   'ubi': 'TENERIFE-GÜIMAR',
#   'pres': 1006.8,
#   'hr': 72.0,
#   'pres_nmar': 1020.7,
#   'tamin': 21.9,
#   'ta': 22.8,
#   'tamax': 23.5,
#   'tpr': 17.5},
#  {'idema': 'C447A',
#   'lon': -16.329445,
#   'fint': '2021-10-25T11:00:00',
#   'prec': 0.0,
#   'alt': 632.0,
#   'vmax': 8.8,
#   'vv': 3.7,
#   'dv': 330.0,
#   'lat': 28.477497,
#   'dmax': 310.0,
#   'ubi': 'TENERIFE/LOS RODEOS',
#   'pres': 950.8,
#   'hr': 82.0,
#   'stdvv': 0.7,
#   'ts': 20.4,
#   'pres_nmar': 1021.1,
#   'tamin': 16.5,
#   'ta': 18.2,
#   'tamax': 18.6,
#   'tpr': 15.1,
#   'vis': 26.5,
#   'stddv': 16.0,
#   'inso': 12.0},
#  {'idema': 'C449C',
#   'lon': -16.255281,
#   'fint': '2021-10-25T11:00:00',
#   'prec': 0.0,
#   'alt': 35.0,
#   'vmax': 5.3,
#   'vv': 2.4,
#   'dv': 82.0,
#   'lat': 28.463337,
#   'dmax': 0.0,
#   'ubi': 'SANTA CRUZ DE TENERIFE ',
#   'pres': 1015.6,
#   'hr': 68.0,
#   'stdvv': 0.8,
#   'ts': 22.9,
#   'pres_nmar': 1021.0,
#   'tamin': 21.8,
#   'ta': 22.3,
#   'tamax': 22.4,
#   'tpr': 16.1,
#   'vis': 20.0,
#   'stddv': 21.0,
#   'inso': 0.0,
#   'tss5cm': 21.4,
#   'pacutp': 0.0,
#   'tss20cm': 22.4},
#  {'idema': 'C429I',
#   'lon': -16.561157,
#   'fint': '2021-10-25T12:00:00',
#   'prec': 0.0,
#   'alt': 64.0,
#   'vmax': 12.4,
#   'vv': 8.8,
#   'dv': 70.0,
#   'lat': 28.046991,
#   'dmax': 70.0,
#   'ubi': 'TENERIFE/SUR',
#   'pres': 1011.7,
#   'hr': 63.0,
#   'stdvv': 0.7,
#   'ts': 26.1,
#   'pres_nmar': 1020.6,
#   'tamin': 23.8,
#   'ta': 24.0,
#   'tamax': 25.1,
#   'tpr': 16.6,
#   'stddv': 5.0,
#   'inso': 43.0},
#  {'idema': 'C439J',
#   'lon': -16.382229,
#   'fint': '2021-10-25T12:00:00',
#   'prec': 0.0,
#   'alt': 115.0,
#   'vmax': 10.3,
#   'vv': 4.8,
#   'dv': 56.0,
#   'lat': 28.318405,
#   'dmax': 78.0,
#   'ubi': 'TENERIFE-GÜIMAR',
#   'pres': 1006.6,
#   'hr': 62.0,
#   'pres_nmar': 1020.5,
#   'tamin': 21.7,
#   'ta': 23.4,
#   'tamax': 23.5,
#   'tpr': 15.7},
#  {'idema': 'C447A',
#   'lon': -16.329445,
#   'fint': '2021-10-25T12:00:00',
#   'prec': 0.0,
#   'alt': 632.0,
#   'vmax': 7.2,
#   'vv': 4.5,
#   'dv': 340.0,
#   'lat': 28.477497,
#   'dmax': 340.0,
#   'ubi': 'TENERIFE/LOS RODEOS',
#   'pres': 950.5,
#   'hr': 74.0,
#   'stdvv': 0.5,
#   'ts': 25.3,
#   'pres_nmar': 1020.4,
#   'tamin': 18.1,
#   'ta': 19.8,
#   'tamax': 20.3,
#   'tpr': 15.0,
#   'vis': 24.7,
#   'stddv': 8.0,
#   'inso': 21.0},
#  {'idema': 'C449C',
#   'lon': -16.255281,
#   'fint': '2021-10-25T12:00:00',
#   'prec': 0.0,
#   'alt': 35.0,
#   'vmax': 4.8,
#   'vv': 2.7,
#   'dv': 45.0,
#   'lat': 28.463337,
#   'dmax': 33.0,
#   'ubi': 'SANTA CRUZ DE TENERIFE ',
#   'pres': 1015.3,
#   'hr': 62.0,
#   'stdvv': 0.8,
#   'ts': 24.7,
#   'pres_nmar': 1020.7,
#   'tamin': 22.3,
#   'ta': 23.6,
#   'tamax': 23.6,
#   'tpr': 15.9,
#   'vis': 20.0,
#   'stddv': 28.0,
#   'inso': 0.0,
#   'tss5cm': 22.7,
#   'pacutp': 0.02,
#   'tss20cm': 22.6},
#  {'idema': 'C429I',
#   'lon': -16.561157,
#   'fint': '2021-10-25T13:00:00',
#   'prec': 0.0,
#   'alt': 64.0,
#   'vmax': 11.3,
#   'vv': 7.7,
#   'dv': 70.0,
#   'lat': 28.046991,
#   'dmax': 70.0,
#   'ubi': 'TENERIFE/SUR',
#   'pres': 1010.8,
#   'hr': 57.0,
#   'stdvv': 0.8,
#   'ts': 28.0,
#   'pres_nmar': 1019.7,
#   'tamin': 24.0,
#   'ta': 25.4,
#   'tamax': 26.4,
#   'tpr': 16.2,
#   'stddv': 9.0,
#   'inso': 47.0},
#  {'idema': 'C439J',
#   'lon': -16.382229,
#   'fint': '2021-10-25T13:00:00',
#   'prec': 0.0,
#   'alt': 115.0,
#   'vmax': 8.8,
#   'vv': 6.6,
#   'dv': 66.0,
#   'lat': 28.318405,
#   'dmax': 75.0,
#   'ubi': 'TENERIFE-GÜIMAR',
#   'pres': 1005.8,
#   'hr': 64.0,
#   'pres_nmar': 1019.7,
#   'tamin': 22.8,
#   'ta': 23.2,
#   'tamax': 24.5,
#   'tpr': 16.0},
#  {'idema': 'C447A',
#   'lon': -16.329445,
#   'fint': '2021-10-25T13:00:00',
#   'prec': 0.0,
#   'alt': 632.0,
#   'vmax': 8.8,
#   'vv': 4.0,
#   'dv': 340.0,
#   'lat': 28.477497,
#   'dmax': 340.0,
#   'ubi': 'TENERIFE/LOS RODEOS',
#   'pres': 949.8,
#   'hr': 70.0,
#   'stdvv': 0.6,
#   'ts': 23.2,
#   'pres_nmar': 1019.8,
#   'tamin': 19.0,
#   'ta': 19.6,
#   'tamax': 20.6,
#   'tpr': 13.9,
#   'vis': 28.7,
#   'stddv': 11.0,
#   'inso': 19.0},
#  {'idema': 'C449C',
#   'lon': -16.255281,
#   'fint': '2021-10-25T13:00:00',
#   'prec': 0.0,
#   'alt': 35.0,
#   'vmax': 6.4,
#   'vv': 3.6,
#   'dv': 66.0,
#   'lat': 28.463337,
#   'dmax': 63.0,
#   'ubi': 'SANTA CRUZ DE TENERIFE ',
#   'pres': 1014.4,
#   'hr': 56.0,
#   'stdvv': 1.1,
#   'ts': 28.8,
#   'pres_nmar': 1019.8,
#   'tamin': 23.6,
#   'ta': 25.4,
#   'tamax': 25.5,
#   'tpr': 16.0,
#   'vis': 20.0,
#   'stddv': 21.0,
#   'inso': 39.7,
#   'tss5cm': 25.0,
#   'pacutp': 0.0,
#   'tss20cm': 23.2},
#  {'idema': 'C429I',
#   'lon': -16.561157,
#   'fint': '2021-10-25T14:00:00',
#   'prec': 0.0,
#   'alt': 64.0,
#   'vmax': 11.8,
#   'vv': 8.7,
#   'dv': 80.0,
#   'lat': 28.046991,
#   'dmax': 80.0,
#   'ubi': 'TENERIFE/SUR',
#   'pres': 1010.0,
#   'hr': 62.0,
#   'stdvv': 0.7,
#   'ts': 28.3,
#   'pres_nmar': 1018.9,
#   'tamin': 24.8,
#   'ta': 25.3,
#   'tamax': 25.6,
#   'tpr': 17.5,
#   'stddv': 7.0,
#   'inso': 49.0},
#  {'idema': 'C439J',
#   'lon': -16.382229,
#   'fint': '2021-10-25T14:00:00',
#   'prec': 0.0,
#   'alt': 115.0,
#   'vmax': 9.9,
#   'vv': 7.8,
#   'dv': 59.0,
#   'lat': 28.318405,
#   'dmax': 70.0,
#   'ubi': 'TENERIFE-GÜIMAR',
#   'pres': 1004.8,
#   'hr': 67.0,
#   'pres_nmar': 1018.7,
#   'tamin': 23.0,
#   'ta': 23.4,
#   'tamax': 24.3,
#   'tpr': 16.9},
#  {'idema': 'C447A',
#   'lon': -16.329445,
#   'fint': '2021-10-25T14:00:00',
#   'prec': 0.0,
#   'alt': 632.0,
#   'vmax': 8.2,
#   'vv': 4.9,
#   'dv': 340.0,
#   'lat': 28.477497,
#   'dmax': 340.0,
#   'ubi': 'TENERIFE/LOS RODEOS',
#   'pres': 949.0,
#   'hr': 71.0,
#   'stdvv': 0.4,
#   'ts': 25.6,
#   'pres_nmar': 1018.7,
#   'tamin': 19.5,
#   'ta': 20.2,
#   'tamax': 20.7,
#   'tpr': 14.8,
#   'vis': 28.4,
#   'stddv': 12.0,
#   'inso': 15.0},
#  {'idema': 'C449C',
#   'lon': -16.255281,
#   'fint': '2021-10-25T14:00:00',
#   'prec': 0.0,
#   'alt': 35.0,
#   'vmax': 7.1,
#   'vv': 2.7,
#   'dv': 36.0,
#   'lat': 28.463337,
#   'dmax': 3.0,
#   'ubi': 'SANTA CRUZ DE TENERIFE ',
#   'pres': 1013.6,
#   'hr': 58.0,
#   'stdvv': 1.4,
#   'ts': 25.4,
#   'pres_nmar': 1019.0,
#   'tamin': 24.6,
#   'ta': 24.6,
#   'tamax': 25.8,
#   'tpr': 15.8,
#   'vis': 20.0,
#   'stddv': 36.0,
#   'inso': 23.0,
#   'tss5cm': 27.2,
#   'pacutp': 0.0,
#   'tss20cm': 23.6},
#  {'idema': 'C429I',
#   'lon': -16.561157,
#   'fint': '2021-10-25T15:00:00',
#   'prec': 0.4,
#   'alt': 64.0,
#   'vmax': 11.3,
#   'vv': 7.2,
#   'dv': 70.0,
#   'lat': 28.046991,
#   'dmax': 90.0,
#   'ubi': 'TENERIFE/SUR',
#   'pres': 1009.9,
#   'hr': 76.0,
#   'stdvv': 0.5,
#   'ts': 22.8,
#   'pres_nmar': 1018.8,
#   'tamin': 22.6,
#   'ta': 22.6,
#   'tamax': 24.9,
#   'tpr': 18.2,
#   'stddv': 5.0,
#   'inso': 12.0},
#  {'idema': 'C439J',
#   'lon': -16.382229,
#   'fint': '2021-10-25T15:00:00',
#   'prec': 0.0,
#   'alt': 115.0,
#   'vmax': 9.9,
#   'vv': 8.2,
#   'dv': 52.0,
#   'lat': 28.318405,
#   'dmax': 61.0,
#   'ubi': 'TENERIFE-GÜIMAR',
#   'pres': 1004.4,
#   'hr': 60.0,
#   'pres_nmar': 1018.2,
#   'tamin': 23.3,
#   'ta': 24.0,
#   'tamax': 24.5,
#   'tpr': 15.8},
#  {'idema': 'C447A',
#   'lon': -16.329445,
#   'fint': '2021-10-25T15:00:00',
#   'prec': 0.0,
#   'alt': 632.0,
#   'vmax': 9.8,
#   'vv': 4.3,
#   'dv': 320.0,
#   'lat': 28.477497,
#   'dmax': 340.0,
#   'ubi': 'TENERIFE/LOS RODEOS',
#   'pres': 948.8,
#   'hr': 70.0,
#   'stdvv': 0.8,
#   'ts': 22.0,
#   'pres_nmar': 1018.7,
#   'tamin': 19.2,
#   'ta': 19.4,
#   'tamax': 21.6,
#   'tpr': 13.8,
#   'vis': 27.4,
#   'stddv': 100.0,
#   'inso': 27.0},
#  {'idema': 'C449C',
#   'lon': -16.255281,
#   'fint': '2021-10-25T15:00:00',
#   'prec': 0.0,
#   'alt': 35.0,
#   'vmax': 7.2,
#   'vv': 3.3,
#   'dv': 72.0,
#   'lat': 28.463337,
#   'dmax': 0.0,
#   'ubi': 'SANTA CRUZ DE TENERIFE ',
#   'pres': 1013.4,
#   'hr': 54.0,
#   'stdvv': 1.0,
#   'ts': 26.4,
#   'pres_nmar': 1018.8,
#   'tamin': 24.5,
#   'ta': 24.8,
#   'tamax': 25.5,
#   'tpr': 14.9,
#   'vis': 20.0,
#   'stddv': 21.0,
#   'inso': 43.7,
#   'tss5cm': 28.1,
#   'pacutp': 0.0,
#   'tss20cm': 24.2},
#  {'idema': 'C429I',
#   'lon': -16.561157,
#   'fint': '2021-10-25T16:00:00',
#   'prec': 0.0,
#   'alt': 64.0,
#   'vmax': 10.8,
#   'vv': 7.4,
#   'dv': 60.0,
#   'lat': 28.046991,
#   'dmax': 60.0,
#   'ubi': 'TENERIFE/SUR',
#   'pres': 1009.7,
#   'hr': 65.0,
#   'stdvv': 0.6,
#   'ts': 24.0,
#   'pres_nmar': 1018.6,
#   'tamin': 22.6,
#   'ta': 23.5,
#   'tamax': 23.5,
#   'tpr': 16.6,
#   'stddv': 6.0,
#   'inso': 0.0},
#  {'idema': 'C439J',
#   'lon': -16.382229,
#   'fint': '2021-10-25T16:00:00',
#   'prec': 0.0,
#   'alt': 115.0,
#   'vmax': 12.3,
#   'vv': 8.6,
#   'dv': 55.0,
#   'lat': 28.318405,
#   'dmax': 58.0,
#   'ubi': 'TENERIFE-GÜIMAR',
#   'pres': 1004.3,
#   'hr': 64.0,
#   'pres_nmar': 1018.2,
#   'tamin': 23.1,
#   'ta': 23.3,
#   'tamax': 25.5,
#   'tpr': 16.1},
#  {'idema': 'C447A',
#   'lon': -16.329445,
#   'fint': '2021-10-25T16:00:00',
#   'prec': 0.0,
#   'alt': 632.0,
#   'vmax': 9.3,
#   'vv': 6.2,
#   'dv': 330.0,
#   'lat': 28.477497,
#   'dmax': 320.0,
#   'ubi': 'TENERIFE/LOS RODEOS',
#   'pres': 948.8,
#   'hr': 79.0,
#   'stdvv': 0.7,
#   'ts': 20.9,
#   'pres_nmar': 1018.8,
#   'tamin': 18.6,
#   'ta': 18.8,
#   'tamax': 20.4,
#   'tpr': 15.1,
#   'vis': 25.7,
#   'stddv': 8.0,
#   'inso': 4.0},
#  {'idema': 'C449C',
#   'lon': -16.255281,
#   'fint': '2021-10-25T16:00:00',
#   'prec': 0.2,
#   'alt': 35.0,
#   'vmax': 7.7,
#   'vv': 3.4,
#   'dv': 13.0,
#   'lat': 28.463337,
#   'dmax': 90.0,
#   'ubi': 'SANTA CRUZ DE TENERIFE ',
#   'pres': 1013.5,
#   'hr': 66.0,
#   'stdvv': 1.4,
#   'ts': 23.5,
#   'pres_nmar': 1018.9,
#   'tamin': 23.3,
#   'ta': 23.3,
#   'tamax': 24.8,
#   'tpr': 16.6,
#   'vis': 15.1,
#   'stddv': 37.0,
#   'inso': 13.3,
#   'tss5cm': 27.4,
#   'pacutp': 0.17,
#   'tss20cm': 24.5},
#  {'idema': 'C429I',
#   'lon': -16.561157,
#   'fint': '2021-10-25T17:00:00',
#   'prec': 0.0,
#   'alt': 64.0,
#   'vmax': 10.8,
#   'vv': 8.3,
#   'dv': 60.0,
#   'lat': 28.046991,
#   'dmax': 60.0,
#   'ubi': 'TENERIFE/SUR',
#   'pres': 1009.8,
#   'hr': 67.0,
#   'stdvv': 0.7,
#   'ts': 24.1,
#   'pres_nmar': 1018.7,
#   'tamin': 23.4,
#   'ta': 23.4,
#   'tamax': 23.8,
#   'tpr': 16.9,
#   'stddv': 6.0,
#   'inso': 1.0},
#  {'idema': 'C439J',
#   'lon': -16.382229,
#   'fint': '2021-10-25T17:00:00',
#   'prec': 0.0,
#   'alt': 115.0,
#   'vmax': 10.7,
#   'vv': 7.9,
#   'dv': 59.0,
#   'lat': 28.318405,
#   'dmax': 61.0,
#   'ubi': 'TENERIFE-GÜIMAR',
#   'pres': 1004.4,
#   'hr': 69.0,
#   'pres_nmar': 1018.3,
#   'tamin': 22.3,
#   'ta': 22.6,
#   'tamax': 24.2,
#   'tpr': 16.6},
#  {'idema': 'C447A',
#   'lon': -16.329445,
#   'fint': '2021-10-25T17:00:00',
#   'prec': 0.0,
#   'alt': 632.0,
#   'vmax': 8.8,
#   'vv': 6.0,
#   'dv': 340.0,
#   'lat': 28.477497,
#   'dmax': 340.0,
#   'ubi': 'TENERIFE/LOS RODEOS',
#   'pres': 948.7,
#   'hr': 80.0,
#   'stdvv': 0.5,
#   'ts': 18.7,
#   'pres_nmar': 1019.0,
#   'tamin': 17.9,
#   'ta': 18.0,
#   'tamax': 18.9,
#   'tpr': 14.5,
#   'vis': 28.5,
#   'stddv': 6.0,
#   'inso': 0.0},
#  {'idema': 'C449C',
#   'lon': -16.255281,
#   'fint': '2021-10-25T17:00:00',
#   'prec': 0.0,
#   'alt': 35.0,
#   'vmax': 8.8,
#   'vv': 5.0,
#   'dv': 4.0,
#   'lat': 28.463337,
#   'dmax': 15.0,
#   'ubi': 'SANTA CRUZ DE TENERIFE ',
#   'pres': 1013.2,
#   'hr': 60.0,
#   'stdvv': 1.6,
#   'ts': 23.4,
#   'pres_nmar': 1018.6,
#   'tamin': 22.7,
#   'ta': 23.5,
#   'tamax': 23.7,
#   'tpr': 15.3,
#   'vis': 20.0,
#   'stddv': 22.0,
#   'inso': 23.8,
#   'tss5cm': 25.8,
#   'pacutp': 0.12,
#   'tss20cm': 24.6},
#  {'idema': 'C429I',
#   'lon': -16.561157,
#   'fint': '2021-10-25T18:00:00',
#   'prec': 0.0,
#   'alt': 64.0,
#   'vmax': 11.3,
#   'vv': 6.4,
#   'dv': 60.0,
#   'lat': 28.046991,
#   'dmax': 70.0,
#   'ubi': 'TENERIFE/SUR',
#   'pres': 1010.1,
#   'hr': 68.0,
#   'stdvv': 0.6,
#   'ts': 23.2,
#   'pres_nmar': 1019.0,
#   'tamin': 22.9,
#   'ta': 22.9,
#   'tamax': 23.4,
#   'tpr': 16.6,
#   'stddv': 5.0,
#   'inso': 0.0},
#  {'idema': 'C439J',
#   'lon': -16.382229,
#   'fint': '2021-10-25T18:00:00',
#   'prec': 0.0,
#   'alt': 115.0,
#   'vmax': 10.7,
#   'vv': 8.9,
#   'dv': 34.0,
#   'lat': 28.318405,
#   'dmax': 58.0,
#   'ubi': 'TENERIFE-GÜIMAR',
#   'pres': 1004.5,
#   'hr': 58.0,
#   'pres_nmar': 1018.4,
#   'tamin': 22.2,
#   'ta': 22.4,
#   'tamax': 23.0,
#   'tpr': 13.8},
#  {'idema': 'C447A',
#   'lon': -16.329445,
#   'fint': '2021-10-25T18:00:00',
#   'prec': 0.0,
#   'alt': 632.0,
#   'vmax': 9.3,
#   'vv': 5.4,
#   'dv': 330.0,
#   'lat': 28.477497,
#   'dmax': 330.0,
#   'ubi': 'TENERIFE/LOS RODEOS',
#   'pres': 949.0,
#   'hr': 83.0,
#   'stdvv': 0.9,
#   'ts': 17.5,
#   'pres_nmar': 1019.4,
#   'tamin': 17.5,
#   'ta': 17.6,
#   'tamax': 18.2,
#   'tpr': 14.7,
#   'vis': 24.8,
#   'stddv': 12.0,
#   'inso': 0.0},
#  {'idema': 'C449C',
#   'lon': -16.255281,
#   'fint': '2021-10-25T18:00:00',
#   'prec': 0.0,
#   'alt': 35.0,
#   'vmax': 9.1,
#   'vv': 3.7,
#   'dv': 7.0,
#   'lat': 28.463337,
#   'dmax': 355.0,
#   'ubi': 'SANTA CRUZ DE TENERIFE ',
#   'pres': 1013.6,
#   'hr': 60.0,
#   'stdvv': 1.1,
#   'ts': 23.2,
#   'pres_nmar': 1019.0,
#   'tamin': 23.1,
#   'ta': 23.1,
#   'tamax': 23.6,
#   'tpr': 14.9,
#   'vis': 20.0,
#   'stddv': 21.0,
#   'inso': 20.5,
#   'tss5cm': 24.8,
#   'pacutp': 0.0,
#   'tss20cm': 24.5},
#  {'idema': 'C429I',
#   'lon': -16.561157,
#   'fint': '2021-10-25T19:00:00',
#   'prec': 0.0,
#   'alt': 64.0,
#   'vmax': 8.8,
#   'vv': 4.7,
#   'dv': 50.0,
#   'lat': 28.046991,
#   'dmax': 60.0,
#   'ubi': 'TENERIFE/SUR',
#   'pres': 1010.4,
#   'hr': 68.0,
#   'stdvv': 1.1,
#   'ts': 22.8,
#   'pres_nmar': 1019.4,
#   'tamin': 22.7,
#   'ta': 22.8,
#   'tamax': 22.9,
#   'tpr': 16.6,
#   'stddv': 5.0,
#   'inso': 0.0},
#  {'idema': 'C439J',
#   'lon': -16.382229,
#   'fint': '2021-10-25T19:00:00',
#   'prec': 0.0,
#   'alt': 115.0,
#   'vmax': 10.8,
#   'vv': 8.2,
#   'dv': 34.0,
#   'lat': 28.318405,
#   'dmax': 42.0,
#   'ubi': 'TENERIFE-GÜIMAR',
#   'pres': 1004.9,
#   'hr': 61.0,
#   'pres_nmar': 1018.9,
#   'tamin': 21.9,
#   'ta': 21.9,
#   'tamax': 22.4,
#   'tpr': 14.0},
#  {'idema': 'C447A',
#   'lon': -16.329445,
#   'fint': '2021-10-25T19:00:00',
#   'prec': 0.0,
#   'alt': 632.0,
#   'vmax': 8.8,
#   'vv': 4.7,
#   'dv': 310.0,
#   'lat': 28.477497,
#   'dmax': 350.0,
#   'ubi': 'TENERIFE/LOS RODEOS',
#   'pres': 949.5,
#   'hr': 86.0,
#   'stdvv': 0.5,
#   'ts': 16.7,
#   'pres_nmar': 1020.0,
#   'tamin': 17.0,
#   'ta': 17.1,
#   'tamax': 17.6,
#   'tpr': 14.7,
#   'vis': 22.6,
#   'stddv': 9.0,
#   'inso': 0.0},
#  {'idema': 'C449C',
#   'lon': -16.255281,
#   'fint': '2021-10-25T19:00:00',
#   'prec': 0.0,
#   'alt': 35.0,
#   'vmax': 8.5,
#   'vv': 3.7,
#   'dv': 40.0,
#   'lat': 28.463337,
#   'dmax': 350.0,
#   'ubi': 'SANTA CRUZ DE TENERIFE ',
#   'pres': 1014.1,
#   'hr': 63.0,
#   'stdvv': 1.0,
#   'ts': 22.6,
#   'pres_nmar': 1019.5,
#   'tamin': 22.7,
#   'ta': 22.7,
#   'tamax': 23.1,
#   'tpr': 15.3,
#   'vis': 20.0,
#   'stddv': 16.0,
#   'inso': 0.0,
#   'tss5cm': 23.9,
#   'pacutp': 0.0,
#   'tss20cm': 24.4}]

# %%
df_idemas = pd.DataFrame(tenerife_list)
df_idemas = df_idemas[['idema', 'ubi', 'lat', 'lon']]
df_idemas = df_idemas.drop_duplicates(subset = ["ubi"])

# %%
df_idemas
# Out:
#    idema                      ubi        lat        lon
# 0  C429I             TENERIFE/SUR  28.046991 -16.561157
# 1  C439J          TENERIFE-GÜIMAR  28.318405 -16.382229
# 2  C447A      TENERIFE/LOS RODEOS  28.477497 -16.329445
# 3  C449C  SANTA CRUZ DE TENERIFE   28.463337 -16.255281

# %%
df_idemas.to_csv(DATA_PATH+'idemas.csv', index = False)

# %% [markdown]
# ## Valores Climatológicos

# %%
# valores climatológicos
fechaini = '2019-01-01T00:00:00UTC'
fechafin = '2019-12-31T00:00:00UTC'
idema = 'C429I,C439J,C449C,C447A' #aquí podría hacer un bucle
api = '/api/valores/climatologicos/diarios/datos/fechaini/'+fechaini+'/fechafin/'+fechafin+'/estacion/'+idema

response = requests.request("GET", url+api, headers=headers, params=querystring)

print(response.text)


if response.status_code == 200:
    valores_climatologicos = get_data( response)
else:
    print(response)
    
valores_climatologicos

# create dataframe
# export to csv.
# Out:
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/679b5b5d",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# [{'fecha': '2019-01-01',
#   'indicativo': 'C447A',
#   'nombre': 'TENERIFE NORTE AEROPUERTO',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '632',
#   'tmed': '15,0',
#   'prec': '0,0',
#   'tmin': '10,4',
#   'horatmin': '07:56',
#   'tmax': '19,5',
#   'horatmax': '15:30',
#   'dir': '16',
#   'velmedia': '3,9',
#   'racha': '11,4',
#   'horaracha': '10:11',
#   'sol': '5,5',
#   'presMax': '956,5',
#   'horaPresMax': 'Varias',
#   'presMin': '951,2',
#   'horaPresMin': '01'},
#  {'fecha': '2019-01-01',
#   'indicativo': 'C449C',
#   'nombre': 'STA.CRUZ DE TENERIFE',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '35',
#   'tmed': '19,6',
#   'prec': '0,0',
#   'tmin': '15,0',
#   'horatmin': '07:00',
#   'tmax': '24,2',
#   'horatmax': '15:20',
#   'dir': '20',
#   'velmedia': '3,1',
#   'racha': '8,6',
#   'horaracha': '13:00',
#   'sol': '9,3',
#   'presMax': '1023,3',
#   'horaPresMax': 'Varias',
#   'presMin': '1018,1',
#   'horaPresMin': '01'},
#  {'fecha': '2019-01-01',
#   'indicativo': 'C429I',
#   'nombre': 'TENERIFE SUR AEROPUERTO',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '64',
#   'tmed': '19,2',
#   'prec': '0,0',
#   'tmin': '15,1',
#   'horatmin': '06:54',
#   'tmax': '23,3',
#   'horatmax': '13:05',
#   'dir': '03',
#   'velmedia': '4,4',
#   'racha': '8,9',
#   'horaracha': '20:50',
#   'sol': '9,6',
#   'presMax': '1018,3',
#   'horaPresMax': 'Varias',
#   'presMin': '1013,0',
#   'horaPresMin': '05'},
#  {'fecha': '2019-01-01',
#   'indicativo': 'C439J',
#   'nombre': 'GÜÍMAR',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '115',
#   'tmed': '16,6',
#   'prec': '0,0',
#   'tmin': '10,5',
#   'horatmin': '05:50',
#   'tmax': '22,6',
#   'horatmax': '17:00',
#   'presMax': '1013,7',
#   'horaPresMax': '22',
#   'presMin': '1008,4',
#   'horaPresMin': '05'},
#  {'fecha': '2019-01-02',
#   'indicativo': 'C447A',
#   'nombre': 'TENERIFE NORTE AEROPUERTO',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '632',
#   'tmed': '14,6',
#   'prec': '0,0',
#   'tmin': '10,9',
#   'horatmin': '23:30',
#   'tmax': '18,2',
#   'horatmax': '12:28',
#   'dir': '14',
#   'velmedia': '3,1',
#   'racha': '7,8',
#   'horaracha': '00:47',
#   'sol': '6,3',
#   'presMax': '957,5',
#   'horaPresMax': 'Varias',
#   'presMin': '954,5',
#   'horaPresMin': '24'},
#  {'fecha': '2019-01-02',
#   'indicativo': 'C449C',
#   'nombre': 'STA.CRUZ DE TENERIFE',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '35',
#   'tmed': '18,6',
#   'prec': '0,0',
#   'tmin': '15,8',
#   'horatmin': '07:30',
#   'tmax': '21,5',
#   'horatmax': '14:50',
#   'dir': '09',
#   'velmedia': '2,8',
#   'racha': '7,8',
#   'horaracha': '14:00',
#   'sol': '9,7',
#   'presMax': '1024,6',
#   'horaPresMax': 'Varias',
#   'presMin': '1021,7',
#   'horaPresMin': '24'},
#  {'fecha': '2019-01-02',
#   'indicativo': 'C429I',
#   'nombre': 'TENERIFE SUR AEROPUERTO',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '64',
#   'tmed': '19,0',
#   'prec': '0,0',
#   'tmin': '15,1',
#   'horatmin': '05:39',
#   'tmax': '22,8',
#   'horatmax': '13:58',
#   'dir': '05',
#   'velmedia': '5,8',
#   'racha': '11,4',
#   'horaracha': '23:31',
#   'sol': '9,9',
#   'presMax': '1020,4',
#   'horaPresMax': 'Varias',
#   'presMin': '1016,3',
#   'horaPresMin': '24'},
#  {'fecha': '2019-01-02',
#   'indicativo': 'C439J',
#   'nombre': 'GÜÍMAR',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '115',
#   'tmed': '17,0',
#   'prec': '0,0',
#   'tmin': '13,0',
#   'horatmin': '07:30',
#   'tmax': '21,1',
#   'horatmax': '13:30',
#   'dir': '99',
#   'velmedia': '1,9',
#   'racha': '6,4',
#   'horaracha': 'Varias',
#   'presMax': '1015,0',
#   'horaPresMax': '10',
#   'presMin': '1012,2',
#   'horaPresMin': 'Varias'},
#  {'fecha': '2019-01-03',
#   'indicativo': 'C447A',
#   'nombre': 'TENERIFE NORTE AEROPUERTO',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '632',
#   'tmed': '13,5',
#   'prec': '0,0',
#   'tmin': '11,1',
#   'horatmin': '06:48',
#   'tmax': '15,9',
#   'horatmax': '12:42',
#   'dir': '10',
#   'velmedia': '4,2',
#   'racha': '8,3',
#   'horaracha': 'Varias',
#   'sol': '6,0',
#   'presMax': '954,8',
#   'horaPresMax': 'Varias',
#   'presMin': '951,6',
#   'horaPresMin': '16'},
#  {'fecha': '2019-01-03',
#   'indicativo': 'C449C',
#   'nombre': 'STA.CRUZ DE TENERIFE',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '35',
#   'tmed': '18,0',
#   'prec': '0,0',
#   'tmin': '15,0',
#   'horatmin': '05:40',
#   'tmax': '20,9',
#   'horatmax': '13:40',
#   'dir': '07',
#   'velmedia': '2,8',
#   'racha': '7,2',
#   'horaracha': '18:30',
#   'sol': '8,8',
#   'presMax': '1022,3',
#   'horaPresMax': '11',
#   'presMin': '1018,7',
#   'horaPresMin': '16'},
#  {'fecha': '2019-01-03',
#   'indicativo': 'C429I',
#   'nombre': 'TENERIFE SUR AEROPUERTO',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '64',
#   'tmed': '18,0',
#   'prec': '0,0',
#   'tmin': '14,5',
#   'horatmin': '07:03',
#   'tmax': '21,6',
#   'horatmax': '12:45',
#   'dir': '08',
#   'velmedia': '6,7',
#   'racha': '11,7',
#   'horaracha': '11:33',
#   'sol': '9,9',
#   'presMax': '1017,3',
#   'horaPresMax': 'Varias',
#   'presMin': '1013,9',
#   'horaPresMin': '15'},
#  {'fecha': '2019-01-03',
#   'indicativo': 'C439J',
#   'nombre': 'GÜÍMAR',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '115',
#   'tmed': '17,0',
#   'prec': '0,0',
#   'tmin': '14,3',
#   'horatmin': '07:40',
#   'tmax': '19,7',
#   'horatmax': '14:00',
#   'velmedia': '2,2',
#   'presMax': '1012,6',
#   'horaPresMax': '11',
#   'presMin': '1009,2',
#   'horaPresMin': '16'},
#  {'fecha': '2019-01-04',
#   'indicativo': 'C447A',
#   'nombre': 'TENERIFE NORTE AEROPUERTO',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '632',
#   'tmed': '12,8',
#   'prec': '0,0',
#   'tmin': '9,9',
#   'horatmin': '22:30',
#   'tmax': '15,6',
#   'horatmax': '14:23',
#   'dir': '99',
#   'velmedia': '3,6',
#   'racha': '8,3',
#   'horaracha': 'Varias',
#   'sol': '2,3',
#   'presMax': '954,9',
#   'horaPresMax': 'Varias',
#   'presMin': '951,3',
#   'horaPresMin': '05'},
#  {'fecha': '2019-01-04',
#   'indicativo': 'C449C',
#   'nombre': 'STA.CRUZ DE TENERIFE',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '35',
#   'tmed': '18,0',
#   'prec': '0,0',
#   'tmin': '15,5',
#   'horatmin': '23:59',
#   'tmax': '20,4',
#   'horatmax': 'Varias',
#   'dir': '09',
#   'velmedia': '2,5',
#   'racha': '6,9',
#   'horaracha': '11:30',
#   'sol': '5,8',
#   'presMax': '1022,3',
#   'horaPresMax': '23',
#   'presMin': '1018,6',
#   'horaPresMin': '05'},
#  {'fecha': '2019-01-04',
#   'indicativo': 'C429I',
#   'nombre': 'TENERIFE SUR AEROPUERTO',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '64',
#   'tmed': '18,0',
#   'prec': '0,0',
#   'tmin': '14,8',
#   'horatmin': 'Varias',
#   'tmax': '21,2',
#   'horatmax': '14:08',
#   'dir': '99',
#   'velmedia': '4,2',
#   'racha': '11,7',
#   'horaracha': 'Varias',
#   'sol': '9,2',
#   'presMax': '1017,3',
#   'horaPresMax': 'Varias',
#   'presMin': '1013,4',
#   'horaPresMin': '06'},
#  {'fecha': '2019-01-04',
#   'indicativo': 'C439J',
#   'nombre': 'GÜÍMAR',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '115',
#   'tmed': '16,4',
#   'prec': '0,0',
#   'tmin': '13,5',
#   'horatmin': '23:59',
#   'tmax': '19,3',
#   'horatmax': '14:30',
#   'velmedia': '1,9',
#   'presMax': '1012,6',
#   'horaPresMax': '23',
#   'presMin': '1009,0',
#   'horaPresMin': '05'},
#  {'fecha': '2019-01-05',
#   'indicativo': 'C447A',
#   'nombre': 'TENERIFE NORTE AEROPUERTO',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '632',
#   'tmed': '14,2',
#   'prec': '0,0',
#   'tmin': '10,8',
#   'horatmin': '04:05',
#   'tmax': '17,7',
#   'horatmax': '15:55',
#   'dir': '12',
#   'velmedia': '3,9',
#   'racha': '10,3',
#   'horaracha': '14:24',
#   'sol': '2,2',
#   'presMax': '955,6',
#   'horaPresMax': 'Varias',
#   'presMin': '953,1',
#   'horaPresMin': '14'},
#  {'fecha': '2019-01-05',
#   'indicativo': 'C449C',
#   'nombre': 'STA.CRUZ DE TENERIFE',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '35',
#   'tmed': '18,4',
#   'prec': '0,0',
#   'tmin': '15,0',
#   'horatmin': '03:30',
#   'tmax': '21,7',
#   'horatmax': '15:40',
#   'dir': '09',
#   'velmedia': '1,4',
#   'racha': '5,6',
#   'horaracha': '12:40',
#   'sol': '6,9',
#   'presMax': '1023,2',
#   'horaPresMax': '10',
#   'presMin': '1020,3',
#   'horaPresMin': '16'},
#  {'fecha': '2019-01-05',
#   'indicativo': 'C429I',
#   'nombre': 'TENERIFE SUR AEROPUERTO',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '64',
#   'tmed': '19,4',
#   'prec': '0,0',
#   'tmin': '14,8',
#   'horatmin': 'Varias',
#   'tmax': '24,0',
#   'horatmax': '12:48',
#   'dir': '99',
#   'velmedia': '5,0',
#   'racha': '9,2',
#   'horaracha': 'Varias',
#   'sol': '6,7',
#   'presMax': '1017,9',
#   'horaPresMax': 'Varias',
#   'presMin': '1015,4',
#   'horaPresMin': '05'},
#  {'fecha': '2019-01-05',
#   'indicativo': 'C439J',
#   'nombre': 'GÜÍMAR',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '115',
#   'tmed': '17,6',
#   'prec': '0,0',
#   'tmin': '12,4',
#   'horatmin': '05:30',
#   'tmax': '22,9',
#   'horatmax': '16:00',
#   'presMax': '1013,5',
#   'horaPresMax': '10',
#   'presMin': '1010,5',
#   'horaPresMin': '16'},
#  {'fecha': '2019-01-06',
#   'indicativo': 'C447A',
#   'nombre': 'TENERIFE NORTE AEROPUERTO',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '632',
#   'tmed': '14,2',
#   'prec': '0,0',
#   'tmin': '10,6',
#   'horatmin': '02:22',
#   'tmax': '17,7',
#   'horatmax': '12:29',
#   'dir': '16',
#   'velmedia': '6,4',
#   'racha': '14,4',
#   'horaracha': '13:26',
#   'sol': '6,5',
#   'presMax': '955,2',
#   'horaPresMax': 'Varias',
#   'presMin': '953,0',
#   'horaPresMin': '14'},
#  {'fecha': '2019-01-06',
#   'indicativo': 'C449C',
#   'nombre': 'STA.CRUZ DE TENERIFE',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '35',
#   'tmed': '19,2',
#   'prec': '0,0',
#   'tmin': '15,6',
#   'horatmin': '02:20',
#   'tmax': '22,7',
#   'horatmax': '13:50',
#   'dir': '10',
#   'velmedia': '4,4',
#   'racha': '10,0',
#   'horaracha': '06:30',
#   'sol': '9,5',
#   'presMax': '1022,5',
#   'horaPresMax': '10',
#   'presMin': '1020,3',
#   'horaPresMin': '15'},
#  {'fecha': '2019-01-06',
#   'indicativo': 'C429I',
#   'nombre': 'TENERIFE SUR AEROPUERTO',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '64',
#   'tmed': '19,0',
#   'prec': '0,0',
#   'tmin': '15,8',
#   'horatmin': '08:00',
#   'tmax': '22,3',
#   'horatmax': '12:27',
#   'dir': '99',
#   'velmedia': '5,8',
#   'racha': '15,0',
#   'horaracha': 'Varias',
#   'sol': '9,8',
#   'presMax': '1018,4',
#   'horaPresMax': 'Varias',
#   'presMin': '1015,6',
#   'horaPresMin': '17'},
#  {'fecha': '2019-01-06',
#   'indicativo': 'C439J',
#   'nombre': 'GÜÍMAR',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '115',
#   'tmed': '16,8',
#   'prec': '0,0',
#   'tmin': '11,5',
#   'horatmin': '08:30',
#   'tmax': '22,0',
#   'horatmax': '13:00',
#   'presMax': '1012,9',
#   'horaPresMax': '00',
#   'presMin': '1010,5',
#   'horaPresMin': 'Varias'},
#  {'fecha': '2019-01-07',
#   'indicativo': 'C447A',
#   'nombre': 'TENERIFE NORTE AEROPUERTO',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '632',
#   'tmed': '14,0',
#   'prec': '0,0',
#   'tmin': '11,4',
#   'horatmin': '00:44',
#   'tmax': '16,5',
#   'horatmax': '12:46',
#   'dir': '99',
#   'velmedia': '5,6',
#   'racha': '10,8',
#   'horaracha': 'Varias',
#   'sol': '3,2',
#   'presMax': '955,0',
#   'horaPresMax': '10',
#   'presMin': '952,1',
#   'horaPresMin': '15'},
#  {'fecha': '2019-01-07',
#   'indicativo': 'C449C',
#   'nombre': 'STA.CRUZ DE TENERIFE',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '35',
#   'tmed': '18,9',
#   'prec': '0,0',
#   'tmin': '16,1',
#   'horatmin': '04:00',
#   'tmax': '21,7',
#   'horatmax': '15:30',
#   'dir': '09',
#   'velmedia': '4,2',
#   'racha': '8,9',
#   'horaracha': '10:30',
#   'sol': '6,8',
#   'presMax': '1022,2',
#   'horaPresMax': '10',
#   'presMin': '1019,3',
#   'horaPresMin': '16'},
#  {'fecha': '2019-01-07',
#   'indicativo': 'C429I',
#   'nombre': 'TENERIFE SUR AEROPUERTO',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '64',
#   'tmed': '20,0',
#   'prec': '0,0',
#   'tmin': '16,7',
#   'horatmin': '08:11',
#   'tmax': '23,2',
#   'horatmax': '12:42',
#   'dir': '09',
#   'velmedia': '5,8',
#   'racha': '13,3',
#   'horaracha': '13:31',
#   'sol': '7,2',
#   'presMax': '1017,3',
#   'horaPresMax': 'Varias',
#   'presMin': '1013,9',
#   'horaPresMin': '20'},
#  {'fecha': '2019-01-07',
#   'indicativo': 'C439J',
#   'nombre': 'GÜÍMAR',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '115',
#   'tmed': '17,0',
#   'prec': '0,0',
#   'tmin': '13,7',
#   'horatmin': '01:30',
#   'tmax': '20,2',
#   'horatmax': '12:50',
#   'dir': '05',
#   'velmedia': '3,3',
#   'racha': '7,5',
#   'horaracha': '15:50',
#   'presMax': '1012,6',
#   'horaPresMax': '00',
#   'presMin': '1009,5',
#   'horaPresMin': '16'},
#  {'fecha': '2019-01-08',
#   'indicativo': 'C447A',
#   'nombre': 'TENERIFE NORTE AEROPUERTO',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '632',
#   'tmed': '13,4',
#   'prec': 'Ip',
#   'tmin': '10,8',
#   'horatmin': '05:12',
#   'tmax': '16,1',
#   'horatmax': '12:24',
#   'dir': '99',
#   'velmedia': '4,4',
#   'racha': '8,3',
#   'horaracha': 'Varias',
#   'sol': '2,3',
#   'presMax': '953,5',
#   'horaPresMax': 'Varias',
#   'presMin': '950,4',
#   'horaPresMin': '15'},
#  {'fecha': '2019-01-08',
#   'indicativo': 'C449C',
#   'nombre': 'STA.CRUZ DE TENERIFE',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '35',
#   'tmed': '18,0',
#   'prec': '0,0',
#   'tmin': '15,6',
#   'horatmin': '07:40',
#   'tmax': '20,5',
#   'horatmax': '13:10',
#   'dir': '12',
#   'velmedia': '2,8',
#   'racha': '5,8',
#   'horaracha': '15:00',
#   'sol': '6,2',
#   'presMax': '1020,6',
#   'horaPresMax': '10',
#   'presMin': '1017,5',
#   'horaPresMin': '16'},
#  {'fecha': '2019-01-08',
#   'indicativo': 'C429I',
#   'nombre': 'TENERIFE SUR AEROPUERTO',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '64',
#   'tmed': '19,2',
#   'prec': '0,0',
#   'tmin': '15,1',
#   'horatmin': 'Varias',
#   'tmax': '23,3',
#   'horatmax': '13:11',
#   'dir': '99',
#   'velmedia': '6,4',
#   'racha': '10,8',
#   'horaracha': 'Varias',
#   'sol': '7,7',
#   'presMax': '1015,4',
#   'horaPresMax': 'Varias',
#   'presMin': '1012,2',
#   'horaPresMin': '15'},
#  {'fecha': '2019-01-08',
#   'indicativo': 'C439J',
#   'nombre': 'GÜÍMAR',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '115',
#   'tmed': '16,3',
#   'prec': '0,0',
#   'tmin': '13,1',
#   'horatmin': '07:00',
#   'tmax': '19,5',
#   'horatmax': '14:00',
#   'velmedia': '2,2',
#   'presMax': '1010,9',
#   'horaPresMax': '11',
#   'presMin': '1007,8',
#   'horaPresMin': '16'},
#  {'fecha': '2019-01-09',
#   'indicativo': 'C447A',
#   'nombre': 'TENERIFE NORTE AEROPUERTO',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '632',
#   'tmed': '12,9',
#   'prec': '0,0',
#   'tmin': '9,2',
#   'horatmin': '03:57',
#   'tmax': '16,6',
#   'horatmax': '14:45',
#   'dir': '25',
#   'velmedia': '2,2',
#   'racha': '7,2',
#   'horaracha': '22:06',
#   'sol': '4,2',
#   'presMax': '951,4',
#   'horaPresMax': 'Varias',
#   'presMin': '948,0',
#   'horaPresMin': '16'},
#  {'fecha': '2019-01-09',
#   'indicativo': 'C449C',
#   'nombre': 'STA.CRUZ DE TENERIFE',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '35',
#   'tmed': '17,6',
#   'prec': '0,0',
#   'tmin': '14,9',
#   'horatmin': '23:50',
#   'tmax': '20,3',
#   'horatmax': '13:40',
#   'dir': '09',
#   'velmedia': '2,5',
#   'racha': '6,7',
#   'horaracha': '12:30',
#   'sol': '8,1',
#   'presMax': '1018,4',
#   'horaPresMax': 'Varias',
#   'presMin': '1014,8',
#   'horaPresMin': 'Varias'},
#  {'fecha': '2019-01-09',
#   'indicativo': 'C429I',
#   'nombre': 'TENERIFE SUR AEROPUERTO',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '64',
#   'tmed': '18,4',
#   'prec': '0,0',
#   'tmin': '14,7',
#   'horatmin': '23:59',
#   'tmax': '22,0',
#   'horatmax': '12:43',
#   'dir': '07',
#   'velmedia': '5,3',
#   'racha': '11,7',
#   'horaracha': '12:11',
#   'sol': '9,8',
#   'presMax': '1013,4',
#   'horaPresMax': '00',
#   'presMin': '1009,9',
#   'horaPresMin': '16'},
#  {'fecha': '2019-01-09',
#   'indicativo': 'C439J',
#   'nombre': 'GÜÍMAR',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '115',
#   'tmed': '15,8',
#   'prec': '0,0',
#   'tmin': '12,3',
#   'horatmin': '03:00',
#   'tmax': '19,4',
#   'horatmax': '13:30',
#   'presMax': '1008,8',
#   'horaPresMax': '00',
#   'presMin': '1005,2',
#   'horaPresMin': '16'},
#  {'fecha': '2019-01-10',
#   'indicativo': 'C447A',
#   'nombre': 'TENERIFE NORTE AEROPUERTO',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '632',
#   'tmed': '12,3',
#   'prec': '0,0',
#   'tmin': '8,5',
#   'horatmin': 'Varias',
#   'tmax': '16,1',
#   'horatmax': '15:30',
#   'dir': '28',
#   'velmedia': '3,6',
#   'racha': '8,3',
#   'horaracha': '00:47',
#   'sol': '6,7',
#   'presMax': '949,5',
#   'horaPresMax': 'Varias',
#   'presMin': '946,5',
#   'horaPresMin': '16'},
#  {'fecha': '2019-01-10',
#   'indicativo': 'C449C',
#   'nombre': 'STA.CRUZ DE TENERIFE',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '35',
#   'tmed': '17,1',
#   'prec': '0,0',
#   'tmin': '13,8',
#   'horatmin': 'Varias',
#   'tmax': '20,4',
#   'horatmax': '14:00',
#   'dir': '10',
#   'velmedia': '5,0',
#   'racha': '9,4',
#   'horaracha': '12:50',
#   'sol': '9,3',
#   'presMax': '1016,5',
#   'horaPresMax': '10',
#   'presMin': '1013,1',
#   'horaPresMin': '16'},
#  {'fecha': '2019-01-10',
#   'indicativo': 'C429I',
#   'nombre': 'TENERIFE SUR AEROPUERTO',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '64',
#   'tmed': '17,4',
#   'prec': '0,0',
#   'tmin': '13,6',
#   'horatmin': '05:04',
#   'tmax': '21,1',
#   'horatmax': '14:28',
#   'dir': '11',
#   'velmedia': '5,8',
#   'racha': '11,7',
#   'horaracha': '13:42',
#   'sol': '9,6',
#   'presMax': '1011,8',
#   'horaPresMax': 'Varias',
#   'presMin': '1008,5',
#   'horaPresMin': '16'},
#  {'fecha': '2019-01-10',
#   'indicativo': 'C439J',
#   'nombre': 'GÜÍMAR',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '115',
#   'tmed': '15,3',
#   'prec': '0,0',
#   'tmin': '11,7',
#   'horatmin': '03:30',
#   'tmax': '18,9',
#   'horatmax': '12:40',
#   'velmedia': '2,8',
#   'presMax': '1006,9',
#   'horaPresMax': '10',
#   'presMin': '1003,8',
#   'horaPresMin': 'Varias'},
#  {'fecha': '2019-01-11',
#   'indicativo': 'C447A',
#   'nombre': 'TENERIFE NORTE AEROPUERTO',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '632',
#   'tmed': '12,4',
#   'prec': '0,0',
#   'tmin': '8,8',
#   'horatmin': '02:31',
#   'tmax': '16,1',
#   'horatmax': '13:32',
#   'dir': '12',
#   'velmedia': '3,1',
#   'racha': '9,2',
#   'horaracha': '23:41',
#   'sol': '2,3',
#   'presMax': '949,1',
#   'horaPresMax': 'Varias',
#   'presMin': '946,4',
#   'horaPresMin': '05'},
#  {'fecha': '2019-01-11',
#   'indicativo': 'C449C',
#   'nombre': 'STA.CRUZ DE TENERIFE',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '35',
#   'tmed': '17,4',
#   'prec': '0,0',
#   'tmin': '14,5',
#   'horatmin': '03:50',
#   'tmax': '20,4',
#   'horatmax': '15:00',
#   'dir': '10',
#   'velmedia': '2,8',
#   'racha': '6,4',
#   'horaracha': '14:20',
#   'sol': '5,8',
#   'presMax': '1016,2',
#   'horaPresMax': '23',
#   'presMin': '1013,4',
#   'horaPresMin': 'Varias'},
#  {'fecha': '2019-01-11',
#   'indicativo': 'C429I',
#   'nombre': 'TENERIFE SUR AEROPUERTO',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '64',
#   'tmed': '17,1',
#   'prec': '0,0',
#   'tmin': '13,5',
#   'horatmin': '08:07',
#   'tmax': '20,7',
#   'horatmax': '12:25',
#   'dir': '36',
#   'velmedia': '3,6',
#   'racha': '9,7',
#   'horaracha': '08:12',
#   'sol': '5,1',
#   'presMax': '1011,6',
#   'horaPresMax': 'Varias',
#   'presMin': '1008,9',
#   'horaPresMin': '06'},
#  {'fecha': '2019-01-11',
#   'indicativo': 'C439J',
#   'nombre': 'GÜÍMAR',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '115',
#   'tmed': '15,9',
#   'prec': '0,0',
#   'tmin': '12,3',
#   'horatmin': '08:10',
#   'tmax': '19,5',
#   'horatmax': '12:20',
#   'velmedia': '1,4',
#   'presMax': '1006,6',
#   'horaPresMax': '23',
#   'presMin': '1003,7',
#   'horaPresMin': '05'},
#  {'fecha': '2019-01-12',
#   'indicativo': 'C447A',
#   'nombre': 'TENERIFE NORTE AEROPUERTO',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '632',
#   'tmed': '13,0',
#   'prec': '0,0',
#   'tmin': '10,4',
#   'horatmin': '23:58',
#   'tmax': '15,6',
#   'horatmax': '12:59',
#   'dir': '99',
#   'velmedia': '5,0',
#   'racha': '9,7',
#   'horaracha': 'Varias',
#   'sol': '1,4',
#   'presMax': '950,0',
#   'horaPresMax': 'Varias',
#   'presMin': '947,1',
#   'horaPresMin': '06'},
#  {'fecha': '2019-01-12',
#   'indicativo': 'C449C',
#   'nombre': 'STA.CRUZ DE TENERIFE',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '35',
#   'tmed': '17,9',
#   'prec': '0,0',
#   'tmin': '15,4',
#   'horatmin': '23:40',
#   'tmax': '20,4',
#   'horatmax': '15:00',
#   'dir': '09',
#   'velmedia': '3,1',
#   'racha': '6,9',
#   'horaracha': '06:00',
#   'sol': '5,7',
#   'presMax': '1017,1',
#   'horaPresMax': 'Varias',
#   'presMin': '1014,4',
#   'horaPresMin': '06'},
#  {'fecha': '2019-01-12',
#   'indicativo': 'C429I',
#   'nombre': 'TENERIFE SUR AEROPUERTO',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '64',
#   'tmed': '17,6',
#   'prec': '0,0',
#   'tmin': '13,9',
#   'horatmin': '06:20',
#   'tmax': '21,3',
#   'horatmax': '14:23',
#   'dir': '06',
#   'velmedia': '6,4',
#   'racha': '11,4',
#   'horaracha': '18:24',
#   'sol': '9,2',
#   'presMax': '1012,1',
#   'horaPresMax': 'Varias',
#   'presMin': '1009,6',
#   'horaPresMin': '06'},
#  {'fecha': '2019-01-12',
#   'indicativo': 'C439J',
#   'nombre': 'GÜÍMAR',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '115',
#   'tmed': '16,2',
#   'prec': '0,0',
#   'tmin': '12,8',
#   'horatmin': '23:50',
#   'tmax': '19,7',
#   'horatmax': '14:10',
#   'presMax': '1007,5',
#   'horaPresMax': '23',
#   'presMin': '1004,7',
#   'horaPresMin': '07'},
#  {'fecha': '2019-01-13',
#   'indicativo': 'C447A',
#   'nombre': 'TENERIFE NORTE AEROPUERTO',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '632',
#   'tmed': '13,6',
#   'prec': '0,0',
#   'tmin': '8,4',
#   'horatmin': '01:12',
#   'tmax': '18,7',
#   'horatmax': '11:30',
#   'dir': '99',
#   'velmedia': '5,3',
#   'racha': '13,3',
#   'horaracha': 'Varias',
#   'sol': '6,8',
#   'presMax': '950,8',
#   'horaPresMax': 'Varias',
#   'presMin': '948,5',
#   'horaPresMin': '05'},
#  {'fecha': '2019-01-13',
#   'indicativo': 'C449C',
#   'nombre': 'STA.CRUZ DE TENERIFE',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '35',
#   'tmed': '18,6',
#   'prec': '0,0',
#   'tmin': '14,2',
#   'horatmin': '05:30',
#   'tmax': '22,9',
#   'horatmax': '14:10',
#   'dir': '18',
#   'velmedia': '3,6',
#   'racha': '10,8',
#   'horaracha': '13:00',
#   'sol': '9,6',
#   'presMax': '1017,6',
#   'horaPresMax': '11',
#   'presMin': '1015,5',
#   'horaPresMin': '05'},
#  {'fecha': '2019-01-13',
#   'indicativo': 'C429I',
#   'nombre': 'TENERIFE SUR AEROPUERTO',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '64',
#   'tmed': '19,6',
#   'prec': '0,0',
#   'tmin': '14,8',
#   'horatmin': '00:01',
#   'tmax': '24,5',
#   'horatmax': '10:46',
#   'dir': '99',
#   'velmedia': '5,0',
#   'racha': '9,2',
#   'horaracha': 'Varias',
#   'sol': '9,7',
#   'presMax': '1013,5',
#   'horaPresMax': 'Varias',
#   'presMin': '1010,3',
#   'horaPresMin': '02'},
#  {'fecha': '2019-01-13',
#   'indicativo': 'C439J',
#   'nombre': 'GÜÍMAR',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '115',
#   'tmed': '16,6',
#   'prec': '0,0',
#   'tmin': '10,0',
#   'horatmin': '01:40',
#   'tmax': '23,1',
#   'horatmax': '11:50',
#   'presMax': '1008,0',
#   'horaPresMax': '11',
#   'presMin': '1005,6',
#   'horaPresMin': '16'},
#  {'fecha': '2019-01-14',
#   'indicativo': 'C447A',
#   'nombre': 'TENERIFE NORTE AEROPUERTO',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '632',
#   'tmed': '14,4',
#   'prec': '0,0',
#   'tmin': '10,5',
#   'horatmin': '21:32',
#   'tmax': '18,2',
#   'horatmax': '14:57',
#   'dir': '14',
#   'velmedia': '4,2',
#   'racha': '12,8',
#   'horaracha': '11:38',
#   'sol': '6,6',
#   'presMax': '950,6',
#   'horaPresMax': 'Varias',
#   'presMin': '947,8',
#   'horaPresMin': '15'},
#  {'fecha': '2019-01-14',
#   'indicativo': 'C449C',
#   'nombre': 'STA.CRUZ DE TENERIFE',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '35',
#   'tmed': '19,0',
#   'prec': '0,0',
#   'tmin': '15,0',
#   'horatmin': '07:30',
#   'tmax': '23,0',
#   'horatmax': '14:20',
#   'dir': '21',
#   'velmedia': '2,8',
#   'racha': '9,4',
#   'horaracha': '11:40',
#   'sol': '9,4',
#   'presMax': '1017,4',
#   'horaPresMax': '11',
#   'presMin': '1014,5',
#   'horaPresMin': '15'},
#  {'fecha': '2019-01-14',
#   'indicativo': 'C429I',
#   'nombre': 'TENERIFE SUR AEROPUERTO',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '64',
#   'tmed': '18,8',
#   'prec': '0,0',
#   'tmin': '15,4',
#   'horatmin': '23:17',
#   'tmax': '22,2',
#   'horatmax': '13:26',
#   'dir': '99',
#   'velmedia': '4,4',
#   'racha': '8,3',
#   'horaracha': 'Varias',
#   'sol': '9,7',
#   'presMax': '1013,3',
#   'horaPresMax': 'Varias',
#   'presMin': '1010,0',
#   'horaPresMin': '16'},
#  {'fecha': '2019-01-14',
#   'indicativo': 'C439J',
#   'nombre': 'GÜÍMAR',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '115',
#   'tmed': '16,4',
#   'prec': '0,0',
#   'tmin': '11,5',
#   'horatmin': '04:00',
#   'tmax': '21,4',
#   'horatmax': '10:40',
#   'dir': '19',
#   'racha': '8,6',
#   'horaracha': '11:50',
#   'presMax': '1007,9',
#   'horaPresMax': '11',
#   'presMin': '1004,8',
#   'horaPresMin': '15'},
#  {'fecha': '2019-01-15',
#   'indicativo': 'C447A',
#   'nombre': 'TENERIFE NORTE AEROPUERTO',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '632',
#   'tmed': '12,8',
#   'prec': '0,0',
#   'tmin': '9,4',
#   'horatmin': '01:20',
#   'tmax': '16,1',
#   'horatmax': '13:33',
#   'dir': '11',
#   'velmedia': '3,9',
#   'racha': '8,9',
#   'horaracha': '10:55',
#   'sol': '5,7',
#   'presMax': '952,5',
#   'horaPresMax': 'Varias',
#   'presMin': '948,7',
#   'horaPresMin': '06'},
#  {'fecha': '2019-01-15',
#   'indicativo': 'C449C',
#   'nombre': 'STA.CRUZ DE TENERIFE',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '35',
#   'tmed': '17,8',
#   'prec': '0,0',
#   'tmin': '14,5',
#   'horatmin': 'Varias',
#   'tmax': '21,0',
#   'horatmax': '14:20',
#   'dir': '09',
#   'velmedia': '3,1',
#   'racha': '8,3',
#   'horaracha': '17:20',
#   'sol': '9,5',
#   'presMax': '1019,7',
#   'horaPresMax': '23',
#   'presMin': '1015,7',
#   'horaPresMin': '06'},
#  {'fecha': '2019-01-15',
#   'indicativo': 'C429I',
#   'nombre': 'TENERIFE SUR AEROPUERTO',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '64',
#   'tmed': '19,0',
#   'prec': '0,0',
#   'tmin': '15,1',
#   'horatmin': '03:57',
#   'tmax': '22,8',
#   'horatmax': '13:23',
#   'dir': '99',
#   'velmedia': '7,8',
#   'racha': '12,8',
#   'horaracha': 'Varias',
#   'sol': '9,8',
#   'presMax': '1014,3',
#   'horaPresMax': 'Varias',
#   'presMin': '1010,3',
#   'horaPresMin': '05'},
#  {'fecha': '2019-01-15',
#   'indicativo': 'C439J',
#   'nombre': 'GÜÍMAR',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '115',
#   'tmed': '17,0',
#   'prec': '0,0',
#   'tmin': '14,0',
#   'horatmin': '06:30',
#   'tmax': '19,9',
#   'horatmax': '13:50',
#   'dir': '07',
#   'velmedia': '2,5',
#   'racha': '7,2',
#   'horaracha': '12:10',
#   'presMax': '1010,0',
#   'horaPresMax': '24',
#   'presMin': '1006,0',
#   'horaPresMin': '06'},
#  {'fecha': '2019-01-16',
#   'indicativo': 'C447A',
#   'nombre': 'TENERIFE NORTE AEROPUERTO',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '632',
#   'tmed': '12,0',
#   'prec': '1,6',
#   'tmin': '8,3',
#   'horatmin': '04:32',
#   'tmax': '15,6',
#   'horatmax': '12:23',
#   'dir': '99',
#   'velmedia': '6,4',
#   'racha': '12,8',
#   'horaracha': 'Varias',
#   'sol': '4,8',
#   'presMax': '952,9',
#   'horaPresMax': 'Varias',
#   'presMin': '949,9',
#   'horaPresMin': '15'},
#  {'fecha': '2019-01-16',
#   'indicativo': 'C449C',
#   'nombre': 'STA.CRUZ DE TENERIFE',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '35',
#   'tmed': '18,0',
#   'prec': '1,2',
#   'tmin': '14,6',
#   'horatmin': '05:20',
#   'tmax': '21,5',
#   'horatmax': '14:10',
#   'dir': '31',
#   'velmedia': '2,2',
#   'racha': '9,2',
#   'horaracha': '16:00',
#   'sol': '7,9',
#   'presMax': '1020,0',
#   'horaPresMax': '11',
#   'presMin': '1016,8',
#   'horaPresMin': '16'},
#  {'fecha': '2019-01-16',
#   'indicativo': 'C429I',
#   'nombre': 'TENERIFE SUR AEROPUERTO',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '64',
#   'tmed': '18,0',
#   'prec': '0,0',
#   'tmin': '14,7',
#   'horatmin': '06:12',
#   'tmax': '21,4',
#   'horatmax': '13:42',
#   'dir': '07',
#   'velmedia': '6,1',
#   'racha': '12,5',
#   'horaracha': '10:14',
#   'sol': '5,9',
#   'presMax': '1015,2',
#   'horaPresMax': 'Varias',
#   'presMin': '1012,1',
#   'horaPresMin': '18'},
#  {'fecha': '2019-01-16',
#   'indicativo': 'C439J',
#   'nombre': 'GÜÍMAR',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '115',
#   'tmed': '17,3',
#   'prec': '0,0',
#   'tmin': '13,1',
#   'horatmin': '07:00',
#   'tmax': '21,5',
#   'horatmax': '15:50',
#   'velmedia': '5,6',
#   'presMax': '1010,0',
#   'horaPresMax': '00',
#   'presMin': '1005,7',
#   'horaPresMin': 'Varias'},
#  {'fecha': '2019-01-17',
#   'indicativo': 'C447A',
#   'nombre': 'TENERIFE NORTE AEROPUERTO',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '632',
#   'tmed': '11,9',
#   'prec': '19,0',
#   'tmin': '9,3',
#   'horatmin': '02:34',
#   'tmax': '14,5',
#   'horatmax': '11:37',
#   'dir': '99',
#   'velmedia': '7,8',
#   'racha': '17,5',
#   'horaracha': 'Varias',
#   'sol': '2,5',
#   'presMax': '951,6',
#   'horaPresMax': 'Varias',
#   'presMin': '948,6',
#   'horaPresMin': '15'},
#  {'fecha': '2019-01-17',
#   'indicativo': 'C449C',
#   'nombre': 'STA.CRUZ DE TENERIFE',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '35',
#   'tmed': '17,8',
#   'prec': '10,0',
#   'tmin': '14,7',
#   'horatmin': '03:50',
#   'tmax': '20,8',
#   'horatmax': '13:40',
#   'dir': '36',
#   'velmedia': '2,8',
#   'racha': '12,5',
#   'horaracha': '21:00',
#   'sol': '6,4',
#   'presMax': '1018,7',
#   'horaPresMax': '00',
#   'presMin': '1015,7',
#   'horaPresMin': '15'},
#  {'fecha': '2019-01-17',
#   'indicativo': 'C429I',
#   'nombre': 'TENERIFE SUR AEROPUERTO',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '64',
#   'tmed': '17,6',
#   'prec': '0,0',
#   'tmin': '13,0',
#   'horatmin': '07:46',
#   'tmax': '22,1',
#   'horatmax': '15:46',
#   'dir': '05',
#   'velmedia': '3,6',
#   'racha': '10,3',
#   'horaracha': '19:36',
#   'sol': '8,4',
#   'presMax': '1013,9',
#   'horaPresMax': 'Varias',
#   'presMin': '1010,5',
#   'horaPresMin': '15'},
#  {'fecha': '2019-01-17',
#   'indicativo': 'C439J',
#   'nombre': 'GÜÍMAR',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '115',
#   'tmed': '17,6',
#   'prec': '0,4',
#   'tmin': '13,4',
#   'horatmin': '04:10',
#   'tmax': '21,8',
#   'horatmax': '13:10',
#   'dir': '04',
#   'velmedia': '3,3',
#   'racha': '12,2',
#   'horaracha': '16:10',
#   'presMax': '1008,5',
#   'horaPresMax': '00',
#   'presMin': '1005,0',
#   'horaPresMin': '15'},
#  {'fecha': '2019-01-18',
#   'indicativo': 'C447A',
#   'nombre': 'TENERIFE NORTE AEROPUERTO',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '632',
#   'tmed': '12,3',
#   'prec': '0,5',
#   'tmin': '10,5',
#   'horatmin': '23:22',
#   'tmax': '14,1',
#   'horatmax': '12:22',
#   'dir': '34',
#   'velmedia': '7,2',
#   'racha': '15,3',
#   'horaracha': '13:11',
#   'sol': '2,2',
#   'presMax': '955,1',
#   'horaPresMax': 'Varias',
#   'presMin': '950,5',
#   'horaPresMin': '05'},
#  {'fecha': '2019-01-18',
#   'indicativo': 'C449C',
#   'nombre': 'STA.CRUZ DE TENERIFE',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '35',
#   'tmed': '17,6',
#   'prec': '0,2',
#   'tmin': '14,9',
#   'horatmin': '06:20',
#   'tmax': '20,4',
#   'horatmax': '14:30',
#   'dir': '36',
#   'velmedia': '3,6',
#   'racha': '10,8',
#   'horaracha': '15:10',
#   'sol': '6,8',
#   'presMax': '1022,7',
#   'horaPresMax': '24',
#   'presMin': '1017,4',
#   'horaPresMin': '06'},
#  {'fecha': '2019-01-18',
#   'indicativo': 'C429I',
#   'nombre': 'TENERIFE SUR AEROPUERTO',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '64',
#   'tmed': '17,6',
#   'prec': '0,0',
#   'tmin': '13,4',
#   'horatmin': '06:47',
#   'tmax': '21,9',
#   'horatmax': '11:59',
#   'dir': '99',
#   'velmedia': '7,2',
#   'racha': '14,4',
#   'horaracha': 'Varias',
#   'sol': '6,5',
#   'presMax': '1017,3',
#   'horaPresMax': 'Varias',
#   'presMin': '1012,4',
#   'horaPresMin': '04'},
#  {'fecha': '2019-01-18',
#   'indicativo': 'C439J',
#   'nombre': 'GÜÍMAR',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '115',
#   'tmed': '17,2',
#   'prec': '0,0',
#   'tmin': '14,2',
#   'horatmin': '03:50',
#   'tmax': '20,1',
#   'horatmax': '12:20',
#   'dir': '05',
#   'velmedia': '6,1',
#   'racha': '15,3',
#   'horaracha': '13:20',
#   'presMax': '1012,2',
#   'horaPresMax': '24',
#   'presMin': '1007,3',
#   'horaPresMin': '15'},
#  {'fecha': '2019-01-19',
#   'indicativo': 'C447A',
#   'nombre': 'TENERIFE NORTE AEROPUERTO',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '632',
#   'tmed': '12,4',
#   'prec': '0,1',
#   'tmin': '10,1',
#   'horatmin': '00:23',
#   'tmax': '14,8',
#   'horatmax': '13:11',
#   'dir': '30',
#   'velmedia': '5,8',
#   'racha': '11,7',
#   'horaracha': '04:39',
#   'sol': '1,6',
#   'presMax': '956,9',
#   'horaPresMax': 'Varias',
#   'presMin': '953,8',
#   'horaPresMin': '05'},
#  {'fecha': '2019-01-19',
#   'indicativo': 'C449C',
#   'nombre': 'STA.CRUZ DE TENERIFE',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '35',
#   'tmed': '17,9',
#   'prec': '0,0',
#   'tmin': '15,8',
#   'horatmin': '07:30',
#   'tmax': '20,0',
#   'horatmax': '13:00',
#   'dir': '36',
#   'velmedia': '2,8',
#   'racha': '7,8',
#   'horaracha': '13:10',
#   'sol': '3,1',
#   'presMax': '1024,5',
#   'horaPresMax': '11',
#   'presMin': '1021,3',
#   'horaPresMin': '05'},
#  {'fecha': '2019-01-19',
#   'indicativo': 'C429I',
#   'nombre': 'TENERIFE SUR AEROPUERTO',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '64',
#   'tmed': '18,6',
#   'prec': '0,0',
#   'tmin': '15,3',
#   'horatmin': '03:47',
#   'tmax': '21,8',
#   'horatmax': '13:57',
#   'dir': '10',
#   'velmedia': '7,2',
#   'racha': '13,3',
#   'horaracha': '14:29',
#   'sol': '7,5',
#   'presMax': '1019,4',
#   'horaPresMax': 'Varias',
#   'presMin': '1016,4',
#   'horaPresMin': '04'},
#  {'fecha': '2019-01-19',
#   'indicativo': 'C439J',
#   'nombre': 'GÜÍMAR',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '115',
#   'tmed': '16,8',
#   'prec': '0,0',
#   'tmin': '13,4',
#   'horatmin': '23:40',
#   'tmax': '20,3',
#   'horatmax': '14:00',
#   'dir': '06',
#   'velmedia': '4,2',
#   'racha': '12,2',
#   'horaracha': '13:30',
#   'presMax': '1014,1',
#   'horaPresMax': '11',
#   'presMin': '1010,7',
#   'horaPresMin': '06'},
#  {'fecha': '2019-01-20',
#   'indicativo': 'C447A',
#   'nombre': 'TENERIFE NORTE AEROPUERTO',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '632',
#   'tmed': '13,5',
#   'prec': '4,8',
#   'tmin': '11,1',
#   'horatmin': '08:30',
#   'tmax': '15,9',
#   'horatmax': '15:32',
#   'dir': '29',
#   'velmedia': '8,3',
#   'racha': '13,3',
#   'horaracha': 'Varias',
#   'sol': '4,6',
#   'presMax': '956,2',
#   'horaPresMax': 'Varias',
#   'presMin': '953,3',
#   'horaPresMin': '17'},
#  {'fecha': '2019-01-20',
#   'indicativo': 'C449C',
#   'nombre': 'STA.CRUZ DE TENERIFE',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '35',
#   'tmed': '19,6',
#   'prec': '0,8',
#   'tmin': '16,8',
#   'horatmin': '00:40',
#   'tmax': '22,3',
#   'horatmax': '15:40',
#   'dir': '32',
#   'velmedia': '4,4',
#   'racha': '13,1',
#   'horaracha': '18:20',
#   'sol': '7,2',
#   'presMax': '1023,6',
#   'horaPresMax': '11',
#   'presMin': '1019,9',
#   'horaPresMin': '19'},
#  {'fecha': '2019-01-20',
#   'indicativo': 'C429I',
#   'nombre': 'TENERIFE SUR AEROPUERTO',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '64',
#   'tmed': '18,2',
#   'prec': '0,0',
#   'tmin': '14,1',
#   'horatmin': '04:56',
#   'tmax': '22,3',
#   'horatmax': '13:47',
#   'dir': '09',
#   'velmedia': '4,2',
#   'racha': '10,8',
#   'horaracha': '03:32',
#   'sol': '10,1',
#   'presMax': '1018,8',
#   'horaPresMax': 'Varias',
#   'presMin': '1015,7',
#   'horaPresMin': '17'},
#  {'fecha': '2019-01-20',
#   'indicativo': 'C439J',
#   'nombre': 'GÜÍMAR',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '115',
#   'tmed': '15,8',
#   'prec': '0,0',
#   'tmin': '10,6',
#   'horatmin': '07:30',
#   'tmax': '21,0',
#   'horatmax': '15:00',
#   'velmedia': '1,7',
#   'presMax': '1013,6',
#   'horaPresMax': '11',
#   'presMin': '1010,3',
#   'horaPresMin': '19'},
#  {'fecha': '2019-01-21',
#   'indicativo': 'C447A',
#   'nombre': 'TENERIFE NORTE AEROPUERTO',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '632',
#   'tmed': '12,6',
#   'prec': '1,3',
#   'tmin': '10,5',
#   'horatmin': '21:18',
#   'tmax': '14,7',
#   'horatmax': 'Varias',
#   'dir': '32',
#   'velmedia': '6,9',
#   'racha': '12,8',
#   'horaracha': 'Varias',
#   'sol': '2,5',
#   'presMax': '954,5',
#   'horaPresMax': 'Varias',
#   'presMin': '952,6',
#   'horaPresMin': '16'},
#  {'fecha': '2019-01-21',
#   'indicativo': 'C449C',
#   'nombre': 'STA.CRUZ DE TENERIFE',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '35',
#   'tmed': '17,5',
#   'prec': '1,0',
#   'tmin': '15,3',
#   'horatmin': '05:20',
#   'tmax': '19,7',
#   'horatmax': '11:30',
#   'dir': '36',
#   'velmedia': '2,8',
#   'racha': '8,9',
#   'horaracha': '14:50',
#   'sol': '2,2',
#   'presMax': '1021,9',
#   'horaPresMax': '11',
#   'presMin': '1020,0',
#   'horaPresMin': '17'},
#  {'fecha': '2019-01-21',
#   'indicativo': 'C429I',
#   'nombre': 'TENERIFE SUR AEROPUERTO',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '64',
#   'tmed': '18,2',
#   'prec': '0,0',
#   'tmin': '14,7',
#   'horatmin': 'Varias',
#   'tmax': '21,8',
#   'horatmax': '11:54',
#   'dir': '99',
#   'velmedia': '7,2',
#   'racha': '15,0',
#   'horaracha': 'Varias',
#   'sol': '4,0',
#   'presMax': '1016,8',
#   'horaPresMax': '00',
#   'presMin': '1014,3',
#   'horaPresMin': '16'},
#  {'fecha': '2019-01-21',
#   'indicativo': 'C439J',
#   'nombre': 'GÜÍMAR',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '115',
#   'tmed': '17,0',
#   'prec': '0,0',
#   'tmin': '13,3',
#   'horatmin': '04:00',
#   'tmax': '20,8',
#   'horatmax': '13:50',
#   'dir': '05',
#   'velmedia': '6,7',
#   'racha': '15,8',
#   'horaracha': '15:20',
#   'presMax': '1011,9',
#   'horaPresMax': '00',
#   'presMin': '1008,7',
#   'horaPresMin': '16'},
#  {'fecha': '2019-01-22',
#   'indicativo': 'C447A',
#   'nombre': 'TENERIFE NORTE AEROPUERTO',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '632',
#   'tmed': '12,4',
#   'prec': '0,0',
#   'tmin': '9,7',
#   'horatmin': '02:39',
#   'tmax': '15,0',
#   'horatmax': '15:06',
#   'dir': '34',
#   'velmedia': '2,8',
#   'racha': '10,3',
#   'horaracha': '00:58',
#   'sol': '1,1',
#   'presMax': '955,7',
#   'horaPresMax': 'Varias',
#   'presMin': '953,0',
#   'horaPresMin': '06'},
#  {'fecha': '2019-01-22',
#   'indicativo': 'C449C',
#   'nombre': 'STA.CRUZ DE TENERIFE',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '35',
#   'tmed': '18,0',
#   'prec': '0,0',
#   'tmin': '15,8',
#   'horatmin': '02:50',
#   'tmax': '20,3',
#   'horatmax': '15:30',
#   'dir': '07',
#   'velmedia': '2,5',
#   'racha': '10,3',
#   'horaracha': '13:50',
#   'sol': '5,7',
#   'presMax': '1023,1',
#   'horaPresMax': '12',
#   'presMin': '1020,2',
#   'horaPresMin': '05'},
#  {'fecha': '2019-01-22',
#   'indicativo': 'C429I',
#   'nombre': 'TENERIFE SUR AEROPUERTO',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '64',
#   'tmed': '17,6',
#   'prec': '0,0',
#   'tmin': '14,1',
#   'horatmin': '04:56',
#   'tmax': '21,0',
#   'horatmax': '13:53',
#   'dir': '99',
#   'velmedia': '7,8',
#   'racha': '17,5',
#   'horaracha': 'Varias',
#   'sol': '8,2',
#   'presMax': '1017,6',
#   'horaPresMax': 'Varias',
#   'presMin': '1014,9',
#   'horaPresMin': '17'},
#  {'fecha': '2019-01-22',
#   'indicativo': 'C439J',
#   'nombre': 'GÜÍMAR',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '115',
#   'tmed': '17,4',
#   'prec': '0,0',
#   'tmin': '15,3',
#   'horatmin': '03:30',
#   'tmax': '19,6',
#   'horatmax': '12:50',
#   'dir': '05',
#   'velmedia': '4,2',
#   'racha': '10,6',
#   'horaracha': '15:00',
#   'presMax': '1013,2',
#   'horaPresMax': '12',
#   'presMin': '1010,3',
#   'horaPresMin': '05'},
#  {'fecha': '2019-01-23',
#   'indicativo': 'C447A',
#   'nombre': 'TENERIFE NORTE AEROPUERTO',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '632',
#   'tmed': '13,0',
#   'prec': '1,6',
#   'tmin': '10,4',
#   'horatmin': '07:20',
#   'tmax': '15,7',
#   'horatmax': '13:30',
#   'dir': '01',
#   'velmedia': '3,9',
#   'racha': '9,4',
#   'horaracha': '13:10',
#   'sol': '2,0',
#   'presMax': '955,1',
#   'horaPresMax': '00',
#   'presMin': '951,4',
#   'horaPresMin': '24'},
#  {'fecha': '2019-01-23',
#   'indicativo': 'C449C',
#   'nombre': 'STA.CRUZ DE TENERIFE',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '35',
#   'tmed': '16,8',
#   'prec': '0,4',
#   'tmin': '14,5',
#   'horatmin': 'Varias',
#   'tmax': '19,0',
#   'horatmax': 'Varias',
#   'velmedia': '2,5',
#   'sol': '1,8',
#   'presMax': '1022,5',
#   'horaPresMax': 'Varias',
#   'presMin': '1018,6',
#   'horaPresMin': '24'},
#  {'fecha': '2019-01-23',
#   'indicativo': 'C429I',
#   'nombre': 'TENERIFE SUR AEROPUERTO',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '64',
#   'tmed': '17,4',
#   'prec': '0,0',
#   'tmin': '14,1',
#   'horatmin': '05:07',
#   'tmax': '20,8',
#   'horatmax': '15:27',
#   'dir': '99',
#   'velmedia': '8,6',
#   'racha': '15,3',
#   'horaracha': 'Varias',
#   'sol': '8,3',
#   'presMax': '1017,2',
#   'horaPresMax': 'Varias',
#   'presMin': '1013,8',
#   'horaPresMin': '18'},
#  {'fecha': '2019-01-23',
#   'indicativo': 'C439J',
#   'nombre': 'GÜÍMAR',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '115',
#   'tmed': '16,8',
#   'prec': '0,0',
#   'tmin': '14,9',
#   'horatmin': '07:00',
#   'tmax': '18,6',
#   'horatmax': '13:40',
#   'dir': '06',
#   'velmedia': '3,1',
#   'racha': '10,8',
#   'horaracha': '14:40',
#   'presMax': '1012,7',
#   'horaPresMax': '00',
#   'presMin': '1008,6',
#   'horaPresMin': '23'},
#  {'fecha': '2019-01-24',
#   'indicativo': 'C447A',
#   'nombre': 'TENERIFE NORTE AEROPUERTO',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '632',
#   'prec': '0,7',
#   'tmax': '15,8',
#   'horatmax': '15:37',
#   'velmedia': '5,3',
#   'sol': '4,0',
#   'presMax': '951,4',
#   'horaPresMax': '00',
#   'presMin': '946,3',
#   'horaPresMin': '18'},
#  {'fecha': '2019-01-24',
#   'indicativo': 'C449C',
#   'nombre': 'STA.CRUZ DE TENERIFE',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '35',
#   'tmed': '18,1',
#   'prec': '0,2',
#   'tmin': '15,1',
#   'horatmin': '07:20',
#   'tmax': '21,1',
#   'horatmax': '15:30',
#   'dir': '04',
#   'velmedia': '2,5',
#   'racha': '9,2',
#   'horaracha': '14:20',
#   'sol': '4,0',
#   'presMax': '1018,6',
#   'horaPresMax': '00',
#   'presMin': '1013,0',
#   'horaPresMin': '19'},
#  {'fecha': '2019-01-24',
#   'indicativo': 'C429I',
#   'nombre': 'TENERIFE SUR AEROPUERTO',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '64',
#   'tmed': '17,3',
#   'prec': '0,7',
#   'tmin': '14,0',
#   'horatmin': '07:55',
#   'tmax': '20,6',
#   'horatmax': '11:51',
#   'dir': '08',
#   'velmedia': '5,3',
#   'racha': '11,4',
#   'horaracha': '17:54',
#   'sol': '1,1',
#   'presMax': '1014,0',
#   'horaPresMax': '00',
#   'presMin': '1007,9',
#   'horaPresMin': '17'},
#  {'fecha': '2019-01-24',
#   'indicativo': 'C439J',
#   'nombre': 'GÜÍMAR',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '115',
#   'tmed': '17,0',
#   'prec': '0,0',
#   'tmin': '13,8',
#   'horatmin': '02:30',
#   'tmax': '20,2',
#   'horatmax': '16:20',
#   'dir': '99',
#   'velmedia': '3,3',
#   'racha': '10,3',
#   'horaracha': 'Varias',
#   'presMax': '1008,8',
#   'horaPresMax': '00',
#   'presMin': '1002,4',
#   'horaPresMin': '18'},
#  {'fecha': '2019-01-25',
#   'indicativo': 'C447A',
#   'nombre': 'TENERIFE NORTE AEROPUERTO',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '632',
#   'tmed': '13,4',
#   'prec': 'Ip',
#   'tmin': '10,1',
#   'horatmin': '20:29',
#   'tmax': '16,7',
#   'horatmax': '15:08',
#   'dir': '32',
#   'velmedia': '3,6',
#   'racha': '7,8',
#   'horaracha': '16:05',
#   'sol': '6,6',
#   'presMax': '947,6',
#   'horaPresMax': 'Varias',
#   'presMin': '945,3',
#   'horaPresMin': '15'},
#  {'fecha': '2019-01-25',
#   'indicativo': 'C449C',
#   'nombre': 'STA.CRUZ DE TENERIFE',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '35',
#   'tmed': '19,2',
#   'prec': '0,0',
#   'tmin': '15,9',
#   'horatmin': '03:30',
#   'tmax': '22,4',
#   'horatmax': '13:20',
#   'dir': '09',
#   'velmedia': '2,5',
#   'racha': '8,9',
#   'horaracha': '13:30',
#   'sol': '8,7',
#   'presMax': '1014,2',
#   'horaPresMax': '24',
#   'presMin': '1011,4',
#   'horaPresMin': '15'},
#  {'fecha': '2019-01-25',
#   'indicativo': 'C429I',
#   'nombre': 'TENERIFE SUR AEROPUERTO',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '64',
#   'tmed': '17,6',
#   'prec': '0,0',
#   'tmin': '13,9',
#   'horatmin': '02:51',
#   'tmax': '21,3',
#   'horatmax': '12:27',
#   'dir': '99',
#   'velmedia': '3,6',
#   'racha': '7,2',
#   'horaracha': 'Varias',
#   'sol': '3,3',
#   'presMax': '1010,0',
#   'horaPresMax': 'Varias',
#   'presMin': '1007,6',
#   'horaPresMin': '15'},
#  {'fecha': '2019-01-25',
#   'indicativo': 'C439J',
#   'nombre': 'GÜÍMAR',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '115',
#   'tmed': '16,6',
#   'prec': '0,2',
#   'tmin': '13,2',
#   'horatmin': '00:50',
#   'tmax': '20,0',
#   'horatmax': '11:20',
#   'velmedia': '2,2',
#   'presMax': '1004,8',
#   'horaPresMax': '24',
#   'presMin': '1002,3',
#   'horaPresMin': '07'},
#  {'fecha': '2019-01-26',
#   'indicativo': 'C447A',
#   'nombre': 'TENERIFE NORTE AEROPUERTO',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '632',
#   'tmed': '12,8',
#   'prec': '0,2',
#   'tmin': '9,1',
#   'horatmin': '06:38',
#   'tmax': '16,4',
#   'horatmax': '10:32',
#   'dir': '01',
#   'velmedia': '2,8',
#   'racha': '7,2',
#   'horaracha': '14:44',
#   'sol': '3,6',
#   'presMax': '951,4',
#   'horaPresMax': 'Varias',
#   'presMin': '947,3',
#   'horaPresMin': '05'},
#  {'fecha': '2019-01-26',
#   'indicativo': 'C449C',
#   'nombre': 'STA.CRUZ DE TENERIFE',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '35',
#   'tmed': '17,8',
#   'prec': '0,0',
#   'tmin': '14,5',
#   'horatmin': '07:30',
#   'tmax': '21,1',
#   'horatmax': '14:10',
#   'dir': '09',
#   'velmedia': '2,5',
#   'racha': '6,4',
#   'horaracha': 'Varias',
#   'sol': '7,7',
#   'presMax': '1018,3',
#   'horaPresMax': '24',
#   'presMin': '1014,2',
#   'horaPresMin': 'Varias'},
#  {'fecha': '2019-01-26',
#   'indicativo': 'C429I',
#   'nombre': 'TENERIFE SUR AEROPUERTO',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '64',
#   'tmed': '17,2',
#   'prec': 'Ip',
#   'tmin': '12,9',
#   'horatmin': '08:11',
#   'tmax': '21,5',
#   'horatmax': '14:50',
#   'dir': '05',
#   'velmedia': '3,3',
#   'racha': '8,9',
#   'horaracha': '21:01',
#   'sol': '6,9',
#   'presMax': '1013,8',
#   'horaPresMax': 'Varias',
#   'presMin': '1009,5',
#   'horaPresMin': '05'},
#  {'fecha': '2019-01-26',
#   'indicativo': 'C439J',
#   'nombre': 'GÜÍMAR',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '115',
#   'tmed': '15,8',
#   'prec': '0,2',
#   'tmin': '11,8',
#   'horatmin': '07:40',
#   'tmax': '19,7',
#   'horatmax': '11:10',
#   'presMax': '1008,7',
#   'horaPresMax': '24',
#   'presMin': '1004,4',
#   'horaPresMin': '05'},
#  {'fecha': '2019-01-27',
#   'indicativo': 'C447A',
#   'nombre': 'TENERIFE NORTE AEROPUERTO',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '632',
#   'tmed': '12,6',
#   'prec': '0,1',
#   'tmin': '8,8',
#   'horatmin': '04:12',
#   'tmax': '16,3',
#   'horatmax': '13:03',
#   'dir': '29',
#   'velmedia': '5,8',
#   'racha': '10,8',
#   'horaracha': '19:19',
#   'sol': '5,6',
#   'presMax': '954,5',
#   'horaPresMax': 'Varias',
#   'presMin': '951,0',
#   'horaPresMin': '05'},
#  {'fecha': '2019-01-27',
#   'indicativo': 'C449C',
#   'nombre': 'STA.CRUZ DE TENERIFE',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '35',
#   'tmed': '18,8',
#   'prec': '0,0',
#   'tmin': '15,2',
#   'horatmin': '03:40',
#   'tmax': '22,3',
#   'horatmax': '14:50',
#   'dir': '06',
#   'velmedia': '2,8',
#   'racha': '8,6',
#   'horaracha': '13:20',
#   'sol': '7,8',
#   'presMax': '1021,4',
#   'horaPresMax': '23',
#   'presMin': '1018,0',
#   'horaPresMin': 'Varias'},
#  {'fecha': '2019-01-27',
#   'indicativo': 'C429I',
#   'nombre': 'TENERIFE SUR AEROPUERTO',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '64',
#   'tmed': '18,4',
#   'prec': '0,0',
#   'tmin': '14,5',
#   'horatmin': '06:38',
#   'tmax': '22,4',
#   'horatmax': '13:17',
#   'dir': '99',
#   'velmedia': '6,4',
#   'racha': '11,4',
#   'horaracha': 'Varias',
#   'sol': '4,2',
#   'presMax': '1016,4',
#   'horaPresMax': 'Varias',
#   'presMin': '1013,2',
#   'horaPresMin': '06'},
#  {'fecha': '2019-01-27',
#   'indicativo': 'C439J',
#   'nombre': 'GÜÍMAR',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '115',
#   'tmed': '16,6',
#   'prec': '0,0',
#   'tmin': '12,0',
#   'horatmin': '08:10',
#   'tmax': '21,3',
#   'horatmax': '17:30',
#   'velmedia': '4,2',
#   'presMax': '1011,3',
#   'horaPresMax': '23',
#   'presMin': '1008,3',
#   'horaPresMin': '06'},
#  {'fecha': '2019-01-28',
#   'indicativo': 'C447A',
#   'nombre': 'TENERIFE NORTE AEROPUERTO',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '632',
#   'tmed': '13,4',
#   'prec': '0,0',
#   'tmin': '10,2',
#   'horatmin': '22:01',
#   'tmax': '16,5',
#   'horatmax': '14:45',
#   'dir': '32',
#   'velmedia': '5,3',
#   'racha': '11,4',
#   'horaracha': '06:22',
#   'sol': '5,0',
#   'presMax': '954,8',
#   'horaPresMax': 'Varias',
#   'presMin': '952,4',
#   'horaPresMin': '15'},
#  {'fecha': '2019-01-28',
#   'indicativo': 'C449C',
#   'nombre': 'STA.CRUZ DE TENERIFE',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '35',
#   'tmed': '19,2',
#   'prec': '0,0',
#   'tmin': '16,8',
#   'horatmin': '23:10',
#   'tmax': '21,7',
#   'horatmax': '14:50',
#   'dir': '07',
#   'velmedia': '2,5',
#   'racha': '9,4',
#   'horaracha': '11:40',
#   'sol': '7,6',
#   'presMax': '1021,9',
#   'horaPresMax': '12',
# ...
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '632',
#   'tmed': '20,8',
#   'prec': '0,0',
#   'tmin': '16,3',
#   'horatmin': '06:44',
#   'tmax': '25,4',
#   'horatmax': '10:06',
#   'dir': '99',
#   'velmedia': '6,7',
#   'racha': '12,8',
#   'horaracha': 'Varias',
#   'sol': '7,9',
#   'presMax': '949,5',
#   'horaPresMax': 'Varias',
#   'presMin': '947,1',
#   'horaPresMin': '04'},
#  {'fecha': '2019-08-30',
#   'indicativo': 'C449C',
#   'nombre': 'STA.CRUZ DE TENERIFE',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '35',
#   'tmed': '25,5',
#   'prec': '0,0',
#   'tmin': '21,6',
#   'horatmin': '06:10',
#   'tmax': '29,4',
#   'horatmax': '14:20',
#   'dir': '18',
#   'velmedia': '2,5',
#   'racha': '7,8',
#   'horaracha': '13:30',
#   'sol': '8,7',
#   'presMax': '1015,0',
#   'horaPresMax': '08',
#   'presMin': '1011,6',
#   'horaPresMin': '19'},
#  {'fecha': '2019-08-30',
#   'indicativo': 'C429I',
#   'nombre': 'TENERIFE SUR AEROPUERTO',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '64',
#   'tmed': '25,5',
#   'prec': '0,0',
#   'tmin': '21,6',
#   'horatmin': '03:38',
#   'tmax': '29,4',
#   'horatmax': '10:46',
#   'dir': '07',
#   'velmedia': '8,3',
#   'racha': '15,0',
#   'horaracha': '16:31',
#   'sol': '8,2',
#   'presMax': '1010,3',
#   'horaPresMax': 'Varias',
#   'presMin': '1007,3',
#   'horaPresMin': '03'},
#  {'fecha': '2019-08-30',
#   'indicativo': 'C439J',
#   'nombre': 'GÜÍMAR',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '115',
#   'tmed': '23,4',
#   'prec': '0,0',
#   'tmin': '19,6',
#   'horatmin': '06:50',
#   'tmax': '27,3',
#   'horatmax': '14:30',
#   'dir': '08',
#   'velmedia': '3,6',
#   'racha': '7,5',
#   'horaracha': '11:50',
#   'presMax': '1005,8',
#   'horaPresMax': '08',
#   'presMin': '1002,5',
#   'horaPresMin': '04'},
#  {'fecha': '2019-08-31',
#   'indicativo': 'C447A',
#   'nombre': 'TENERIFE NORTE AEROPUERTO',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '632',
#   'tmed': '20,3',
#   'prec': '0,0',
#   'tmin': '16,8',
#   'horatmin': '06:41',
#   'tmax': '23,8',
#   'horatmax': '15:33',
#   'dir': '29',
#   'velmedia': '8,3',
#   'racha': '15,3',
#   'horaracha': '23:29',
#   'sol': '5,7',
#   'presMax': '949,2',
#   'horaPresMax': 'Varias',
#   'presMin': '947,3',
#   'horaPresMin': '17'},
#  {'fecha': '2019-08-31',
#   'indicativo': 'C449C',
#   'nombre': 'STA.CRUZ DE TENERIFE',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '35',
#   'tmed': '25,0',
#   'prec': '0,0',
#   'tmin': '21,8',
#   'horatmin': '06:10',
#   'tmax': '28,2',
#   'horatmax': '11:50',
#   'dir': '08',
#   'velmedia': '3,6',
#   'racha': '10,0',
#   'horaracha': '15:00',
#   'sol': '9,4',
#   'presMax': '1014,0',
#   'horaPresMax': '00',
#   'presMin': '1011,6',
#   'horaPresMin': '17'},
#  {'fecha': '2019-08-31',
#   'indicativo': 'C429I',
#   'nombre': 'TENERIFE SUR AEROPUERTO',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '64',
#   'tmed': '24,8',
#   'prec': '0,0',
#   'tmin': '21,9',
#   'horatmin': '06:41',
#   'tmax': '27,7',
#   'horatmax': '14:32',
#   'dir': '99',
#   'velmedia': '8,6',
#   'racha': '16,1',
#   'horaracha': 'Varias',
#   'sol': '6,1',
#   'presMax': '1009,4',
#   'horaPresMax': 'Varias',
#   'presMin': '1006,9',
#   'horaPresMin': '19'},
#  {'fecha': '2019-08-31',
#   'indicativo': 'C439J',
#   'nombre': 'GÜÍMAR',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '115',
#   'tmed': '22,8',
#   'prec': '0,0',
#   'tmin': '20,1',
#   'horatmin': '05:30',
#   'tmax': '25,6',
#   'horatmax': '12:00',
#   'dir': '06',
#   'velmedia': '5,6',
#   'racha': '11,7',
#   'horaracha': '12:40',
#   'presMax': '1004,9',
#   'horaPresMax': '13',
#   'presMin': '1002,3',
#   'horaPresMin': '19'},
#  {'fecha': '2019-09-01',
#   'indicativo': 'C447A',
#   'nombre': 'TENERIFE NORTE AEROPUERTO',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '632',
#   'tmed': '20,3',
#   'prec': '0,0',
#   'tmin': '16,9',
#   'horatmin': '06:24',
#   'tmax': '23,7',
#   'horatmax': '16:21',
#   'dir': '29',
#   'velmedia': '8,3',
#   'racha': '13,9',
#   'horaracha': '09:09',
#   'sol': '9,5',
#   'presMax': '948,4',
#   'horaPresMax': 'Varias',
#   'presMin': '946,2',
#   'horaPresMin': '18'},
#  {'fecha': '2019-09-01',
#   'indicativo': 'C449C',
#   'nombre': 'STA.CRUZ DE TENERIFE',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '35',
#   'tmed': '24,7',
#   'prec': '0,0',
#   'tmin': '21,4',
#   'horatmin': '06:40',
#   'tmax': '28,0',
#   'horatmax': '14:20',
#   'dir': '05',
#   'velmedia': '3,3',
#   'racha': '9,7',
#   'horaracha': '13:40',
#   'sol': '11,4',
#   'presMax': '1013,5',
#   'horaPresMax': '10',
#   'presMin': '1011,0',
#   'horaPresMin': '18'},
#  {'fecha': '2019-09-01',
#   'indicativo': 'C429I',
#   'nombre': 'TENERIFE SUR AEROPUERTO',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '64',
#   'tmed': '24,8',
#   'prec': '0,0',
#   'tmin': '21,6',
#   'horatmin': '06:30',
#   'tmax': '27,9',
#   'horatmax': '13:31',
#   'dir': '07',
#   'velmedia': '8,9',
#   'racha': '17,5',
#   'horaracha': '12:19',
#   'sol': '11,5',
#   'presMax': '1008,6',
#   'horaPresMax': 'Varias',
#   'presMin': '1005,8',
#   'horaPresMin': '03'},
#  {'fecha': '2019-09-01',
#   'indicativo': 'C439J',
#   'nombre': 'GÜÍMAR',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '115',
#   'tmed': '23,0',
#   'prec': '0,0',
#   'tmin': '20,1',
#   'horatmin': '23:59',
#   'tmax': '26,0',
#   'horatmax': '10:30',
#   'dir': '07',
#   'velmedia': '5,6',
#   'racha': '11,7',
#   'horaracha': '09:30',
#   'presMax': '1003,6',
#   'horaPresMax': '12',
#   'presMin': '1000,8',
#   'horaPresMin': '06'},
#  {'fecha': '2019-09-02',
#   'indicativo': 'C447A',
#   'nombre': 'TENERIFE NORTE AEROPUERTO',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '632',
#   'tmed': '20,1',
#   'prec': '0,0',
#   'tmin': '16,9',
#   'horatmin': '05:18',
#   'tmax': '23,3',
#   'horatmax': '13:04',
#   'dir': '99',
#   'velmedia': '5,8',
#   'racha': '12,5',
#   'horaracha': 'Varias',
#   'sol': '8,7',
#   'presMax': '948,3',
#   'horaPresMax': '11',
#   'presMin': '945,7',
#   'horaPresMin': '05'},
#  {'fecha': '2019-09-02',
#   'indicativo': 'C449C',
#   'nombre': 'STA.CRUZ DE TENERIFE',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '35',
#   'tmed': '25,0',
#   'prec': '0,0',
#   'tmin': '21,9',
#   'horatmin': '06:50',
#   'tmax': '28,1',
#   'horatmax': '15:40',
#   'dir': '99',
#   'velmedia': '3,6',
#   'racha': '11,4',
#   'horaracha': 'Varias',
#   'sol': '9,8',
#   'presMax': '1013,6',
#   'horaPresMax': '10',
#   'presMin': '1011,1',
#   'horaPresMin': '05'},
#  {'fecha': '2019-09-02',
#   'indicativo': 'C429I',
#   'nombre': 'TENERIFE SUR AEROPUERTO',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '64',
#   'tmed': '24,0',
#   'prec': '0,0',
#   'tmin': '20,7',
#   'horatmin': '06:08',
#   'tmax': '27,4',
#   'horatmax': '15:50',
#   'dir': '06',
#   'velmedia': '7,5',
#   'racha': '13,9',
#   'horaracha': '15:52',
#   'sol': '11,5',
#   'presMax': '1009,0',
#   'horaPresMax': 'Varias',
#   'presMin': '1006,3',
#   'horaPresMin': '05'},
#  {'fecha': '2019-09-02',
#   'indicativo': 'C439J',
#   'nombre': 'GÜÍMAR',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '115',
#   'tmed': '22,4',
#   'prec': '0,0',
#   'tmin': '19,2',
#   'horatmin': '01:50',
#   'tmax': '25,5',
#   'horatmax': '13:40',
#   'dir': '08',
#   'velmedia': '5,3',
#   'racha': '10,3',
#   'horaracha': '02:50',
#   'presMax': '1004,3',
#   'horaPresMax': '11',
#   'presMin': '1001,2',
#   'horaPresMin': 'Varias'},
#  {'fecha': '2019-09-03',
#   'indicativo': 'C447A',
#   'nombre': 'TENERIFE NORTE AEROPUERTO',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '632',
#   'tmed': '19,9',
#   'prec': '0,0',
#   'tmin': '16,1',
#   'horatmin': '06:35',
#   'tmax': '23,7',
#   'horatmax': '14:30',
#   'dir': '31',
#   'velmedia': '6,4',
#   'racha': '12,8',
#   'horaracha': '17:40',
#   'sol': '11,8',
#   'presMax': '950,5',
#   'horaPresMax': 'Varias',
#   'presMin': '947,2',
#   'horaPresMin': '03'},
#  {'fecha': '2019-09-03',
#   'indicativo': 'C449C',
#   'nombre': 'STA.CRUZ DE TENERIFE',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '35',
#   'tmed': '25,3',
#   'prec': '0,0',
#   'tmin': '21,1',
#   'horatmin': '05:50',
#   'tmax': '29,5',
#   'horatmax': '15:50',
#   'dir': '10',
#   'velmedia': '3,3',
#   'racha': '9,2',
#   'horaracha': '13:50',
#   'sol': '11,8',
#   'presMax': '1015,6',
#   'horaPresMax': '11',
#   'presMin': '1012,7',
#   'horaPresMin': '04'},
#  {'fecha': '2019-09-03',
#   'indicativo': 'C429I',
#   'nombre': 'TENERIFE SUR AEROPUERTO',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '64',
#   'tmed': '23,6',
#   'prec': '0,0',
#   'tmin': '19,9',
#   'horatmin': '04:11',
#   'tmax': '27,3',
#   'horatmax': '13:08',
#   'dir': '99',
#   'velmedia': '6,1',
#   'racha': '10,8',
#   'horaracha': 'Varias',
#   'sol': '10,4',
#   'presMax': '1011,6',
#   'horaPresMax': 'Varias',
#   'presMin': '1008,3',
#   'horaPresMin': '03'},
#  {'fecha': '2019-09-03',
#   'indicativo': 'C439J',
#   'nombre': 'GÜÍMAR',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '115',
#   'tmed': '22,5',
#   'prec': '0,0',
#   'tmin': '19,1',
#   'horatmin': '07:00',
#   'tmax': '25,9',
#   'horatmax': '15:10',
#   'dir': '08',
#   'velmedia': '3,6',
#   'racha': '8,3',
#   'horaracha': '15:30',
#   'presMax': '1006,5',
#   'horaPresMax': '11',
#   'presMin': '1002,9',
#   'horaPresMin': '03'},
#  {'fecha': '2019-09-04',
#   'indicativo': 'C447A',
#   'nombre': 'TENERIFE NORTE AEROPUERTO',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '632',
#   'tmed': '19,8',
#   'prec': '0,0',
#   'tmin': '16,6',
#   'horatmin': 'Varias',
#   'tmax': '23,0',
#   'horatmax': '13:20',
#   'dir': '99',
#   'velmedia': '6,4',
#   'racha': '12,5',
#   'horaracha': 'Varias',
#   'sol': '10,8',
#   'presMax': '950,6',
#   'horaPresMax': 'Varias',
#   'presMin': '948,7',
#   'horaPresMin': '04'},
#  {'fecha': '2019-09-04',
#   'indicativo': 'C449C',
#   'nombre': 'STA.CRUZ DE TENERIFE',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '35',
#   'tmed': '25,1',
#   'prec': '0,0',
#   'tmin': '21,3',
#   'horatmin': '06:10',
#   'tmax': '28,9',
#   'horatmax': '14:10',
#   'dir': '34',
#   'velmedia': '3,1',
#   'racha': '10,0',
#   'horaracha': '14:20',
#   'sol': '11,8',
#   'presMax': '1015,9',
#   'horaPresMax': '09',
#   'presMin': '1013,7',
#   'horaPresMin': '16'},
#  {'fecha': '2019-09-04',
#   'indicativo': 'C429I',
#   'nombre': 'TENERIFE SUR AEROPUERTO',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '64',
#   'tmed': '24,2',
#   'prec': '0,0',
#   'tmin': '20,4',
#   'horatmin': '06:38',
#   'tmax': '28,0',
#   'horatmax': '13:20',
#   'dir': '10',
#   'velmedia': '6,9',
#   'racha': '13,3',
#   'horaracha': '13:29',
#   'sol': '11,9',
#   'presMax': '1011,6',
#   'horaPresMax': 'Varias',
#   'presMin': '1009,4',
#   'horaPresMin': '18'},
#  {'fecha': '2019-09-04',
#   'indicativo': 'C439J',
#   'nombre': 'GÜÍMAR',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '115',
#   'tmed': '22,6',
#   'prec': '0,0',
#   'tmin': '18,4',
#   'horatmin': '03:50',
#   'tmax': '26,9',
#   'horatmax': '15:20',
#   'dir': '08',
#   'velmedia': '4,2',
#   'racha': '12,2',
#   'horaracha': '12:20',
#   'presMax': '1006,0',
#   'horaPresMax': '09',
#   'presMin': '1004,1',
#   'horaPresMin': '19'},
#  {'fecha': '2019-09-05',
#   'indicativo': 'C447A',
#   'nombre': 'TENERIFE NORTE AEROPUERTO',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '632',
#   'tmed': '20,5',
#   'prec': '0,0',
#   'tmin': '17,1',
#   'horatmin': '03:17',
#   'tmax': '23,9',
#   'horatmax': '14:12',
#   'dir': '28',
#   'velmedia': '8,6',
#   'racha': '14,4',
#   'horaracha': '04:45',
#   'sol': '4,7',
#   'presMax': '949,1',
#   'horaPresMax': '00',
#   'presMin': '946,6',
#   'horaPresMin': '18'},
#  {'fecha': '2019-09-05',
#   'indicativo': 'C449C',
#   'nombre': 'STA.CRUZ DE TENERIFE',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '35',
#   'tmed': '25,1',
#   'prec': '0,0',
#   'tmin': '21,9',
#   'horatmin': '06:40',
#   'tmax': '28,3',
#   'horatmax': '13:40',
#   'dir': '30',
#   'velmedia': '2,2',
#   'racha': '13,1',
#   'horaracha': '13:50',
#   'sol': '11,3',
#   'presMax': '1014,4',
#   'horaPresMax': '00',
#   'presMin': '1011,8',
#   'horaPresMin': '16'},
#  {'fecha': '2019-09-05',
#   'indicativo': 'C429I',
#   'nombre': 'TENERIFE SUR AEROPUERTO',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '64',
#   'tmed': '23,6',
#   'prec': '0,0',
#   'tmin': '20,3',
#   'horatmin': '05:30',
#   'tmax': '26,8',
#   'horatmax': '10:10',
#   'dir': '30',
#   'velmedia': '3,9',
#   'racha': '9,2',
#   'horaracha': '05:15',
#   'sol': '5,3',
#   'presMax': '1010,1',
#   'horaPresMax': '00',
#   'presMin': '1007,8',
#   'horaPresMin': '18'},
#  {'fecha': '2019-09-05',
#   'indicativo': 'C439J',
#   'nombre': 'GÜÍMAR',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '115',
#   'tmed': '22,8',
#   'prec': '0,0',
#   'tmin': '18,0',
#   'horatmin': '06:50',
#   'tmax': '27,7',
#   'horatmax': '12:40',
#   'dir': '19',
#   'velmedia': '3,9',
#   'racha': '8,3',
#   'horaracha': '13:20',
#   'presMax': '1004,6',
#   'horaPresMax': '00',
#   'presMin': '1002,2',
#   'horaPresMin': '16'},
#  {'fecha': '2019-09-06',
#   'indicativo': 'C447A',
#   'nombre': 'TENERIFE NORTE AEROPUERTO',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '632',
#   'tmed': '19,2',
#   'prec': '0,0',
#   'tmin': '17,3',
#   'horatmin': '23:53',
#   'tmax': '21,0',
#   'horatmax': '10:48',
#   'dir': '29',
#   'velmedia': '8,3',
#   'racha': '15,0',
#   'horaracha': '00:37',
#   'sol': '0,4',
#   'presMax': '948,3',
#   'horaPresMax': 'Varias',
#   'presMin': '946,3',
#   'horaPresMin': '04'},
#  {'fecha': '2019-09-06',
#   'indicativo': 'C449C',
#   'nombre': 'STA.CRUZ DE TENERIFE',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '35',
#   'tmed': '25,3',
#   'prec': '0,0',
#   'tmin': '22,8',
#   'horatmin': '23:30',
#   'tmax': '27,8',
#   'horatmax': '11:50',
#   'dir': '31',
#   'velmedia': '4,2',
#   'racha': '13,1',
#   'horaracha': '10:20',
#   'sol': '8,7',
#   'presMax': '1013,5',
#   'horaPresMax': '12',
#   'presMin': '1011,3',
#   'horaPresMin': '04'},
#  {'fecha': '2019-09-06',
#   'indicativo': 'C429I',
#   'nombre': 'TENERIFE SUR AEROPUERTO',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '64',
#   'tmed': '23,6',
#   'prec': '0,0',
#   'tmin': '19,4',
#   'horatmin': '04:50',
#   'tmax': '27,8',
#   'horatmax': '13:00',
#   'dir': '99',
#   'velmedia': '4,4',
#   'racha': '10,3',
#   'horaracha': 'Varias',
#   'sol': '1,0',
#   'presMax': '1009,5',
#   'horaPresMax': 'Varias',
#   'presMin': '1007,1',
#   'horaPresMin': '04'},
#  {'fecha': '2019-09-06',
#   'indicativo': 'C439J',
#   'nombre': 'GÜÍMAR',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '115',
#   'tmed': '23,4',
#   'prec': '0,0',
#   'tmin': '18,7',
#   'horatmin': '02:20',
#   'tmax': '28,0',
#   'horatmax': '11:50',
#   'dir': '21',
#   'velmedia': '4,7',
#   'racha': '9,2',
#   'horaracha': '14:10',
#   'presMax': '1003,5',
#   'horaPresMax': '23',
#   'presMin': '1001,8',
#   'horaPresMin': 'Varias'},
#  {'fecha': '2019-09-07',
#   'indicativo': 'C447A',
#   'nombre': 'TENERIFE NORTE AEROPUERTO',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '632',
#   'tmed': '20,1',
#   'prec': '0,0',
#   'tmin': '16,7',
#   'horatmin': '00:51',
#   'tmax': '23,5',
#   'horatmax': '13:56',
#   'dir': '29',
#   'velmedia': '7,8',
#   'racha': '13,3',
#   'horaracha': '18:20',
#   'sol': '8,9',
#   'presMax': '948,2',
#   'horaPresMax': 'Varias',
#   'presMin': '946,3',
#   'horaPresMin': '18'},
#  {'fecha': '2019-09-07',
#   'indicativo': 'C449C',
#   'nombre': 'STA.CRUZ DE TENERIFE',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '35',
#   'tmed': '25,6',
#   'prec': '0,0',
#   'tmin': '22,4',
#   'horatmin': 'Varias',
#   'tmax': '28,9',
#   'horatmax': '14:20',
#   'dir': '33',
#   'velmedia': '3,3',
#   'racha': '10,6',
#   'horaracha': '09:10',
#   'sol': '11,5',
#   'presMax': '1013,5',
#   'horaPresMax': '22',
#   'presMin': '1011,4',
#   'horaPresMin': '04'},
#  {'fecha': '2019-09-07',
#   'indicativo': 'C429I',
#   'nombre': 'TENERIFE SUR AEROPUERTO',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '64',
#   'tmed': '24,6',
#   'prec': '0,0',
#   'tmin': '21,5',
#   'horatmin': 'Varias',
#   'tmax': '27,8',
#   'horatmax': '11:37',
#   'dir': '22',
#   'velmedia': '4,7',
#   'racha': '11,4',
#   'horaracha': '11:34',
#   'sol': '10,4',
#   'presMax': '1009,1',
#   'horaPresMax': 'Varias',
#   'presMin': '1007,2',
#   'horaPresMin': '17'},
#  {'fecha': '2019-09-07',
#   'indicativo': 'C439J',
#   'nombre': 'GÜÍMAR',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '115',
#   'tmed': '22,6',
#   'prec': '0,0',
#   'tmin': '18,7',
#   'horatmin': '07:00',
#   'tmax': '26,6',
#   'horatmax': '13:50',
#   'dir': '21',
#   'velmedia': '3,6',
#   'racha': '8,1',
#   'horaracha': '02:10',
#   'presMax': '1003,9',
#   'horaPresMax': '22',
#   'presMin': '1001,8',
#   'horaPresMin': '04'},
#  ...]

# %%
df_meteo = pd.DataFrame(valores_climatologicos)

# %%
df_meteo.head()
# Out:
#         fecha indicativo                     nombre              provincia  \
# 0  2019-01-01      C447A  TENERIFE NORTE AEROPUERTO  STA. CRUZ DE TENERIFE
# 1  2019-01-01      C449C       STA.CRUZ DE TENERIFE  STA. CRUZ DE TENERIFE
# 2  2019-01-01      C429I    TENERIFE SUR AEROPUERTO  STA. CRUZ DE TENERIFE
# 3  2019-01-01      C439J                     GÜÍMAR  STA. CRUZ DE TENERIFE
# 4  2019-01-02      C447A  TENERIFE NORTE AEROPUERTO  STA. CRUZ DE TENERIFE
#
#   altitud  tmed prec  tmin horatmin  tmax horatmax  dir velmedia racha  \
# 0     632  15,0  0,0  10,4    07:56  19,5    15:30   16      3,9  11,4
# 1      35  19,6  0,0  15,0    07:00  24,2    15:20   20      3,1   8,6
# 2      64  19,2  0,0  15,1    06:54  23,3    13:05   03      4,4   8,9
# 3     115  16,6  0,0  10,5    05:50  22,6    17:00  NaN      NaN   NaN
# 4     632  14,6  0,0  10,9    23:30  18,2    12:28   14      3,1   7,8
#
#   horaracha  sol presMax horaPresMax presMin horaPresMin
# 0     10:11  5,5   956,5      Varias   951,2          01
# 1     13:00  9,3  1023,3      Varias  1018,1          01
# 2     20:50  9,6  1018,3      Varias  1013,0          05
# 3       NaN  NaN  1013,7          22  1008,4          05
# 4     00:47  6,3   957,5      Varias   954,5          24

# %%
df_meteo.shape
# Out:
# (1460, 20)

# %%
df_meteo.to_csv(DATA_PATH+'df_meteo_tfs_2019.csv', index = False)
